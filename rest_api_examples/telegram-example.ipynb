# %% [markdown]
# # Telegram Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting Messages
#
# Returns list of telegram messages according to filtration specified in the request.
#
# ***Parameters:***
#
# `from_`
# - `from_` is the required parameter; however, the start of data history is used if omitted. The date could be entered as a timestamp (integer number) or by a human-readable string (e.g., `2022-05-01`).
#
# `limit`
# - The parameter `limit` has to be a positive number. It is compulsory parameter.
#
# `tag`
# - An optional parameter for filtering messages.
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
messages = client.get_telegram(
    "2022-04-01T00:00Z",
    10
)
messages
# Out:
# [TelegramPublicMessage(
#  	sent_at = 2022-04-01 00:00:00+00:00,
#  	message_id = 115306659840,
#  	content = Bridgebot | BLOCK Info
#  	------------------------
#  	CMC Rank: 746
#
#  	Price USD: $348.74M
#  	Cap USD: $2,882,868.46B
#  	Change 24h: +34867438975.47%🚀
#  	Change 7d: +30987249966.52%🚀
#  	Volume USD: $0.00
#
#  	Price BTC: 0.00051449
#  	Cap BTC: 4.25K BTC
#  	Change 24h: +2291.60%🚀
#  	Change 7d: +2218.29%🚀
#  	Volume BTC: 0.00 BTC
#
#  	Staking ROI: 16.45%
#
#  	Supply: 8.58M
#  	Staking: 3.20M
#
#  	Difficulty: 7.79K
#  	Nodes Qty: 163
#  	Height: 2436623,
#  	created_at = 2022-04-01 00:00:00.293613+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:58+00:00,
#  	message_id = 52858716160,
#  	content = 🔥🔥SHILLERS UNION (First of its kind) 🔥🔥
#
#  	💥 PROFESSIONAL DIGITAL CRYPTOCURRENCY MARKETING & AUDITING COMPANY 💥
#
#  	With past experience of working with big projects like cum rockets and babyfeg token.
#
#  	💡💡 SERVICES PROVIDED 💡💡
#
#  	✅ AUDITS ( BY CONTRACTO)
#  	✅ TELEGRAM SHILLING (CONTINUOUS)
#  	✅ TWITTER SHILLING (TARGETED)
#  	✅ FACEBOOK SHILLING (TARGETED)
#  	✅ TWITTER INFLUENCER PROMOTION(GIVEAWAY)
#  	✅ CMS + SUBREDDIT POSTS
#  	✅ CMS UPVOTES
#  	✅ COINSNIPER UPVOTES
#  	✅ PINNED MESSAGES(TELEGRAM CHANNEL) 📌
#  	✅ INSTAGRAM PROMOTION
#  	✅ WEBSITE BANNER PROMOTION
#  	✅ SHORT PROMOTIONAL VIDEOS
#  	✅ STICKER PACKS
#  	✅ LOGO DESIGNING
#
#  	For project promotions contact = @shillteam14
#
#  	Twitter =  https://twitter.com/UShillers?s=09
#
#  	Website = https://www.shillersunion.com/
#
#  	 Telegram Channel https://t.me/cryptosos2,
#  	created_at = 2022-04-01 00:00:00.313826+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:54+00:00,
#  	message_id = 2469557960704,
#  	content = 🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼
#
#  	🚨 Public Launch on April 6, 13:30 UTC @redpandabsc
#
#  	The REDPANDA Future was conceived with a mission to create an open MetaVerse, where partners not only play games to earn money, but also freely create values to serve the needs of the inhabitants of the MetaVerse.
#
#  	Features:
#
#  	Liquidity Locked 5 Year 💦
#  	Advanced Anti-Whale Feature 🐳
#  	Fast Blockchain ✅
#
#  	👑 Official Links:  🌐 Website (https://redpanda.info/) | 🐦 Twitter (https://twitter.com/redpandabsc) | 💬 Telegram (https://t.me/redpandabsc)
#
#  	  📲TG Chanel : @pikachushil
#  	     ⚡️  SHILL BY Contact : @Pikachushilservis,
#  	created_at = 2022-04-01 00:00:00.338824+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:55+00:00,
#  	message_id = 2469559009280,
#  	content = 🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼
#
#  	🚨 Public Launch on April 6, 13:30 UTC 🚨
#
#  	📈 Lowest Cost
#  	Maximum low transaction fees thanks to Binance Smart Chain (BEP-20) integration
#
#  	🎆 Join Community : @redpandabsc @redpandabsc
#
#  	🌐 Community
#  	By using our payment system, you will interact with people in our community, and this will lead to sustainable partnership and security!
#
#  	✅ Fast Blockchain
#  	SHIBF Token is an BSC BEP-20 Token. This guarantees fast translations and accurate work!
#
#  	📝 Token Details & Features:
#
#  	🐼 Token Name: REDPANDA
#  	🐼 Token Symbol: $RPND
#  	🐼 Token Type: BEP-20 (PancakeSwap V2)
#  	🐼 Total Supply: 100,000,000,000 💎
#  	🐼 Liquidity Locked 5 Year 💦
#  	🐼 Advanced Anti-Whale Feature 🐳
#
#  	🎆 Join Community : @redpandabsc @redpandabsc
#
#  	📊 Tax Distribution (15% Total TX Fee):
#
#  	3% Marketing & Community Funds 🤲
#  	10% BTC Reward (Every BUY)
#  	2% Auto Liquidity 💦
#
#  	🌐 Website - 🐦Twitter - 💬 Telegram,
#  	created_at = 2022-04-01 00:00:00.356425+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:58+00:00,
#  	message_id = 2469560057856,
#  	content = 9532g,
#  	created_at = 2022-04-01 00:00:00.361694+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:59+00:00,
#  	message_id = 2469561106432,
#  	content = 🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼
#
#  	🚨 Public Launch on April 6, 13:30 UTC 🚨
#
#  	📈 Lowest Cost
#  	Maximum low transaction fees thanks to Binance Smart Chain (BEP-20) integration
#
#  	🎆 Join Community : @redpandabsc @redpandabsc
#
#  	🌐 Community
#  	By using our payment system, you will interact with people in our community, and this will lead to sustainable partnership and security!
#
#  	✅ Fast Blockchain
#  	SHIBF Token is an BSC BEP-20 Token. This guarantees fast translations and accurate work!
#
#  	📝 Token Details & Features:
#
#  	🐼 Token Name: REDPANDA
#  	🐼 Token Symbol: $RPND
#  	🐼 Token Type: BEP-20 (PancakeSwap V2)
#  	🐼 Total Supply: 100,000,000,000 💎
#  	🐼 Liquidity Locked 5 Year 💦
#  	🐼 Advanced Anti-Whale Feature 🐳
#
#  	🎆 Join Community : @redpandabsc @redpandabsc
#
#  	📊 Tax Distribution (15% Total TX Fee):
#
#  	3% Marketing & Community Funds 🤲
#  	10% BTC Reward (Every BUY)
#  	2% Auto Liquidity 💦
#
#  	🌐 Website - 🐦Twitter - 💬 Telegram,
#  	created_at = 2022-04-01 00:00:00.364737+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:57+00:00,
#  	message_id = 22344742469632,
#  	content = 🦍Welcome to GoldenApes 🦍
#
#  	Our team have over 2 years of experience in blockchain development with diverse skill sets in the gaming industry. We decided to form synergy to build a successful NFT game that will win mainstream attention, just like subway surfers did with an outstanding statistics of over 1billion downloads on playstore alone. GoldenApes is a huge step at fostering mainstream adoption of blockchain NFT gaming. The comprehensive ecosystem comprises of - The endless runner game on BSc, NFT Marketplace, Innovative staking platform, rare collectibles and GoldenApes community.
#
#  	🧬Tokenomics:
#
#  	Name: GoldenApes
#  	Symbol: GAPE
#  	Network: BSC
#  	Decimals: 18
#  	Total supply: 1,000,000,000
#  	Contract: 0x3c4B50035a90ce1C567a5421DC7fcfE02c36b274
#
#  	15% tax on buy
#  	⬇️
#  	1% to  liquidity pool
#  	2% to Market Wallet
#  	12% to BUSD reward pool
#
#  	15% tax on sell
#  	⬇️
#  	1% to liquidity pool
#  	2% to Marketing Wallet
#  	12% to BUSD reward pool
#
#  	🔑Telegram group: https://t.me/GoldenApesToken
#
#  	🚀Fair launch link: https://www.pinksale.finance/#/launchpad/0x382E4271615d9CC145CE9ee24FA3B41584960fBd?chain=BSC
#
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#
#
#  	#GoldenApesTokenFast
#  	🟢➖🟡➖🔴➖🟣➖🔵➖🟤
#
#  	☎️SHILL BY Contact : @FastSafee
#
#  	🟢➖🟡➖🔴➖🟣➖🔵➖🟤,
#  	created_at = 2022-04-01 00:00:00.370058+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:58+00:00,
#  	message_id = 22344743518208,
#  	content = 🦍Welcome to GoldenApes 🦍
#
#  	Our team have over 2 years of experience in blockchain development with diverse skill sets in the gaming industry. We decided to form synergy to build a successful NFT game that will win mainstream attention, just like subway surfers did with an outstanding statistics of over 1billion downloads on playstore alone. GoldenApes is a huge step at fostering mainstream adoption of blockchain NFT gaming. The comprehensive ecosystem comprises of - The endless runner game on BSc, NFT Marketplace, Innovative staking platform, rare collectibles and GoldenApes community.
#
#  	🧬Tokenomics:
#
#  	Name: GoldenApes
#  	Symbol: GAPE
#  	Network: BSC
#  	Decimals: 18
#  	Total supply: 1,000,000,000
#  	Contract: 0x3c4B50035a90ce1C567a5421DC7fcfE02c36b274
#
#  	15% tax on buy
#  	⬇️
#  	1% to  liquidity pool
#  	2% to Market Wallet
#  	12% to BUSD reward pool
#
#  	15% tax on sell
#  	⬇️
#  	1% to liquidity pool
#  	2% to Marketing Wallet
#  	12% to BUSD reward pool
#
#  	🔑Telegram group: https://t.me/GoldenApesToken
#
#  	🚀Fair launch link: https://www.pinksale.finance/#/launchpad/0x382E4271615d9CC145CE9ee24FA3B41584960fBd?chain=BSC
#
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#  	👉JOIN NOW : @GoldenApesToken
#
#
#  	#GoldenApesTokenFast
#  	🟢➖🟡➖🔴➖🟣➖🔵➖🟤
#
#  	☎️SHILL BY Contact : @FastSafee
#
#  	🟢➖🟡➖🔴➖🟣➖🔵➖🟤,
#  	created_at = 2022-04-01 00:00:00.375563+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:59+00:00,
#  	message_id = 2469562155008,
#  	content = 6662y,
#  	created_at = 2022-04-01 00:00:00.383417+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 23:59:54+00:00,
#  	message_id = 9201100259328,
#  	content = ﻿‼️ HIGGS DOMINO TOKEN ($HDT) PINKSALE PRESALE LIVE NOW ‼️
#
#  	💰 Low initial MarketCap
#  	✅ 6% Low Tax
#  	✅ Big Marketing Running
#  	✅ P2E Nft and Web3 Project
#  	🔥 40% tokens BURNED at launch
#  	🔥 3% Weekly burn
#
#  	🌐 Website : https://higgsdomino.io/
#  	💬 Telegram : @higgsdominotoken
#  	🐦 Twitter : https://twitter.com/HiggsToken
#
#  	Promoter by : @Sastrashiller
#  	░▒█ ░▀░ █░█▀▀█ █▀▀█,
#  	created_at = 2022-04-01 00:00:00.386585+00:00,
#  )]

# %%
pd.DataFrame([m.__dict__ for m in messages]).set_index("created_at")
# Out:
#                                                    sent_at      message_id  \
# created_at
# 2022-04-01 00:00:00.293613+00:00 2022-04-01 00:00:00+00:00    115306659840
# 2022-04-01 00:00:00.313826+00:00 2022-03-31 23:59:58+00:00     52858716160
# 2022-04-01 00:00:00.338824+00:00 2022-03-31 23:59:54+00:00   2469557960704
# 2022-04-01 00:00:00.356425+00:00 2022-03-31 23:59:55+00:00   2469559009280
# 2022-04-01 00:00:00.361694+00:00 2022-03-31 23:59:58+00:00   2469560057856
# 2022-04-01 00:00:00.364737+00:00 2022-03-31 23:59:59+00:00   2469561106432
# 2022-04-01 00:00:00.370058+00:00 2022-03-31 23:59:57+00:00  22344742469632
# 2022-04-01 00:00:00.375563+00:00 2022-03-31 23:59:58+00:00  22344743518208
# 2022-04-01 00:00:00.383417+00:00 2022-03-31 23:59:59+00:00   2469562155008
# 2022-04-01 00:00:00.386585+00:00 2022-03-31 23:59:54+00:00   9201100259328
#
#                                                                             content
# created_at
# 2022-04-01 00:00:00.293613+00:00  Bridgebot | BLOCK Info\n----------------------...
# 2022-04-01 00:00:00.313826+00:00  🔥🔥SHILLERS UNION (First of its kind) 🔥🔥\n\n💥 P...
# 2022-04-01 00:00:00.338824+00:00  🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼\n\n🚨 Pu...
# 2022-04-01 00:00:00.356425+00:00  🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼\n\n🚨 Pu...
# 2022-04-01 00:00:00.361694+00:00                                              9532g
# 2022-04-01 00:00:00.364737+00:00  🐼 REDPANDA ($RPDN) | %10 BTC REWARD! 🐼\n\n🚨 Pu...
# 2022-04-01 00:00:00.370058+00:00  🦍Welcome to GoldenApes 🦍\n\nOur team have over...
# 2022-04-01 00:00:00.375563+00:00  🦍Welcome to GoldenApes 🦍\n\nOur team have over...
# 2022-04-01 00:00:00.383417+00:00                                              6662y
# 2022-04-01 00:00:00.386585+00:00  ﻿‼️ HIGGS DOMINO TOKEN ($HDT) PINKSALE PRESALE...

# %%
messages = client.get_telegram(
    from_ = "2022-04-01",
    limit = 10,
    tag = "cardano"
)
messages
# Out:
# [TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:05:34+00:00,
#  	message_id = 374219997184,
#  	content = Team, does anyone happen to know how to determine the exact amount of cards/ada in the migrated pair at the time we pulled it from dripdropz?  I have since staked it with SS and the pair values are constantly changing and doesn't reflect the amount that was in the pair when it was staked.  Cardano scan for the dropdropz receive has a bunch of transactions in that block so I'm not sure how to tell what my exact numbers were before the stake.,
#  	created_at = 2022-03-31 22:05:41.330937+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:07:01+00:00,
#  	message_id = 31860981760,
#  	content = This project is going to be strong an cardano and has the potential of being the best project on the cardano blockchain,
#  	created_at = 2022-03-31 22:07:02.072659+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:10:40+00:00,
#  	message_id = 31866224640,
#  	content = And also the fact that it's built on the cardano Blockchain just blows my mind,
#  	created_at = 2022-03-31 22:10:40.853712+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:11:51+00:00,
#  	message_id = 1274221166592,
#  	content = imagine if cardano community notices our ada cave tomorrow,
#  	created_at = 2022-03-31 22:11:52.444492+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:12:47+00:00,
#  	message_id = 1274231652352,
#  	content = when the ADA cave goes live, let’s raid the tweet and tag cardano in the comments,
#  	created_at = 2022-03-31 22:12:49.621736+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:15:07+00:00,
#  	message_id = 33162264576,
#  	content = Does trezor T support Cardano?,
#  	created_at = 2022-03-31 22:15:07.786608+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:15:10+00:00,
#  	message_id = 25499271168,
#  	content = Does trezor T support Cardano?,
#  	created_at = 2022-03-31 22:15:11.691854+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:22:52+00:00,
#  	message_id = 78182875136,
#  	content = Up-ada.
#  	Ada-up
#  	Massive liquidity on cardano.
#  	If your going cross chain.
#  	Might be a good thing to try as you branch out.,
#  	created_at = 2022-03-31 22:22:52.740749+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:30:58+00:00,
#  	message_id = 374231531520,
#  	content = It launches new projects and if you hold cards you get first to buy.
#  	But its migrating to cardano at minute. So no IDOs until then,
#  	created_at = 2022-03-31 22:30:59.772634+00:00,
#  ),
#  TelegramPublicMessage(
#  	sent_at = 2022-03-31 22:43:49+00:00,
#  	message_id = 987155660800,
#  	content = Hello
#
#  	I am a fullstack developer and have a lot of experience in web development and blockchain projects(Defi/DEX/NFT/Metaverse/Solana/Cardano).
#
#  	If you are currently hiring a Blockchain Developer or Full Stack Developer, please let me know.,
#  	created_at = 2022-03-31 22:44:00.126380+00:00,
#  )]
