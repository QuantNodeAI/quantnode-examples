# %% [markdown]
# # LP Tokens Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting LP Tokens
#
# Returns list of LP tokens, with pagination.
#
# ***Parameters:***
#
# `chain`
# - It is an optional parameter with the default value `"bsc"` (_Binance Smart Chain_). The chain can be specified as a string (case insensitive) or an integer (chain id).
#
# `limit`
# - By default, number of items is 10. Maximal allowed value is 100.
#
# `page`
# - Optional parameter, by default equal to 1.
#
# `sort`
# - Optional parameter for sorting the items. Items are sorted descending according to time by default.
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
tokens = client.get_lps()
tokens
# Out:
# [TokenResponseExtended(
#  	id = 1,
#  	name = Pancake LPs,
#  	symbol = TMT/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1095200.5536463638,
#  	contract = 0x2c7a7ef1de5d007f16401BBe80b127d9B94b0D9d,
#  	token_0 = {'id': 1, 'name': 'TopManager Token', 'symbol': 'TMT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000', 'circulating_supply': '100000000', 'contract': '0x4803Ac6b79F9582F69c4fa23c72cb76dD1E46d8d'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 2,
#  	name = Pancake LPs,
#  	symbol = LMT/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9344.767786959736,
#  	contract = 0x8271d7eAfeEb8F24d7C9fE1AccE2AE20611972E5,
#  	token_0 = {'id': 12, 'name': 'Lympo Market Token', 'symbol': 'LMT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '117964415.1767743494092877', 'circulating_supply': '117964415.1767743494092877', 'contract': '0x9617857E191354dbEA0b714d78Bc59e57C411087'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 3,
#  	name = Pancake LPs,
#  	symbol = WBNB/XVS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 31957.16853244027,
#  	contract = 0x7EB5D86FD78f3852a3e0e064f2842d45a3dB6EA2,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 14, 'name': 'Venus', 'symbol': 'XVS', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '30000000', 'circulating_supply': '29745109.5432573815069642', 'contract': '0xcF6BB5389c92Bdda8a3747Ddb454cB7a64626C63'},
#  ),
#  TokenResponseExtended(
#  	id = 4,
#  	name = Pancake LPs,
#  	symbol = ETH/USDC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 181490.764628607,
#  	contract = 0xEa26B78255Df2bBC31C1eBf60010D78670185bD0,
#  	token_0 = {'id': 8, 'name': 'Ethereum Token', 'symbol': 'ETH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1404999.9999908485028069', 'circulating_supply': '1404988.2498213210586288', 'contract': '0x2170Ed0880ac9A755fd29B2688956BD959F933F8'},
#  	token_1 = {'id': 9, 'name': 'USD Coin', 'symbol': 'USDC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1878999999.999999997504281', 'circulating_supply': '1878999624.0137290977953258', 'contract': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d'},
#  ),
#  TokenResponseExtended(
#  	id = 5,
#  	name = Pancake LPs,
#  	symbol = TRX/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 31275343.5292458,
#  	contract = 0xb5D108578Be3750209d1b3A8f45FFee8C5a75146,
#  	token_0 = {'id': 16, 'name': 'TRON', 'symbol': 'TRX', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '430000000', 'circulating_supply': '429988687.9460231547358974', 'contract': '0x85EAC5Ac2F758618dFa09bDbe0cf174e7d574D5B'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 6,
#  	name = Pancake LPs,
#  	symbol = WBNB/GEM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 24990.32359861104,
#  	contract = 0x28E38FeE521e55bB44219aadbA591045256C81A4,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 18, 'name': 'GEM token', 'symbol': 'GEM', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '5000000', 'circulating_supply': '4999563.7743002049220036', 'contract': '0xC526399973608E6080AFF02062A3840DA6148738'},
#  ),
#  TokenResponseExtended(
#  	id = 7,
#  	name = Pancake LPs,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 3807697.3060108367,
#  	contract = 0x58F876857a02D6762E0101bb5C46A8c1ED44Dc16,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 8,
#  	name = Pancake LPs,
#  	symbol = WBNB/EFT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 135320438.0452848,
#  	contract = 0x8bA52005fFB23c02e1fdf805F3fdbaDD337959A1,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 15, 'name': 'ETH Fan Token', 'symbol': 'EFT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000000000000000', 'circulating_supply': '617293861540228.8261080431231072', 'contract': '0xCcB5051962F77e6a23ecA1235c97FaD32fbB9826'},
#  ),
#  TokenResponseExtended(
#  	id = 9,
#  	name = MDEX LP Token,
#  	symbol = ETH/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 102754.99193741746,
#  	contract = 0x0FB881c078434b1C0E4d0B64d8c64d12078b7Ce2,
#  	token_0 = {'id': 8, 'name': 'Ethereum Token', 'symbol': 'ETH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1404999.9999908485028069', 'circulating_supply': '1404988.2498213210586288', 'contract': '0x2170Ed0880ac9A755fd29B2688956BD959F933F8'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 10,
#  	name = Pancake LPs,
#  	symbol = PPAD/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 40483.896914034194,
#  	contract = 0x778E4a3b6ec989796Dd330569FDa6Ea9426CB064,
#  	token_0 = {'id': 21, 'name': 'PlayPad Token', 'symbol': 'PPAD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000', 'circulating_supply': '93729555.6620518299816974', 'contract': '0x93Bb13E90678cCd8BBab07D1dAEF15086746dc9B'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  )]

# %%
pd.DataFrame([t.__dict__ for t in tokens])
# Out:
#             name     symbol chain  decimals  total_supply  \
# 0    Pancake LPs   TMT/BUSD   BSC      18.0  1.094997e+06
# 1    Pancake LPs   LMT/WBNB   BSC      18.0  9.471799e+03
# 2    Pancake LPs   WBNB/XVS   BSC      18.0  3.614291e+04
# 3    Pancake LPs   ETH/USDC   BSC      18.0  1.741502e+05
# 4    Pancake LPs   TRX/BUSD   BSC      18.0  3.074343e+07
# 5    Pancake LPs   WBNB/GEM   BSC      18.0  2.499032e+04
# 6    Pancake LPs  WBNB/BUSD   BSC      18.0  6.638355e+06
# 7    Pancake LPs   WBNB/EFT   BSC      18.0  1.353204e+08
# 8  MDEX LP Token   ETH/USDT   BSC      18.0  1.923624e+05
# 9    Pancake LPs  PPAD/WBNB   BSC      18.0  4.035715e+04
#
#                                      contract  \
# 0  0x2c7a7ef1de5d007f16401BBe80b127d9B94b0D9d
# 1  0x8271d7eAfeEb8F24d7C9fE1AccE2AE20611972E5
# 2  0x7EB5D86FD78f3852a3e0e064f2842d45a3dB6EA2
# 3  0xEa26B78255Df2bBC31C1eBf60010D78670185bD0
# 4  0xb5D108578Be3750209d1b3A8f45FFee8C5a75146
# 5  0x28E38FeE521e55bB44219aadbA591045256C81A4
# 6  0x58F876857a02D6762E0101bb5C46A8c1ED44Dc16
# 7  0x8bA52005fFB23c02e1fdf805F3fdbaDD337959A1
# 8  0x0FB881c078434b1C0E4d0B64d8c64d12078b7Ce2
# 9  0x778E4a3b6ec989796Dd330569FDa6Ea9426CB064
#
#                                              token_0  \
# 0  {'name': 'TopManager Token', 'symbol': 'TMT', ...
# 1  {'name': 'Lympo Market Token', 'symbol': 'LMT'...
# 2  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...
# 3  {'name': 'Ethereum Token', 'symbol': 'ETH', 'c...
# 4  {'name': 'TRON', 'symbol': 'TRX', 'chain': 'BS...
# 5  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...
# 6  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...
# 7  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...
# 8  {'name': 'Ethereum Token', 'symbol': 'ETH', 'c...
# 9  {'name': 'PlayPad Token', 'symbol': 'PPAD', 'c...
#
#                                              token_1
# 0  {'name': 'BUSD Token', 'symbol': 'BUSD', 'chai...
# 1  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...
# 2  {'name': 'Venus', 'symbol': 'XVS', 'chain': 'B...
# 3  {'name': 'USD Coin', 'symbol': 'USDC', 'chain'...
# 4  {'name': 'BUSD Token', 'symbol': 'BUSD', 'chai...
# 5  {'name': 'GEM token', 'symbol': 'GEM', 'chain'...
# 6  {'name': 'BUSD Token', 'symbol': 'BUSD', 'chai...
# 7  {'name': 'ETH Fan Token', 'symbol': 'EFT', 'ch...
# 8  {'name': 'Tether USD', 'symbol': 'USDT', 'chai...
# 9  {'name': 'Wrapped BNB', 'symbol': 'WBNB', 'cha...

# %%
tokens = client.get_lps(
    limit = 100,
    page = 1,
    sort = "+name", # the same as "name.asc"
)
tokens
# Out:
# [TokenResponseExtended(
#  	id = 386260,
#  	symbol = UNFI/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 33.61547262794322,
#  	contract = 0x54579276b1B288F6A482776564CC1f1806910778,
#  	token_0 = {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1370958.48293432619', 'circulating_supply': '1370958.4829343261803745', 'contract': '0x728C5baC3C3e370E372Fc4671f9ef6916b814d8B'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 863363,
#  	symbol = UNFI/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0x9A7C53E99bF6a310d62c36e47dDed6785A6F5b1A,
#  	token_0 = {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1370958.48293432619', 'circulating_supply': '1370958.4829343261803745', 'contract': '0x728C5baC3C3e370E372Fc4671f9ef6916b814d8B'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 797382,
#  	symbol = USDT/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.98997487421e-05,
#  	contract = 0x7eaF35b218d1716bFB45120cF12772a6e27D5C85,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 386259,
#  	symbol = UNFI/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 7.600535236750819,
#  	contract = 0x8a36540E0EcfAFc64AbE834F347D1946acE0CDc7,
#  	token_0 = {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1370958.48293432619', 'circulating_supply': '1370958.4829343261803745', 'contract': '0x728C5baC3C3e370E372Fc4671f9ef6916b814d8B'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 166331,
#  	name = 0x1 LP Token,
#  	symbol = Terk/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4.0924557165e-06,
#  	contract = 0x3793cf4d0421258442496B66eC8776261C8b1B55,
#  	token_0 = {'id': 100, 'name': 'Terk', 'symbol': 'Terk', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '210000000000', 'circulating_supply': '207999997990', 'contract': '0x53035E4e14fb3f82C02357B35d5cC0C5b53928B4'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 892651,
#  	name = 0x1 LP Token,
#  	symbol = WMUE/1INCH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.1487603408001286,
#  	contract = 0xC94F3493aE1E2Ce2D82BF731B0682331B61B1e09,
#  	token_0 = {'id': 3684, 'name': 'Wrapped MonetaryUnit', 'symbol': 'WMUE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '20166324.8103855413564099', 'circulating_supply': '20166324.8103855413564099', 'contract': '0x00abaA93fAF8fDc4f382135a7A56F9Cf7C3EdD21'},
#  	token_1 = {'id': 915, 'name': '1INCH Token', 'symbol': '1INCH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '25000000', 'circulating_supply': '24999999.168242781473533', 'contract': '0x111111111117dC0aa78b770fA6A738034120C302'},
#  ),
#  TokenResponseExtended(
#  	id = 705698,
#  	name = 0x1 LP Token,
#  	symbol = BBYXRP/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0xDC891E433a25616f2a100c4bCDe3aEBb159b6D29,
#  	token_0 = {'id': 5462, 'name': 'BABYXRP', 'symbol': 'BBYXRP', 'chain': 'BSC', 'active': False, 'decimals': '9', 'total_supply': '1000000000000000', 'circulating_supply': '656007244791785.539644078', 'contract': '0x8beAbaa4f025D00B4699d56a683758d692d17F20'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 892647,
#  	name = 0x1 LP Token,
#  	symbol = WMUE/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0139988923666792,
#  	contract = 0x7Ec9146B8f0BDB60eCfa4662586577FD195f6597,
#  	token_0 = {'id': 3684, 'name': 'Wrapped MonetaryUnit', 'symbol': 'WMUE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '20166324.8103855413564099', 'circulating_supply': '20166324.8103855413564099', 'contract': '0x00abaA93fAF8fDc4f382135a7A56F9Cf7C3EdD21'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 892642,
#  	name = 0x1 LP Token,
#  	symbol = 1INCH/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0004898780232283,
#  	contract = 0x689AB411D9BD3DC01fc739a118a5fc1Eaca6e8B9,
#  	token_0 = {'id': 915, 'name': '1INCH Token', 'symbol': '1INCH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '25000000', 'circulating_supply': '24999999.168242781473533', 'contract': '0x111111111117dC0aa78b770fA6A738034120C302'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 892649,
#  	name = 0x1 LP Token,
#  	symbol = WMUE/Cake,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0264396492044499,
#  	contract = 0x8f12AccFEdcFaA10ab6bd9D01Ea88b8aE1278eb5,
#  	token_0 = {'id': 3684, 'name': 'Wrapped MonetaryUnit', 'symbol': 'WMUE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '20166324.8103855413564099', 'circulating_supply': '20166324.8103855413564099', 'contract': '0x00abaA93fAF8fDc4f382135a7A56F9Cf7C3EdD21'},
#  	token_1 = {'id': 23, 'name': 'PancakeSwap Token', 'symbol': 'Cake', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '828541719.7510512016109955', 'circulating_supply': '313381184.2799324699842769', 'contract': '0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82'},
#  ),
#  TokenResponseExtended(
#  	id = 698799,
#  	name = 0x1 LP Token,
#  	symbol = Field/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0xcB30F5184E338F02bf15a47b73bF69Edc5638183,
#  	token_0 = {'id': 5230, 'name': 'YieldFields Token', 'symbol': 'Field', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '122251445.576930044674252', 'circulating_supply': '118151025.576930044674252', 'contract': '0x04D50c032F16a25d1449Ef04D893e95Bcc54d747'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 826760,
#  	name = 0x1 LP Token,
#  	symbol = Cake/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.001562207145935,
#  	contract = 0x3e91E66BEdf3f6B22B6Bd66D05561944DC540E9B,
#  	token_0 = {'id': 23, 'name': 'PancakeSwap Token', 'symbol': 'Cake', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '828541719.7510512016109955', 'circulating_supply': '313381184.2799324699842769', 'contract': '0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 122720,
#  	name = 0x1 LP Token,
#  	symbol = 1INCH/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 16.235578679925542,
#  	contract = 0xBF12CCA84A04dC3E1286E1FB9ca89388e46e8c5a,
#  	token_0 = {'id': 915, 'name': '1INCH Token', 'symbol': '1INCH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '25000000', 'circulating_supply': '24999999.168242781473533', 'contract': '0x111111111117dC0aa78b770fA6A738034120C302'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 250394,
#  	name = 0x1 LP Token,
#  	symbol = WMUE/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 534.207559009798,
#  	contract = 0xdaf4cCf9D8a95C6304018b514C8961Db71Ec4672,
#  	token_0 = {'id': 3684, 'name': 'Wrapped MonetaryUnit', 'symbol': 'WMUE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '20166324.8103855413564099', 'circulating_supply': '20166324.8103855413564099', 'contract': '0x00abaA93fAF8fDc4f382135a7A56F9Cf7C3EdD21'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 238712,
#  	name = 0x1 LP Token,
#  	symbol = WBNB/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2.1340465758306824,
#  	contract = 0xb8202415265a84069437699F1Dd2026335808416,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 122721,
#  	name = 0x1 LP Token,
#  	symbol = USDT/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 376.9275092378198,
#  	contract = 0x0B98B25Dc0cdEdbF0acC2858540c4aA7414D438a,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 264415,
#  	name = 0x1 LP Token,
#  	symbol = ETH/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.058357726442594,
#  	contract = 0xcc177E281c908dC2FF456bFF81B8F48b360F5ADF,
#  	token_0 = {'id': 8, 'name': 'Ethereum Token', 'symbol': 'ETH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1404999.9999908485028069', 'circulating_supply': '1404988.2498213210586288', 'contract': '0x2170Ed0880ac9A755fd29B2688956BD959F933F8'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 38416,
#  	name = 0x1 LP Token,
#  	symbol = USDT/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.3562244450007677,
#  	contract = 0xF7019b0EA2D7bD8BC94394103630e8030788CF12,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 210448,
#  	name = 0x1 LP Token,
#  	symbol = USDT/BTCB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0122547832837305,
#  	contract = 0x3A9d07c6BC6D8c4b6B2a09E72653Ec7a7da4B49f,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 204, 'name': 'BTCB Token', 'symbol': 'BTCB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '112501', 'circulating_supply': '112494.1611586364209641', 'contract': '0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c'},
#  ),
#  TokenResponseExtended(
#  	id = 903645,
#  	name = 0x1 LP Token,
#  	symbol = WMUE/CUB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.030203331466875,
#  	contract = 0xb5EF198D2896107D828FD08EE0e2f783e400C3d5,
#  	token_0 = {'id': 3684, 'name': 'Wrapped MonetaryUnit', 'symbol': 'WMUE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '20166324.8103855413564099', 'circulating_supply': '20166324.8103855413564099', 'contract': '0x00abaA93fAF8fDc4f382135a7A56F9Cf7C3EdD21'},
#  	token_1 = {'id': 3695, 'name': 'Cub Finance', 'symbol': 'CUB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '16246660.1672554398633216', 'circulating_supply': '15728678.7838180489869784', 'contract': '0x50D809c74e0B8e49e7B4c65BB3109AbE3Ff4C1C1'},
#  ),
#  TokenResponseExtended(
#  	id = 761972,
#  	name = 0x1 LP Token,
#  	symbol = USDT/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0002194004707814,
#  	contract = 0xF48eD63fb7247adee0B9149701e216dc38D45227,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 195765,
#  	name = 0x1 LP Token,
#  	symbol = Cake/BIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21.27930952748668,
#  	contract = 0x0E39B20C5476cFD097F743f37625e3210813B9e3,
#  	token_0 = {'id': 23, 'name': 'PancakeSwap Token', 'symbol': 'Cake', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '828541719.7510512016109955', 'circulating_supply': '313381184.2799324699842769', 'contract': '0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82'},
#  	token_1 = {'id': 148177, 'name': '0x1 Token', 'symbol': 'BIN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000', 'circulating_supply': '10000', 'contract': '0xcC1DA2Eaa0150b958Fd30c3B849d9EfE1d365AED'},
#  ),
#  TokenResponseExtended(
#  	id = 256373,
#  	name = 123 LPs,
#  	symbol = USDC/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.5,
#  	contract = 0xff91d50bCF90Ba0a0bAAA88462F7555f5D3E5E95,
#  	token_0 = {'id': 9, 'name': 'USD Coin', 'symbol': 'USDC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1878999999.999999997504281', 'circulating_supply': '1878999624.0137290977953258', 'contract': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 4093,
#  	name = 123 LPs,
#  	symbol = USDT/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 6.0419148015361195,
#  	contract = 0xB6C6E2763DCED1f769958840a3eDd7c36ffA05bD,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 22457,
#  	name = 123 LPs,
#  	symbol = USDC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.1788130234686466,
#  	contract = 0x0A1F730643e7bC0127953e5E57cDc94DFb37B782,
#  	token_0 = {'id': 9, 'name': 'USD Coin', 'symbol': 'USDC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1878999999.999999997504281', 'circulating_supply': '1878999624.0137290977953258', 'contract': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 114715,
#  	name = 123 LPs,
#  	symbol = USDT/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.025,
#  	contract = 0xD305Cc58369A5ec129a9579fc1D2DFb502e20805,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 281133,
#  	name = 123 LPs,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.002,
#  	contract = 0x1Ba808427310f304336e5F382c649BAC1B1756E8,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 256491,
#  	name = 123 LPs,
#  	symbol = USDC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5.098004488e-07,
#  	contract = 0x1777899F96ED3F9D500608a0579fcCBa68Edb174,
#  	token_0 = {'id': 9, 'name': 'USD Coin', 'symbol': 'USDC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1878999999.999999997504281', 'circulating_supply': '1878999624.0137290977953258', 'contract': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 355635,
#  	name = 123swap LP Token,
#  	symbol = USDC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.020000000000001,
#  	contract = 0x7f5471e38336dA86F6087744AFbff496ACC9aF8c,
#  	token_0 = {'id': 9, 'name': 'USD Coin', 'symbol': 'USDC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1878999999.999999997504281', 'circulating_supply': '1878999624.0137290977953258', 'contract': '0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 437988,
#  	name = 123swap LP Token,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.002,
#  	contract = 0x997394E8646Eb9b51a4040e0E07e8d229D2E8c66,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 365760,
#  	name = 1COINSWAP LP Token,
#  	symbol = JOINT/1CN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5555.0,
#  	contract = 0xca4b97c6B16E4aB9Dce35365134fa97A348DD903,
#  	token_0 = {'id': 439861, 'name': 'JointToken', 'symbol': 'JOINT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '2000000', 'circulating_supply': '2000000', 'contract': '0x5F7b4aE59f77DE164E07F7178Cb4351fFF9b2136'},
#  	token_1 = {'id': 54513, 'name': '1COIN Network', 'symbol': '1CN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '34000000000', 'circulating_supply': '34000000000', 'contract': '0x87b9B3cd3a5C8aD3EB1611A8B3F12478A6b3ad43'},
#  ),
#  TokenResponseExtended(
#  	id = 340905,
#  	name = 1COINSWAP LP Token,
#  	symbol = JOINT/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0023466612147409,
#  	contract = 0xe693ee1a053901F2eCC8e869Eb6C45646BDC55bD,
#  	token_0 = {'id': 439861, 'name': 'JointToken', 'symbol': 'JOINT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '2000000', 'circulating_supply': '2000000', 'contract': '0x5F7b4aE59f77DE164E07F7178Cb4351fFF9b2136'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 782180,
#  	name = 1COINSWAP LP Token,
#  	symbol = 1CN/1CAT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5000.0,
#  	contract = 0x7df88297D2851Ba0229048A11B38b56fc86497F8,
#  	token_0 = {'id': 54513, 'name': '1COIN Network', 'symbol': '1CN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '34000000000', 'circulating_supply': '34000000000', 'contract': '0x87b9B3cd3a5C8aD3EB1611A8B3F12478A6b3ad43'},
#  	token_1 = {'id': 1010697, 'name': '1COIN AT', 'symbol': '1CAT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '33000000000', 'circulating_supply': '33000000000', 'contract': '0xBE192A15da3D4004242DE1B215691D08A69543D1'},
#  ),
#  TokenResponseExtended(
#  	id = 782176,
#  	name = 1COINSWAP LP Token,
#  	symbol = WBNB/1CAT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 7.0710678118654755,
#  	contract = 0x97ffb2484F0457C353DFa5bF4Bc4a0605dcdA4C9,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 1010697, 'name': '1COIN AT', 'symbol': '1CAT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '33000000000', 'circulating_supply': '33000000000', 'contract': '0xBE192A15da3D4004242DE1B215691D08A69543D1'},
#  ),
#  TokenResponseExtended(
#  	id = 327528,
#  	name = 1COINSWAP LP Token,
#  	symbol = 1CN/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 541.0469648458107,
#  	contract = 0x020183Ad61371C591937a0cb1Ca3ecba9d43feae,
#  	token_0 = {'id': 54513, 'name': '1COIN Network', 'symbol': '1CN', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '34000000000', 'circulating_supply': '34000000000', 'contract': '0x87b9B3cd3a5C8aD3EB1611A8B3F12478A6b3ad43'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 373719,
#  	name = 1COINSWAP LP Token,
#  	symbol = DAI/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0006701971173015,
#  	contract = 0x80e4E1A2F166E53C1a90d23143B90834aDe3D78e,
#  	token_0 = {'id': 549, 'name': 'Dai Token', 'symbol': 'DAI', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '161999999.9999990081053326', 'circulating_supply': '161999921.9540790984730026', 'contract': '0x1AF3F329e8BE154074D8769D1FFa4eE058B1DBc3'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 333575,
#  	name = 1COINSWAP LP Token,
#  	symbol = 1COINswap/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4.0523e-12,
#  	contract = 0xdAc7C46DfD931A57837A617cF84d8a2ca8da704B,
#  	token_0 = {'id': 430044, 'name': '1COINswap Token', 'symbol': '1COINswap', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '0.0000000000104788', 'circulating_supply': '0.0000000000104788', 'contract': '0xA1dc7ab8FA042E91ab771D6596a6E32baEc89F4d'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 69182,
#  	name = 1INCH/WBNB Value LP,
#  	symbol = 1INCH/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0xe4dAA0E3DBf8b3869B13c4E394c669256160B3aD,
#  	token_0 = {'id': 915, 'name': '1INCH Token', 'symbol': '1INCH', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '25000000', 'circulating_supply': '24999999.168242781473533', 'contract': '0x111111111117dC0aa78b770fA6A738034120C302'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 663644,
#  	name = 1MM LPs,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.002000000000001,
#  	contract = 0x27860b92E7a193d072b4aED10a6e3054fa5759a0,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 264093,
#  	name = 2GameCoin-LP,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.1037720261501171,
#  	contract = 0xbdB274C84F7Dd51A39628645Ac1077bD1c0a1616,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 680875,
#  	name = 2GameCoin-LP,
#  	symbol = 2GC/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9.85388491515616,
#  	contract = 0x9b44a809d546F7B0e7d088AAA4089760Bc211ce9,
#  	token_0 = {'id': 863617, 'name': '2GameCoin', 'symbol': '2GC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '500000000', 'circulating_supply': '500000000', 'contract': '0xAD3C6Dbc0F156bf438038aB63a7de25c988a5eE4'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 24187,
#  	name = 2GameCoin-LP,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0540024784125982,
#  	contract = 0xde70E6d84AE7af2a0a2f4149a3837eae0C468c4c,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 263714,
#  	name = 2GameCoin-LP,
#  	symbol = 2GC/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2.1058649330031662,
#  	contract = 0xB0ECFC18Fb65C023C918CAe4196DE09FF87069D9,
#  	token_0 = {'id': 337018, 'name': '2GameCoin', 'symbol': '2GC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '200000000', 'circulating_supply': '200000000', 'contract': '0x83Ee7E0Dc4CECf34b40E961Ce84Db5CbFA41123f'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 680877,
#  	name = 2GameCoin-LP,
#  	symbol = 2GC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.4231160054065194,
#  	contract = 0x0854f8Dc04e7941256c200731019b2E44cB8f2df,
#  	token_0 = {'id': 863617, 'name': '2GameCoin', 'symbol': '2GC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '500000000', 'circulating_supply': '500000000', 'contract': '0xAD3C6Dbc0F156bf438038aB63a7de25c988a5eE4'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 266046,
#  	name = 2GameCoin-LP,
#  	symbol = 2GC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0979083991417752,
#  	contract = 0xaa561b454d9d3e89f596584CeE84A32f260A1D27,
#  	token_0 = {'id': 337018, 'name': '2GameCoin', 'symbol': '2GC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '200000000', 'circulating_supply': '200000000', 'contract': '0x83Ee7E0Dc4CECf34b40E961Ce84Db5CbFA41123f'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 8093,
#  	name = 2INCH LP Token,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 154.3624518771703,
#  	contract = 0x193562bEebD9cA5f985a283446AA64eB98e44362,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 49187,
#  	name = 2local LPs,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.41911956332e-05,
#  	contract = 0x949285d7eBB74F6D2FDBEFC60d19E619a8A5dfce,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 306960,
#  	name = 2local LPs,
#  	symbol = CLONE/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2.2768399153212333,
#  	contract = 0x3d6B35f4caed47B3C5c842d4ca8A0C00c615AfA7,
#  	token_0 = {'id': 394739, 'name': 'Clone Token', 'symbol': 'CLONE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1588655.0625', 'circulating_supply': '1588655.0625', 'contract': '0x45be9d5f6F746D7b5CC2A94804e7A98e81835126'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 22539,
#  	name = 2local LPs,
#  	symbol = BUSD/ECOIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.000316157658394,
#  	contract = 0xaACE612F68B574fb839Cdbe75b5241f4da8Fe6EB,
#  	token_0 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  	token_1 = {'id': 23696, 'name': 'ECOIN', 'symbol': 'ECOIN', 'chain': 'BSC', 'active': False, 'decimals': '5', 'total_supply': '10000000000', 'circulating_supply': '10000000000', 'contract': '0xEBA66d75A2b3A832B1EaEe03B83fFd91a38Bb362'},
#  ),
#  TokenResponseExtended(
#  	id = 18422,
#  	name = 2local LPs,
#  	symbol = 2LC/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 332981.4325697643,
#  	contract = 0x24CD591b6A62Cc7475De500B18C7705eBaA3EE22,
#  	token_0 = {'id': 3257, 'name': '2local Token', 'symbol': '2LC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '13400000000', 'circulating_supply': '13399999976', 'contract': '0x11F6ECC9E2658627e0876212f1078b9F84d3196e'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 22546,
#  	name = 2local LPs,
#  	symbol = WBNB/ECOIN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4.28340253314e-05,
#  	contract = 0xDd83F61a437165B2C223a871d08862FBC7b1af57,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 23696, 'name': 'ECOIN', 'symbol': 'ECOIN', 'chain': 'BSC', 'active': False, 'decimals': '5', 'total_supply': '10000000000', 'circulating_supply': '10000000000', 'contract': '0xEBA66d75A2b3A832B1EaEe03B83fFd91a38Bb362'},
#  ),
#  TokenResponseExtended(
#  	id = 3474,
#  	name = 2local LPs,
#  	symbol = 2LC/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10022.289657688045,
#  	contract = 0xA77924b786314fA4F7E603C10c372dA1E779b8d1,
#  	token_0 = {'id': 3257, 'name': '2local Token', 'symbol': '2LC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '13400000000', 'circulating_supply': '13399999976', 'contract': '0x11F6ECC9E2658627e0876212f1078b9F84d3196e'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 18932,
#  	name = 3x-LP,
#  	symbol = WBNB/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4.808384240054033,
#  	contract = 0x5aa1562850492AF08Ca1B293CB1f8B38678F5D36,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 180750,
#  	name = 3x-LP,
#  	symbol = 3x/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0x5C0d61bA2B83aE803B6fD11054EC14413Ee2F257,
#  	token_0 = {'id': 11349, 'name': '3x', 'symbol': '3x', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '3000002378.64', 'circulating_supply': '3000002378.64', 'contract': '0xbe40731Af77099e974733C6BAf5A97F497928c8f'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 11499,
#  	name = 3x-LP,
#  	symbol = 3x/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 990000.0,
#  	contract = 0x93e319c63Bfb8c0a14Ba1733825d9977d32551ef,
#  	token_0 = {'id': 11349, 'name': '3x', 'symbol': '3x', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '3000002378.64', 'circulating_supply': '3000002378.64', 'contract': '0xbe40731Af77099e974733C6BAf5A97F497928c8f'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 11501,
#  	name = 3x-LP,
#  	symbol = WBNB/3x,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 40818.74569361484,
#  	contract = 0xFd436521DB1032148C7E7Ff42CCd7C623857BE02,
#  	token_0 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  	token_1 = {'id': 11349, 'name': '3x', 'symbol': '3x', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '3000002378.64', 'circulating_supply': '3000002378.64', 'contract': '0xbe40731Af77099e974733C6BAf5A97F497928c8f'},
#  ),
#  TokenResponseExtended(
#  	id = 529999,
#  	name = 5SWAP,
#  	symbol = USDT/PNC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 707106.7811865475,
#  	contract = 0x7e3CF1BD691592eAf336F70841a87141aD30E8b5,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 366099, 'name': 'PNC', 'symbol': 'PNC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000000000', 'circulating_supply': '10000000000', 'contract': '0x90617c8DB994ff4A44aDc8976CAA2c5C361bE0ba'},
#  ),
#  TokenResponseExtended(
#  	id = 437365,
#  	name = 5SWAP,
#  	symbol = USDT/HJW,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1406870.6729853598,
#  	contract = 0xC5ec04ddbAd647dDFE9b5Ea9e921D2744cad92E2,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 510644, 'name': 'HJW', 'symbol': 'HJW', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '313000000', 'circulating_supply': '313000000', 'contract': '0x6b7B97c52Eec761Ed569471ACeCb05447342F7C3'},
#  ),
#  TokenResponseExtended(
#  	id = 478036,
#  	name = 5SWAP,
#  	symbol = MGET/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 547722.5575051662,
#  	contract = 0xAabb352518F877Cbca39cF973BCA1c69b9DEbB2a,
#  	token_0 = {'id': 550827, 'name': 'MGET', 'symbol': 'MGET', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000000000', 'circulating_supply': '10000000000', 'contract': '0x25A449A185f767401860d95eB5F5c8FF341EF83d'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 437410,
#  	name = 5SWAP,
#  	symbol = USDT/AURA,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 586759.2931515141,
#  	contract = 0xdceD0AF0dd51C22C34298797EE9a28A69a888fE9,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 23027, 'name': 'Aura Token', 'symbol': 'AURA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '555550000', 'circulating_supply': '555550000', 'contract': '0xADB1Ab0912C8ead567fC40753aa7062ea897c745'},
#  ),
#  TokenResponseExtended(
#  	id = 235715,
#  	name = 5SWAP,
#  	symbol = AURA/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0138162189608759,
#  	contract = 0xE66ec1E4B183784f2ba2a09edA5a307Ba3Fe0f50,
#  	token_0 = {'id': 23027, 'name': 'Aura Token', 'symbol': 'AURA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '555550000', 'circulating_supply': '555550000', 'contract': '0xADB1Ab0912C8ead567fC40753aa7062ea897c745'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 229366,
#  	name = AAPEFINANCE LPs,
#  	symbol = SAFEMOON/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4.2426406871e-06,
#  	contract = 0x48060ABD5D9E179261C1fe9320bFB8C47653f03a,
#  	token_0 = {'id': 456, 'name': 'SafeMoon', 'symbol': 'SAFEMOON', 'chain': 'BSC', 'active': False, 'decimals': '9', 'total_supply': '1000000000000000', 'circulating_supply': '999998831765146.829060935', 'contract': '0x8076C74C5e3F5852037F31Ff0093Eeb8c8ADd8D3'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 892457,
#  	name = AAT/BUSD Value LP,
#  	symbol = AAT/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 83.14365174908583,
#  	contract = 0x3bbCDa06FBB87345955e021E98Bbd333b78caAf4,
#  	token_0 = {'id': 1157449, 'name': 'AWESOME Adi Token', 'symbol': 'AAT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '13140000', 'circulating_supply': '13140000', 'contract': '0xa2d99D27695Df1e6069d76394CE9dc86C955B44b'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 889341,
#  	name = ACO LPs,
#  	symbol = USDT/OK,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5.477225575051661,
#  	contract = 0x7aF7C2CE3111807c3767F8934f36D5cEF0ecC125,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 842130, 'name': 'OK', 'symbol': 'OK', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '10000000', 'circulating_supply': '10000000', 'contract': '0xFE6A7FDc2f551102e431E6b9Dff74dF75AB36E4D'},
#  ),
#  TokenResponseExtended(
#  	id = 734948,
#  	name = ACO LPs,
#  	symbol = AEE/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 31.622776601683793,
#  	contract = 0x2b0190e1C104f12338D230aCE5b915b35cfbe2C6,
#  	token_0 = {'id': 928734, 'name': 'AEE Capital', 'symbol': 'AEE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000000', 'circulating_supply': '1000000', 'contract': '0x10e69d94B8F50B009C40C2cd47D78E0D490b5d0A'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 689295,
#  	name = ACO LPs,
#  	symbol = LPCS/U-TEST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 3871666.5439535207,
#  	contract = 0x9B50f4BE66D1dbd3CF55E21B184710E07D626FE2,
# ...
#  ),
#  TokenResponseExtended(
#  	id = 937661,
#  	name = ACO LPs,
#  	symbol = USDT/SS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 15.652475842498529,
#  	contract = 0x52C3B796DFb95b7A0d5d2721b34d1ECB5a1060D6,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 1214521, 'name': 'SS', 'symbol': 'SS', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000', 'circulating_supply': '1000', 'contract': '0x96159934a6669374a351Cc7E5A71c8307E3E7846'},
#  ),
#  TokenResponseExtended(
#  	id = 689520,
#  	name = ACO LPs,
#  	symbol = ABO/U-TEST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 20000.0,
#  	contract = 0xA1de72283Dc8a04dd694ffc29c93148BF841ACcC,
#  	token_0 = {'id': 876855, 'name': 'ABO', 'symbol': 'ABO', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '30000', 'circulating_supply': '30000', 'contract': '0x87DC92E062AB65B01680071de76c8d1219fF2287'},
#  	token_1 = {'id': 730244, 'name': 'USDT-TEST', 'symbol': 'U-TEST', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '9999900000000000', 'circulating_supply': '9999900000000000', 'contract': '0x9caaC8DC3C3D1aC1c8ab5337ee4bA6eD6Bc09aaF'},
#  ),
#  TokenResponseExtended(
#  	id = 693945,
#  	name = ACO LPs,
#  	symbol = ACO/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 25430.51605696841,
#  	contract = 0x8B99EF1EF3FEe00b3b337902AE966428C9eD7348,
#  	token_0 = {'id': 883107, 'name': 'ACO', 'symbol': 'ACO', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '29958.1969680509500091', 'circulating_supply': '17382.6664697372558095', 'contract': '0x3cedaCB7b39B10a6fC8f656EB3cC07DFc12Ae35c'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 950916,
#  	name = ACO LPs,
#  	symbol = USDT/DMS META,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 316.22776601683796,
#  	contract = 0xfD32FE5dA20eb3C1d57249B5de19B4A1A35B1768,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 741460, 'name': 'DMS META', 'symbol': 'DMS META', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '7898236143', 'circulating_supply': '7898236143', 'contract': '0xa8786a7F8c2797515239A16F22ef8a87B58FD56c'},
#  ),
#  TokenResponseExtended(
#  	id = 558531,
#  	name = ACO LPs,
#  	symbol = 币安测试专用/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.9999499987499375,
#  	contract = 0xA2D15B5fC5D012b5F7210453e280339Be69571ED,
#  	token_0 = {'id': 657948, 'name': '币安测试专用', 'symbol': '币安测试专用', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000000000000', 'circulating_supply': '1000000000000', 'contract': '0x210e2B878c8e06A4Ca52a9D0E93942bFc5950B95'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 560093,
#  	name = ACO LPs,
#  	symbol = ACO/U-TEST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9899.494936611665,
#  	contract = 0xd10f98ceD47d5F64c8844f4fB55Ae26e1354d6B0,
#  	token_0 = {'id': 730521, 'name': 'ACO', 'symbol': 'ACO', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '30000', 'circulating_supply': '30000', 'contract': '0x3f0A98aF72eC05835d3eaFAA325241f8A7a76Dd7'},
#  	token_1 = {'id': 730244, 'name': 'USDT-TEST', 'symbol': 'U-TEST', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '9999900000000000', 'circulating_supply': '9999900000000000', 'contract': '0x9caaC8DC3C3D1aC1c8ab5337ee4bA6eD6Bc09aaF'},
#  ),
#  TokenResponseExtended(
#  	id = 944849,
#  	name = ACO LPs,
#  	symbol = SS/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.9899494936611665,
#  	contract = 0x19154404da4127167de32AeD2Efd22cd1284C960,
#  	token_0 = {'id': 1221752, 'name': 'SS', 'symbol': 'SS', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000', 'circulating_supply': '1000', 'contract': '0x9A7833736e05597ec889eC5DE5c6Dd3AF75c6534'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 937640,
#  	name = ACO LPs,
#  	symbol = SS/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.000000000000001,
#  	contract = 0x4aA482A1B419F570d34cCee5286767fF31E32a62,
#  	token_0 = {'id': 1214521, 'name': 'SS', 'symbol': 'SS', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '1000', 'circulating_supply': '1000', 'contract': '0x96159934a6669374a351Cc7E5A71c8307E3E7846'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 683739,
#  	name = ACO LPs,
#  	symbol = USDT/ACO,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 30.331501776206203,
#  	contract = 0xDf74F9D46695a5B417e5a1b7065Df775B46c6513,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 867917, 'name': 'ACO', 'symbol': 'ACO', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '30000', 'circulating_supply': '30000', 'contract': '0xe340126429e9741e6494c062f69c7fcbE06a88b5'},
#  ),
#  TokenResponseExtended(
#  	id = 914503,
#  	name = ACO LPs,
#  	symbol = USDT/AEE,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 3.162277660168379,
#  	contract = 0x8B3bA24053bb2d6BAaD42052B3Eac9aDDC7Ab3eB,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 1185058, 'name': 'AEE', 'symbol': 'AEE', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000', 'circulating_supply': '100000', 'contract': '0xfAd9a91E5C69d3b22dFF36Ea51212Fed166Cb8E0'},
#  ),
#  TokenResponseExtended(
#  	id = 559806,
#  	name = ACO LPs,
#  	symbol = USDT/U-TEST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 3.162277660168379,
#  	contract = 0x2ad9e41968F494A6378cF3875C205045CFfA40A5,
#  	token_0 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  	token_1 = {'id': 730244, 'name': 'USDT-TEST', 'symbol': 'U-TEST', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '9999900000000000', 'circulating_supply': '9999900000000000', 'contract': '0x9caaC8DC3C3D1aC1c8ab5337ee4bA6eD6Bc09aaF'},
#  ),
#  TokenResponseExtended(
#  	id = 560049,
#  	name = ACO LPs,
#  	symbol = ACO/U-TEST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 19798.98987322333,
#  	contract = 0x9c5A82c05f74D93292bD6252E30A61DBC6C1A02a,
#  	token_0 = {'id': 730521, 'name': 'ACO', 'symbol': 'ACO', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '30000', 'circulating_supply': '30000', 'contract': '0x3f0A98aF72eC05835d3eaFAA325241f8A7a76Dd7'},
#  	token_1 = {'id': 730244, 'name': 'USDT-TEST', 'symbol': 'U-TEST', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '9999900000000000', 'circulating_supply': '9999900000000000', 'contract': '0x9caaC8DC3C3D1aC1c8ab5337ee4bA6eD6Bc09aaF'},
#  ),
#  TokenResponseExtended(
#  	id = 831543,
#  	name = ADA/WBNB Value LP,
#  	symbol = ADA/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5.55978551315e-05,
#  	contract = 0x1418c37d67B93cBa80cA1bFA0651bD05fCB186d8,
#  	token_0 = {'id': 879, 'name': 'Cardano Token', 'symbol': 'ADA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '280000000', 'circulating_supply': '279993956.3332700924428991', 'contract': '0x3EE2200Efb3400fAbB9AacF31297cBdD1d435D47'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 583317,
#  	name = ADAcash,
#  	symbol = ADA/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 37.04,
#  	contract = 0x4f4a248EC106BD527984E2b0217Fe43a50d894F1,
#  	token_0 = {'id': 879, 'name': 'Cardano Token', 'symbol': 'ADA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '280000000', 'circulating_supply': '279993956.3332700924428991', 'contract': '0x3EE2200Efb3400fAbB9AacF31297cBdD1d435D47'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 120842,
#  	name = ADAcash,
#  	symbol = ADAcash/SAFEMOON,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0x52B68f50265C5C5f49B1eb9e9CD5C4b7096251f8,
#  	token_0 = {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADAcash', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000000000', 'circulating_supply': '99967560676198.7490255011802066', 'contract': '0x651a89fed302227d41425235F8E934502FB94C48'},
#  	token_1 = {'id': 456, 'name': 'SafeMoon', 'symbol': 'SAFEMOON', 'chain': 'BSC', 'active': False, 'decimals': '9', 'total_supply': '1000000000000000', 'circulating_supply': '999998831765146.829060935', 'contract': '0x8076C74C5e3F5852037F31Ff0093Eeb8c8ADd8D3'},
#  ),
#  TokenResponseExtended(
#  	id = 238526,
#  	name = ADAcash,
#  	symbol = NTX/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.3162277660168379,
#  	contract = 0xcE7492525D8B89b741853b7f87Ad8bef66bD40c1,
#  	token_0 = {'id': 303065, 'name': 'NetixSol', 'symbol': 'NTX', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '300000000', 'circulating_supply': '300000000', 'contract': '0xAC5a7D4E133aa94178a83d6390c9040921b14c5f'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 327563,
#  	name = ADAcash,
#  	symbol = ADAcash/BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0xa7251B7C71857236E606B24e7d3232790F55639B,
#  	token_0 = {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADAcash', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000000000', 'circulating_supply': '99967560676198.7490255011802066', 'contract': '0x651a89fed302227d41425235F8E934502FB94C48'},
#  	token_1 = {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUSD', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4850999328.6294094656550053', 'circulating_supply': '4850773822.9716624991665061', 'contract': '0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56'},
#  ),
#  TokenResponseExtended(
#  	id = 18957,
#  	name = ADAcash,
#  	symbol = ADAcash/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 826163.7678890262,
#  	contract = 0xB7DB3A4b6d78747D28986B15634dEFf2d775D7D1,
#  	token_0 = {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADAcash', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000000000', 'circulating_supply': '99967560676198.7490255011802066', 'contract': '0x651a89fed302227d41425235F8E934502FB94C48'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 20053,
#  	name = ADAcash,
#  	symbol = ADA/ADAcash,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10848607.243878426,
#  	contract = 0x807bAd8a3A7407401429bEF9fC1d0c876e97B2c2,
#  	token_0 = {'id': 879, 'name': 'Cardano Token', 'symbol': 'ADA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '280000000', 'circulating_supply': '279993956.3332700924428991', 'contract': '0x3EE2200Efb3400fAbB9AacF31297cBdD1d435D47'},
#  	token_1 = {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADAcash', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000000000', 'circulating_supply': '99967560676198.7490255011802066', 'contract': '0x651a89fed302227d41425235F8E934502FB94C48'},
#  ),
#  TokenResponseExtended(
#  	id = 118832,
#  	name = ADAcash,
#  	symbol = ADA/USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e-15,
#  	contract = 0xaBf26b22662786BdB60CEd9a5f5637d420536E38,
#  	token_0 = {'id': 879, 'name': 'Cardano Token', 'symbol': 'ADA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '280000000', 'circulating_supply': '279993956.3332700924428991', 'contract': '0x3EE2200Efb3400fAbB9AacF31297cBdD1d435D47'},
#  	token_1 = {'id': 6, 'name': 'Tether USD', 'symbol': 'USDT', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4979997922.1726584085395262', 'circulating_supply': '4979962727.9261662907769359', 'contract': '0x55d398326f99059fF775485246999027B3197955'},
#  ),
#  TokenResponseExtended(
#  	id = 291776,
#  	name = ADAcash,
#  	symbol = ADA/WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 0.0587157143458772,
#  	contract = 0x3628E19363916013e4668bAcE3e08417e86484ad,
#  	token_0 = {'id': 879, 'name': 'Cardano Token', 'symbol': 'ADA', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '280000000', 'circulating_supply': '279993956.3332700924428991', 'contract': '0x3EE2200Efb3400fAbB9AacF31297cBdD1d435D47'},
#  	token_1 = {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'WBNB', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '4634368.5390929170114662', 'circulating_supply': '4634361.6451151676443924', 'contract': '0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c'},
#  ),
#  TokenResponseExtended(
#  	id = 13419,
#  	name = ADAcash,
#  	symbol = ADAcash/MATIC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10099817.829725979,
#  	contract = 0xdA2f81d9882740F8427c97D53B4aa8eF2EE4e61c,
#  	token_0 = {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADAcash', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '100000000000000', 'circulating_supply': '99967560676198.7490255011802066', 'contract': '0x651a89fed302227d41425235F8E934502FB94C48'},
#  	token_1 = {'id': 29, 'name': 'Matic Token', 'symbol': 'MATIC', 'chain': 'BSC', 'active': False, 'decimals': '18', 'total_supply': '99999999.9945597079776697', 'circulating_supply': '99999851.8135995154101288', 'contract': '0xCC42724C6683B7E57334c4E856f4c9965ED682bD'},
#  )]

# %%
pd.DataFrame([t.__dict__ for t in tokens])
# Out:
#         id         symbol chain  decimals  total_supply  \
# 0   386260      UNFI/BUSD   BSC      18.0  3.361547e+01
# 1   863363      UNFI/WBNB   BSC      18.0  1.000000e-15
# 2   797382      USDT/WBNB   BSC      18.0  1.989975e-05
# 3   386259      UNFI/WBNB   BSC      18.0  7.600535e+00
# 4   166331      Terk/WBNB   BSC      18.0  4.092456e-06
# ..     ...            ...   ...       ...           ...
# 95   18957   ADAcash/WBNB   BSC      18.0  8.261638e+05
# 96   20053    ADA/ADAcash   BSC      18.0  1.084861e+07
# 97  118832       ADA/USDT   BSC      18.0  1.000000e-15
# 98  291776       ADA/WBNB   BSC      18.0  5.871571e-02
# 99   13419  ADAcash/MATIC   BSC      18.0  1.009982e+07
#
#                                       contract  \
# 0   0x54579276b1B288F6A482776564CC1f1806910778
# 1   0x9A7C53E99bF6a310d62c36e47dDed6785A6F5b1A
# 2   0x7eaF35b218d1716bFB45120cF12772a6e27D5C85
# 3   0x8a36540E0EcfAFc64AbE834F347D1946acE0CDc7
# 4   0x3793cf4d0421258442496B66eC8776261C8b1B55
# ..                                         ...
# 95  0xB7DB3A4b6d78747D28986B15634dEFf2d775D7D1
# 96  0x807bAd8a3A7407401429bEF9fC1d0c876e97B2c2
# 97  0xaBf26b22662786BdB60CEd9a5f5637d420536E38
# 98  0x3628E19363916013e4668bAcE3e08417e86484ad
# 99  0xdA2f81d9882740F8427c97D53B4aa8eF2EE4e61c
#
#                                               token_0  \
# 0   {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', ...
# 1   {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', ...
# 2   {'id': 6, 'name': 'Tether USD', 'symbol': 'USD...
# 3   {'id': 146, 'name': 'UNFI', 'symbol': 'UNFI', ...
# 4   {'id': 100, 'name': 'Terk', 'symbol': 'Terk', ...
# ..                                                ...
# 95  {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADA...
# 96  {'id': 879, 'name': 'Cardano Token', 'symbol':...
# 97  {'id': 879, 'name': 'Cardano Token', 'symbol':...
# 98  {'id': 879, 'name': 'Cardano Token', 'symbol':...
# 99  {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADA...
#
#                                               token_1          name
# 0   {'id': 2, 'name': 'BUSD Token', 'symbol': 'BUS...           NaN
# 1   {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...           NaN
# 2   {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...           NaN
# 3   {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...           NaN
# 4   {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...  0x1 LP Token
# ..                                                ...           ...
# 95  {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...       ADAcash
# 96  {'id': 4308, 'name': 'ADAcash', 'symbol': 'ADA...       ADAcash
# 97  {'id': 6, 'name': 'Tether USD', 'symbol': 'USD...       ADAcash
# 98  {'id': 10, 'name': 'Wrapped BNB', 'symbol': 'W...       ADAcash
# 99  {'id': 29, 'name': 'Matic Token', 'symbol': 'M...       ADAcash
#
# [100 rows x 9 columns]
