# %% [markdown]
# # Wallets Transactions Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting Data
#
# Method `get_wallets_txs` returns all transactions for given wallet, with pagination.
#
# ***Parameters:***
#
# `chain`
# - It is an optional parameter with the default value `"bsc"` (_Binance Smart Chain_). The chain can be specified as a string (case insensitive) or an integer (chain id).
#
# `address`
# - Required parameter of wallet address (in string format).
#
# `from_`
# - `from_` is the required parameter; however, the start of data history is used if omitted. The date could be entered as a timestamp (integer number) or by a human-readable string (e.g., `2022-05-01`).
#
# `to`
# - The default value is _now_. The format is the same as for parameter `from_`, so a timestamp or a string could be entered. Maximal allowed range between `from_` and `to` is one month.
#
# `limit`
# - By default, number of items is 10. Maximal allowed value is 100.
#
# `page`
# - Optional parameter, by default equal to 1.
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
transactions = client.get_wallets_txs(
    address = "0x8894E0a0c962CB723c1976a4421c95949bE2D4E3",
    from_ = "2022-04-01",
    to = "2022-05-01",
    limit = 100,
)
transactions
# Out:
# [TransactionResponse(
#  	tx_hash = 0x160848eddc98a0c976c10694c773f818e051e05a9e58cdaf8808990d90c793e6,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x2859e4544C4bB03966803b044A93563Bd2D0DD4D",
#  	time = 2022-03-31 22:00:01+00:00,
#  	block = 16548896,
#  	value = 0.0,
#  	tx_fee = 0.00038907,
#  ), TransactionResponse(
#  	tx_hash = 0xd5249d30fb4ad27f2b2d31d20dc384df5b0fe5a5f0b93226acb854cff291e384,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x7c544aC3EE686BE156Db92CF61cE743E7bB28A36",
#  	time = 2022-03-31 22:00:01+00:00,
#  	block = 16548896,
#  	value = 0.24458136,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x6fa4e4e91d8a8ca48308feab31e424c28a5f1cc8a10ce9d71c2374ae6e2cd5c2,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:00:01+00:00,
#  	block = 16548896,
#  	value = 0.0,
#  	tx_fee = 0.00036103,
#  ), TransactionResponse(
#  	tx_hash = 0x1b134598df87962a16c5f154790c40febc0796b46f57d806a90e634ac2fdd48a,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:00:04+00:00,
#  	block = 16548897,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x1ab8468064a8fa8cba29be40ac4b61702e6289cdbd073f1031487a0d9c956c96,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xfb6115445Bff7b52FeB98650C87f44907E58f802,
#  	time = 2022-03-31 22:00:04+00:00,
#  	block = 16548897,
#  	value = 0.0,
#  	tx_fee = 0.00038883,
#  ), TransactionResponse(
#  	tx_hash = 0x918d56abec42a8258507a95ae13e1a767612e99f6cfb482bfcf469ea1a7c047f,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c,
#  	time = 2022-03-31 22:00:04+00:00,
#  	block = 16548897,
#  	value = 0.0,
#  	tx_fee = 0.00051091,
#  ), TransactionResponse(
#  	tx_hash = 0x1dafa54cba08b8914ad74232a1d76c7dc247ad1145be776c98dbc17457162dba,
#  	from_address = "0x643f9eB7982753D103F6DEc6F686d52284B950A5",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:00:13+00:00,
#  	block = 16548900,
#  	value = 399.999895,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xef5c51ab57a43967f12ae19fc23849cdc06f4288775871ad332cb384d548959c,
#  	from_address = "0xbe85401204644143C4966dad4B3A2E4dDF800433",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:00:25+00:00,
#  	block = 16548904,
#  	value = 43.58035,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x1d321f409446b719c11e103eac2d5fcbcad36e7cf0a6d7aa93a756b06fe30e88,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x3019BF2a2eF8040C242C9a4c5c4BD4C81678b2A1,
#  	time = 2022-03-31 22:00:40+00:00,
#  	block = 16548909,
#  	value = 0.0,
#  	tx_fee = 0.00053835,
#  ), TransactionResponse(
#  	tx_hash = 0x56fd1274ef870f0f8a6c5323039be5906a50d8c903206cbc2425b0cf5029bdcb,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:00:40+00:00,
#  	block = 16548909,
#  	value = 0.0,
#  	tx_fee = 0.00036139,
#  ), TransactionResponse(
#  	tx_hash = 0xb8b5d70159f63c11169817ea85267e27e7ca0c7830f742d32f5acf0edc859513,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:00:40+00:00,
#  	block = 16548909,
#  	value = 0.0,
#  	tx_fee = 0.00036115,
#  ), TransactionResponse(
#  	tx_hash = 0xa8d0988e6c0495adbc320c73b8a93f29b3b1bc91635309ddf7815436a6d0dee0,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x1DCB02D83Fd3d3a4fB76E9015Ecfe905ACb7Bc67",
#  	time = 2022-03-31 22:00:43+00:00,
#  	block = 16548910,
#  	value = 0.1014235,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x811a4267148988ae8074aba4ea47460cd429f667d52341db07a914778e80e71d,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:00:43+00:00,
#  	block = 16548910,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0xb7300c168031fc531858b03a039f14709e2dfc86a75a01999c25452df6948f8b,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:00:43+00:00,
#  	block = 16548910,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0x756107f4cfc49a976b0bd13eb78c7f1ead7e82d9e1eb9bd3bdcd6fc63ac05d43,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:00:43+00:00,
#  	block = 16548910,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0x09e5454cdf8be475d003cceef2b27516411d6c3ecbf7fab923722983ff9a7f93,
#  	from_address = "0xd82F794E44215688470084e0fAbA15dE0f9289d1",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:00:46+00:00,
#  	block = 16548911,
#  	value = 13.738209,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xdf46f2dc455d6922ecc06d91bf46309623115d7977b73b66194dc335d5c1ba21,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xE02dF9e3e622DeBdD69fb838bB799E3F168902c5,
#  	time = 2022-03-31 22:01:01+00:00,
#  	block = 16548916,
#  	value = 0.0,
#  	tx_fee = 0.00036067,
#  ), TransactionResponse(
#  	tx_hash = 0x57d21612bdd91015a56b3b9ad267fbb49817a9b151710931d9cba599d586ae66,
#  	from_address = "0x85bCc51A327C082e613F83017CaAd5D0cFF73aA2",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:01:01+00:00,
#  	block = 16548916,
#  	value = 10.79876,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x19ea6573e5ddbe4ce1c3fba8474523b20cd2c66d8956fffbfbe1fb88ea4a27e2,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x0D5BdCE7A037B1A47716DFa2fB5e2235f1FAa0d5",
#  	time = 2022-03-31 22:01:04+00:00,
#  	block = 16548917,
#  	value = 0.08390204,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x48aaae4ef1ce560bd8c477d9ddcd2782c16c841247623ea836782e151a66fa5f,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:01:04+00:00,
#  	block = 16548917,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xdc1a3f8da03b3a3c8f5358f50e2495ec743c1736392c9bcbfd9c6599b0212e79,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:01:04+00:00,
#  	block = 16548917,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0xbff4342db00df63dd34e8caf095ea9b421488575389e45c14b97b67a75d1c8f1,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d,
#  	time = 2022-03-31 22:01:07+00:00,
#  	block = 16548918,
#  	value = 0.0,
#  	tx_fee = 0.00053895,
#  ), TransactionResponse(
#  	tx_hash = 0xa12b720eace1843a2ab77e752445ad3e0a0abf1380af1c87b7403b95b4d50e7e,
#  	from_address = "0x0A75f4768753Da12c570A683C1d440e6f2B6DAf1",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:01:19+00:00,
#  	block = 16548922,
#  	value = 5.624354,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xd21c8cc36999624de2f967815984fbc5dad1c7341a294cf8544ab76c26c3b519,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:01:28+00:00,
#  	block = 16548925,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x7d682967e762ab7b3fa77a1f9ff9e5b0896ef706ca4fa412af45f447adb3c67f,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0xFDEd398B43aEED47CA073d31e0851955CA9bdD3b",
#  	time = 2022-03-31 22:01:28+00:00,
#  	block = 16548925,
#  	value = 0.11353133,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x5d514f12f081f2a954f372587f75365a51c17e7f6f196aefcf743d70547537ee,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:01:31+00:00,
#  	block = 16548926,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0x38da299a38116fe39b7ada0fc3dfc481361e866550c2b927746e3f78b506fa67,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x67ee3Cb086F8a16f34beE3ca72FAD36F7Db929e2",
#  	time = 2022-03-31 22:01:34+00:00,
#  	block = 16548927,
#  	value = 0.0,
#  	tx_fee = 0.00051874,
#  ), TransactionResponse(
#  	tx_hash = 0x60da9263744ffe86c65e64636db79612f2fc9a49f984a9a0f55ce93fee76313e,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c,
#  	time = 2022-03-31 22:01:34+00:00,
#  	block = 16548927,
#  	value = 0.0,
#  	tx_fee = 0.00036091,
#  ), TransactionResponse(
#  	tx_hash = 0xab5f82156adb08564bff0d071d83ecbeba55e8ee8846167a1b70c667745867f8,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:01:34+00:00,
#  	block = 16548927,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xd9085c0840c9e089b76660b92a5de6c3d7ef095087e8e71a3fa45569a4312442,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:01:34+00:00,
#  	block = 16548927,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0xb9fc60b41263472469aaff0f42add891ef6e50cede9ea5ea02014a6c89c15d94,
#  	from_address = "0xD855422e5Fa3F6cf2Ce8910AFb3c7b2848d4694B",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:01:34+00:00,
#  	block = 16548927,
#  	value = 4.9935,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x017c2c9509e85048bcd236870655f8c4c96f5d473a5e1ebfd6f70dcf5906b320,
#  	from_address = "0x3C0EcBB13359F3Ae982853c0BEbd1747D97A3ca3",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:01:49+00:00,
#  	block = 16548932,
#  	value = 4.641789,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x2990cd34959a899e826f3f968cbe4f11083c48360f9da147b3bc5131b04d74dc,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:02:01+00:00,
#  	block = 16548936,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0x6ddb5dfb20242d752f6b1ebbc7296e19250c05294ee569b679516c71007b04eb,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x5e151cA9EfcCCb033a4D99bfEf2Fd6E08742Fa70",
#  	time = 2022-03-31 22:02:01+00:00,
#  	block = 16548936,
#  	value = 0.4995,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x895fd1576d17d90cbdbe36b714421c553506b3caf9d0daf969eb807e2922a593,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:02:01+00:00,
#  	block = 16548936,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x641406f42b18f5762f477262612d44dae140ee1bc098688dcb7b8c0db48e2771,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x66a688099EDde29a2e0FD60D89b01740cAb276B0",
#  	time = 2022-03-31 22:02:04+00:00,
#  	block = 16548937,
#  	value = 0.02330567,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xeadf71326565a4081f2cb11898a221dd037fb1c17ab734ca355113c8f3f8829c,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:02:04+00:00,
#  	block = 16548937,
#  	value = 0.0,
#  	tx_fee = 0.00036103,
#  ), TransactionResponse(
#  	tx_hash = 0x4b11fdbd1d8c9f9677f54f6256676bce7f73d4026b635fd2b5bfee46dd6de93a,
#  	from_address = "0x89AE680B67f3D0cD80054fBc00a5Eb86694D5bCA",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:02:07+00:00,
#  	block = 16548938,
#  	value = 3.3635,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x52f7bba9a6ab544bbe88a0f93f246f94ef0b2665859d4fe0485e9dd059c02fc3,
#  	from_address = "0xB1901C19F4D6d980b101517d516C72A3DEe08485",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:02:22+00:00,
#  	block = 16548943,
#  	value = 2.9113,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x85bed24202e4c03e7680d970fd4c745d88a707d3e0e4a072cdb4c01889ab542e,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x1f9f6a696C6Fd109cD3956F45dC709d2b3902163",
#  	time = 2022-03-31 22:02:31+00:00,
#  	block = 16548946,
#  	value = 0.0,
#  	tx_fee = 0.00038895,
#  ), TransactionResponse(
#  	tx_hash = 0x2c8148e1dd98fadf027dccd7205fe85829ca80ac286979846937a306f40102be,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x4e04D0aDd2f3e6C224bB60c911EDc8971Ba3091f",
#  	time = 2022-03-31 22:02:31+00:00,
#  	block = 16548946,
#  	value = 2.83621817,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xad2b8e9b0c076b5e1bd584e9e6a8015fc257f2f199848c253bdceb6a4ab23219,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:02:31+00:00,
#  	block = 16548946,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x858d5a404c24d80e1cef5aa4b612b8c223fae4f1d1a78757053bcc357993aa95,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:02:31+00:00,
#  	block = 16548946,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xac3ec57f15708c1cb619fa60ce6f69f0a78050ed207b2b01c5abd9a5fd4e4ad4,
#  	from_address = "0x6F52d142da0247c34Ce4E6cA4d4FcA4e30e906ED",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:02:31+00:00,
#  	block = 16548946,
#  	value = 2.56996,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x330f2b5b14a8744160a3d228c016ae9523c9a1edb22888ee47284a303787cf6a,
#  	from_address = "0xcF8f54dDD82667D91C533B5aA8035Be0E05813B1",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:02:49+00:00,
#  	block = 16548952,
#  	value = 2.442107,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x2af2ec73ee5da69be4d70032d1868838bb58876fd33f21fc2175fd1ced9931b5,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x2170Ed0880ac9A755fd29B2688956BD959F933F8,
#  	time = 2022-03-31 22:02:58+00:00,
#  	block = 16548955,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xe2205a8cb4ea5231689a65fa6a5e60f39a5eeabc788a5f7ee1099c9401ec4596,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0xF008fA960AAfa19B47E2e9ff83cD2D5DD5d955c9",
#  	time = 2022-03-31 22:02:58+00:00,
#  	block = 16548955,
#  	value = 0.2605,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xb4af5c2833cb54e586095c9efbaf4266df1df2db9a6630ab2c0a1f85be5acd39,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:03:01+00:00,
#  	block = 16548956,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xde9f2f8e8f1bc5181e56e22f83e674b787bae799d47e3e4d9b57a40386eee427,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:03:01+00:00,
#  	block = 16548956,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x5b44ebf6a96971a5b60e6e45d5044c9be0af5c4373d504284f0339fa59c715cc,
#  	from_address = "0xDa31CB361a60D6A012e741cf908D8F48b5eBC5C7",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:01+00:00,
#  	block = 16548956,
#  	value = 2.3565,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xcbcc7d81f3a46d5acd49d36d1f0d6ba3ed5aec6cf0f16ff65334a2cc0ee4a468,
#  	from_address = "0xd7D8f7f56647B663Af51cFe9E88371690be6c83a",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:13+00:00,
#  	block = 16548960,
#  	value = 1.999895,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x0f769958c8de8002e90ad6fb462acac21eee5a3683c3bc97e119a76488d1c85a,
#  	from_address = "0xf4C909Ed878791cfe58B9Ed368e728307bb116E6",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:19+00:00,
#  	block = 16548962,
#  	value = 1.99845,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xfb4b87cc8ec2053255413b79775b7ce3cc19b159c50b9dfbbc67c5c6ed867e9d,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:03:31+00:00,
#  	block = 16548966,
#  	value = 0.0,
#  	tx_fee = 0.00051091,
#  ), TransactionResponse(
#  	tx_hash = 0x026a71fb29fa2fdebfafdd7738a6e789fb0b5933747579e6f6ac6843a6fd85f6,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x12EC71BC913d0176A0Ed870DdCEE8fA724560C62",
#  	time = 2022-03-31 22:03:31+00:00,
#  	block = 16548966,
#  	value = 0.37237966,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xe13286f7dfda56edfd7374e1d289bf1aa4e9c5a9b37bdff7addcc6b0a41087db,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:03:31+00:00,
#  	block = 16548966,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0x7e9de1e2e888d30d2b2252b12dbbc139692d41125c51dc843dc4e5dbb547e464,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c,
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0xfd379c79777c8850379743b39dc85c42bc11cf3bd5c9f6faca1331f13d33cbe7,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x2859e4544C4bB03966803b044A93563Bd2D0DD4D",
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 0.0,
#  	tx_fee = 0.00053907,
#  ), TransactionResponse(
#  	tx_hash = 0x38a7ddb76426715254dc2fbfca501bd49f101e8c1ff907dd284b8103c731cfc6,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x111111111117dC0aa78b770fA6A738034120C302,
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 0.0,
#  	tx_fee = 0.0003614,
#  ), TransactionResponse(
#  	tx_hash = 0xb2e9a84eef587f071f487d0a949ba48430947870483f8e2d23d1c59a7b66fe02,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xb1a20e2a01b4d671246c94424a39472525a4311e15c6309874f3bfd9aea751d1,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xda4bd16f97ee449c66cc4df07ba656c610bf3fe608f068de27cd7a68c66b1239,
#  	from_address = "0x3b8d18A5e8D141E66f44E459495D218E152c10B5",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:34+00:00,
#  	block = 16548967,
#  	value = 1.99569,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x2fe751bb8a7f8be7e8ec783a0dd2df4e8ba32961bfe34319cad04bed3854cc64,
#  	from_address = "0xd8127cb16944c847c1a31cf572086aB22CF24F0e",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:40+00:00,
#  	block = 16548969,
#  	value = 1.993368,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x86bfdbdcdac0969fc779dda4f870a9accad5ef3868167d3da4cd2b00f9569831,
#  	from_address = "0x3E39e5396249afc047D86247010ED2Bc6FA4b530",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:03:55+00:00,
#  	block = 16548974,
#  	value = 1.714,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xb3fe86429ba1e064751170653ab560445989b5acf0645896983b7528e600e20d,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x1AF3F329e8BE154074D8769D1FFa4eE058B1DBc3,
#  	time = 2022-03-31 22:03:58+00:00,
#  	block = 16548975,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x0172dfd8ed30be55c0a912fac4e828747c668563fe4e882e6243142ffe693391,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x38E99329f4D12904682703605d270ef5E996de4F",
#  	time = 2022-03-31 22:03:58+00:00,
#  	block = 16548975,
#  	value = 0.09317144,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x13f04b658ebae7e6c0a612667bf864f570769d2fdfd8d3b2d96829a1c722e597,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:04:01+00:00,
#  	block = 16548976,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x579524ba77c210d89cd167d58f9ce37da079bbf3f092980d771dedd1c532c239,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:04:01+00:00,
#  	block = 16548976,
#  	value = 0.0,
#  	tx_fee = 0.00036115,
#  ), TransactionResponse(
#  	tx_hash = 0xb75a217367394ea7e2f36091b9c2206e2a6656c8f70e9b8aabb1ba7a1ea1c6dd,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x1CE0c2827e2eF14D5C4f29a091d735A204794041",
#  	time = 2022-03-31 22:04:01+00:00,
#  	block = 16548976,
#  	value = 0.0,
#  	tx_fee = 0.00053871,
#  ), TransactionResponse(
#  	tx_hash = 0x8c5a172ae4a80b070c7009c0bc68a62eb9c94b77b30cc83dbe5aeac0dabf8060,
#  	from_address = "0xd828045886770C3947DcAF29d416fAD6162e2184",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:04:10+00:00,
#  	block = 16548979,
#  	value = 1.6635,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x7030911eaee481f256e675d640e26c00798b2b039f9630306a45b3b5a974c0cc,
#  	from_address = "0x8F3A21ACBa1014D074f77de443aFb2b441aDab0e",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:04:22+00:00,
#  	block = 16548983,
#  	value = 1.499895,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xe3414a379d4765b0270e88bf3a9cc983dab0d90027c7f0401fde913af18abfe1,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xCC42724C6683B7E57334c4E856f4c9965ED682bD,
#  	time = 2022-03-31 22:04:31+00:00,
#  	block = 16548986,
#  	value = 0.0,
#  	tx_fee = 0.00038883,
#  ), TransactionResponse(
#  	tx_hash = 0x452a0271b7084b7e643dfd757a43af06e76bda6635af1eb02a924c51cad19c5a,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x385f8c75Bba00B75c673ec529A69Fee6CFC41005",
#  	time = 2022-03-31 22:04:31+00:00,
#  	block = 16548986,
#  	value = 0.69498933,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xf24f3dd160d3a6f7e01b0e574e2a0a537196189f30b97aef0faebbf93b42ae86,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:04:31+00:00,
#  	block = 16548986,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0xc3aed14a0a12e19d0e8ec11d90a4fde852191344ef83f2e7e865d3ac1e629d0b,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:04:34+00:00,
#  	block = 16548987,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  ), TransactionResponse(
#  	tx_hash = 0xb23921d81f80b9b0a62d45fad7e418103d143ff5504af69040c6f6af6e8dc5af,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x47BEAd2563dCBf3bF2c9407fEa4dC236fAbA485A",
#  	time = 2022-03-31 22:04:34+00:00,
#  	block = 16548987,
#  	value = 0.0,
#  	tx_fee = 0.00055234,
#  ), TransactionResponse(
#  	tx_hash = 0x2acb8542e072343155e27ffd9d6f5bf315230efe678e6471295f3e0ed87aa8cd,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x8AC76a51cc950d9822D68b83fE1Ad97B32Cd580d,
#  	time = 2022-03-31 22:04:34+00:00,
#  	block = 16548987,
#  	value = 0.0,
#  	tx_fee = 0.00053883,
#  ), TransactionResponse(
#  	tx_hash = 0xa9c1195994d85376480a612a70ec3b06853ad685a22401d397385e937eb4cc5a,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82,
#  	time = 2022-03-31 22:04:34+00:00,
#  	block = 16548987,
#  	value = 0.0,
#  	tx_fee = 0.00051139,
#  ), TransactionResponse(
#  	tx_hash = 0x4669c96e7acefa7a752b4a00cc776fee0bb1943b992d592af4f54c0af335cca4,
#  	from_address = "0x3bDa12cbeeaD6081722771E1d1f3Be074fa728A6",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:04:34+00:00,
#  	block = 16548987,
#  	value = 1.49979,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xb61f93a81913954f8afceafb5680a1fb976968cb9773338e5545bd69a92cc523,
#  	from_address = "0xDB905Ad7E66F3EB95b6F643C4BeCA93D25E1F767",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:04:46+00:00,
#  	block = 16548991,
#  	value = 1.39393,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xd29a2c0ea5990573afbc9ee1d93c81703d137edfbe7be78a6d2b8359c638266a,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xfb6115445Bff7b52FeB98650C87f44907E58f802,
#  	time = 2022-03-31 22:04:58+00:00,
#  	block = 16548995,
#  	value = 0.0,
#  	tx_fee = 0.00038895,
#  ), TransactionResponse(
#  	tx_hash = 0x0b2c759d8b624e76894743ba66af7e33214052f63002b9f3b924ca3516962410,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x5615033BAed7a4072844fCA8113418f686ab6291",
#  	time = 2022-03-31 22:05:01+00:00,
#  	block = 16548996,
#  	value = 0.96866033,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xa79ea9b8ada0f54468afff845662c40a4171fd2e127d0ccbb90663d4cfdde07f,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:05:01+00:00,
#  	block = 16548996,
#  	value = 0.0,
#  	tx_fee = 0.00036115,
#  ), TransactionResponse(
#  	tx_hash = 0xbcf0aad5269de929415c31dd0b67d4795a9c15f475f734bfc847dbce2f68f72a,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:05:04+00:00,
#  	block = 16548997,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0x048ef78066691178068366e474c2fcbe7812c9e4bf1874eef97367e36f247edd,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:05:04+00:00,
#  	block = 16548997,
#  	value = 0.0,
#  	tx_fee = 0.00036103,
#  ), TransactionResponse(
#  	tx_hash = 0xb1309fb761e295a737e382d0ec8f6265ca4b68e4092fe14ea09497c7e156bcdd,
#  	from_address = "0x9079527203019711d4F3B91f44C90BE905bC3aA2",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:05:04+00:00,
#  	block = 16548997,
#  	value = 1.348729,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x5ad7155da9ec43d5dab62704a0ac3afecffc3196c553223bc9bf8856774a0b74,
#  	from_address = "0xb769941DF98C32B26D880D2d86d43Eb4373EFbB5",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:05:16+00:00,
#  	block = 16549001,
#  	value = 1.345576,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xdf7de32296c1118a6530eaeaad3beec8cc42d0523a55724020864965ad371369,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x965F527D9159dCe6288a2219DB51fc6Eef120dD1,
#  	time = 2022-03-31 22:05:31+00:00,
#  	block = 16549006,
#  	value = 0.0,
#  	tx_fee = 0.00036067,
#  ), TransactionResponse(
#  	tx_hash = 0xd05e0db7b9114e947a5efda31f38ea9e1df899b0f640c094d95fc35d036fd4c0,
#  	from_address = "0x26d32dA0975d7D24E49524B2d6FF32012F0Deb39",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:05:31+00:00,
#  	block = 16549006,
#  	value = 1.339895,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x27ea4475d9b0d0b632977882f0d97186c9eea2e267616369af241bd6581150a5,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x44A356b495e92e9Cf14ec947eCE1AEeF209b22a2",
#  	time = 2022-03-31 22:05:34+00:00,
#  	block = 16549007,
#  	value = 0.5695,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x9d7e4b280fcbdc1f1c05b18478e811a11aea7e55a3f77f287355d8278e1e00a7,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:05:34+00:00,
#  	block = 16549007,
#  	value = 0.0,
#  	tx_fee = 0.00036127,
#  ), TransactionResponse(
#  	tx_hash = 0xf081f8d05552d470d38bdad9ce907228402c26e58a4b58ec9fb81876502efc4e,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:05:34+00:00,
#  	block = 16549007,
#  	value = 0.0,
#  	tx_fee = 0.00051127,
#  ), TransactionResponse(
#  	tx_hash = 0xe971ed0bc7584c23bd20ba7061030f9ad272182eb58c1cd9bf9b2f27ec827903,
#  	from_address = "0x8364b80126e3C3d4092e3d0069545C95239e014B",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:05:46+00:00,
#  	block = 16549011,
#  	value = 1.2935,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0xb2516b5507b340dd1b939664eede5d5cfe69ed190e0b0419ff89d16b130ca834,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xfb6115445Bff7b52FeB98650C87f44907E58f802,
#  	time = 2022-03-31 22:05:58+00:00,
#  	block = 16549015,
#  	value = 0.0,
#  	tx_fee = 0.00038883,
#  ), TransactionResponse(
#  	tx_hash = 0x941cf8aa27514fe5468e8298c7f2f41de75b537eac16986609d49ad280499ac6,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0xAe30Ba0Af3E31ce6D9DaAc5932DC66C8CcfdF741",
#  	time = 2022-03-31 22:05:58+00:00,
#  	block = 16549015,
#  	value = 0.88394747,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0xaf4a57ff91ad96cbf57cc78e8b5b6a90da2c63ab5bf6bf7bd8127e9cbf9eb781,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:05:58+00:00,
#  	block = 16549015,
#  	value = 0.0,
#  	tx_fee = 0.00036103,
#  ), TransactionResponse(
#  	tx_hash = 0x3939a2a888b4bcf34e45cbea679388733b7e006b367419ca1b3f182d5a8e0a10,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x55d398326f99059fF775485246999027B3197955,
#  	time = 2022-03-31 22:06:01+00:00,
#  	block = 16549016,
#  	value = 0.0,
#  	tx_fee = 0.00051103,
#  ), TransactionResponse(
#  	tx_hash = 0x2572c1fcb720cc0bb8703ab0cac761d626902a226f9e1e9b901d110073b72529,
#  	from_address = "0x5b4eeb67ba2E005658C5C42e439A15cd390b2e58",
#  	to_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	time = 2022-03-31 22:06:01+00:00,
#  	block = 16549016,
#  	value = 1.223587,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x17fef0d16bd1d5cb4d50ec34b461b9618e177bf203307681dcaaa06dd36ae436,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0x070a08BeEF8d36734dD67A491202fF35a6A16d97,
#  	time = 2022-03-31 22:06:34+00:00,
#  	block = 16549027,
#  	value = 0.0,
#  	tx_fee = 0.00038895,
#  ), TransactionResponse(
#  	tx_hash = 0x874fd023328776d0ddd3e9be6159da1c812428a531d307779068545eb92d057f,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = "0x73E09D62A26D24653683A343178Ad5937C1357DD",
#  	time = 2022-03-31 22:06:34+00:00,
#  	block = 16549027,
#  	value = 0.02865852,
#  	tx_fee = 0.00021,
#  ), TransactionResponse(
#  	tx_hash = 0x58744fe26f483b06703b226861826aa2e5299e77b61d2af0621bcef68858e01d,
#  	from_address = 0x8894E0a0c962CB723c1976a4421c95949bE2D4E3,
#  	to_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	time = 2022-03-31 22:06:37+00:00,
#  	block = 16549028,
#  	value = 0.0,
#  	tx_fee = 0.00051115,
#  )]

# %%
pd.DataFrame([t.__dict__ for t in transactions])
# Out:
#                                               tx_hash  \
# 0   0x160848eddc98a0c976c10694c773f818e051e05a9e58...
# 1   0xd5249d30fb4ad27f2b2d31d20dc384df5b0fe5a5f0b9...
# 2   0x6fa4e4e91d8a8ca48308feab31e424c28a5f1cc8a10c...
# 3   0x1b134598df87962a16c5f154790c40febc0796b46f57...
# 4   0x1ab8468064a8fa8cba29be40ac4b61702e6289cdbd07...
# ..                                                ...
# 95  0x3939a2a888b4bcf34e45cbea679388733b7e006b3674...
# 96  0x2572c1fcb720cc0bb8703ab0cac761d626902a226f9e...
# 97  0x17fef0d16bd1d5cb4d50ec34b461b9618e177bf20330...
# 98  0x874fd023328776d0ddd3e9be6159da1c812428a531d3...
# 99  0x58744fe26f483b06703b226861826aa2e5299e77b61d...
#
#                                     from_address  \
# 0     0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 1     0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 2     0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 3     0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 4     0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# ..                                           ...
# 95    0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 96  "0x5b4eeb67ba2E005658C5C42e439A15cd390b2e58"
# 97    0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 98    0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
# 99    0x8894E0a0c962CB723c1976a4421c95949bE2D4E3
#
#                                       to_address                      time  \
# 0   "0x2859e4544C4bB03966803b044A93563Bd2D0DD4D" 2022-03-31 22:00:01+00:00
# 1   "0x7c544aC3EE686BE156Db92CF61cE743E7bB28A36" 2022-03-31 22:00:01+00:00
# 2     0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56 2022-03-31 22:00:01+00:00
# 3     0x55d398326f99059fF775485246999027B3197955 2022-03-31 22:00:04+00:00
# 4     0xfb6115445Bff7b52FeB98650C87f44907E58f802 2022-03-31 22:00:04+00:00
# ..                                           ...                       ...
# 95    0x55d398326f99059fF775485246999027B3197955 2022-03-31 22:06:01+00:00
# 96    0x8894E0a0c962CB723c1976a4421c95949bE2D4E3 2022-03-31 22:06:01+00:00
# 97    0x070a08BeEF8d36734dD67A491202fF35a6A16d97 2022-03-31 22:06:34+00:00
# 98  "0x73E09D62A26D24653683A343178Ad5937C1357DD" 2022-03-31 22:06:34+00:00
# 99    0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56 2022-03-31 22:06:37+00:00
#
#        block     value    tx_fee
# 0   16548896  0.000000  0.000389
# 1   16548896  0.244581  0.000210
# 2   16548896  0.000000  0.000361
# 3   16548897  0.000000  0.000511
# 4   16548897  0.000000  0.000389
# ..       ...       ...       ...
# 95  16549016  0.000000  0.000511
# 96  16549016  1.223587  0.000105
# 97  16549027  0.000000  0.000389
# 98  16549027  0.028659  0.000210
# 99  16549028  0.000000  0.000511
#
# [100 rows x 7 columns]
