# %% [markdown]
# # Assets Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting Assets
#
# Returns list of assets that are used for tagging publications data filtered by query params.
#
# ***Parameters:***
#
# `chain`
# - It is an optional parameter with the filter functionality. The chain can be specified as a string (case insensitive) or an integer (chain id).
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
assets = client.get_assets(chain=56)
assets
# Out:
# [AvailableAsset(
#  	symbol = gals,
#  	chain = 56,
#  	contract = 0x8f7e69bfa676097a046612658dab8fc60fa90a5d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fear,
#  	chain = 56,
#  	contract = 0x9ba6a67a6f3b21705a46b380a1b97373a33da311,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = cor,
#  	chain = 56,
#  	contract = 0x3581a7b7be2ed2edf98710910fd05b0e8545f1db,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fren,
#  	chain = 56,
#  	contract = 0x1f8a1efbf6247139fb9cbdb9d4dea34e3d18c20a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = frf,
#  	chain = 56,
#  	contract = 0x5a29c96fa93ffa8845fb7f8616a03aa85fcc11d6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x6fc015dc3283369125cc31907eef990b8f67a7a1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = uno,
#  	chain = 56,
#  	contract = 0xf9372b1e797ece08ecf5597eba2a73ba61a28e94,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = m,
#  	chain = 56,
#  	contract = 0x558ad2b02ce979ca54f88206ed8597c8c740774e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = palla,
#  	chain = 56,
#  	contract = 0x8f49733210700d38098d7375c221c7d02f700cc8,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x0c01099f3d4c920504e577bd7617f0d7c53cd8df,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = killer,
#  	chain = 56,
#  	contract = 0xe0b1ef69bc4ab4173989c1190f0d77a813f3b726,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x83b325dba77d55644619a4ff29d42ee4487bcf31,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xebf66828c3d2f86e3bd59222bd7570973800c26b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = metal,
#  	chain = 56,
#  	contract = 0xce8fda2f7da85643c2cad1bd299c9c24b01a0963,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x6b81ed499bfe7f4cb79c381892e5ce69c3c9a9df,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x4f0e7a273c7ff13062fa581bee4ffabdae94328f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = inf,
#  	chain = 56,
#  	contract = 0x000000ef379ee7f4c051f4b9af901a9219d9ec5c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = smash,
#  	chain = 56,
#  	contract = 0x3d0e93bfcb8fb46331ea8c98b6ab8c575ab424c3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x86dd49963fe91f0e5bc95d171ff27ea996c0890c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bunny,
#  	chain = 56,
#  	contract = 0xc9849e6fdb743d08faee3e34dd2d1bc69ea11a51,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xa6bf49ab16c2b42a6bc9c6eb531873a53f5e43d7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = jedals,
#  	chain = 56,
#  	contract = 0x50288f36d77d08093809f65b0adf4ded9f5c6236,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gm,
#  	chain = 56,
#  	contract = 0x0b53b5da7d0f275c31a6a182622bdf02474af253,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = crocket,
#  	chain = 56,
#  	contract = 0xfb7d68be68f7d01c98472fdfb62ca2e10c6f6ee1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xmeta,
#  	chain = 56,
#  	contract = 0xb080171c8999c336cc115d4d8224c2de51657a1c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gmfloki,
#  	chain = 56,
#  	contract = 0x7a9a219a23b3a9f748f087b033af397fbf16030c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cds,
#  	chain = 56,
#  	contract = 0x23f07a1c03e7c6d0c88e0e05e79b6e3511073fd5,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lfg,
#  	chain = 56,
#  	contract = 0xae49e74d7ea6a27f1d6f9a95a050f89a068e40fa,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = smc,
#  	chain = 56,
#  	contract = 0x6a6585b7c3def7b8b65c4bc670f2f9713846c9d1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = naxar,
#  	chain = 56,
#  	contract = 0x74d23db8fd35fd20e1964f7197147c8a22d92a8d,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = rat,
#  	chain = 56,
#  	contract = 0x4ea507bf90b2d206bff56999dc76e39e447d2587,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mrxb,
#  	chain = 56,
#  	contract = 0x767b28a30e3a15dcece7bff7a020adfde9d19cf8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bkishu,
#  	chain = 56,
#  	contract = 0x5df2a4e44c25532326d5aad71c19a9976784320f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = m31,
#  	chain = 56,
#  	contract = 0xb46acb1f8d0ff6369c2f00146897aea1dfcf2414,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sct,
#  	chain = 56,
#  	contract = 0x79d8c48da6e3ec769a4d2097a961a9b7f00830be,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xf6e6892325a74383a70570f1ebea9a476483a611,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = omnia,
#  	chain = 56,
#  	contract = 0x7e6a1299ae38b796404ee0d771b9ebc5fa535e7d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = monday,
#  	chain = 56,
#  	contract = 0x407836435a30c7fa62db326d4f2d87bc1a87cc1a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = wtn,
#  	chain = 56,
#  	contract = 0xdc279ddc65ea17382bbf9a141bb71550cdd587b3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xbb8170ad35325522c0026d67584d4fefbd08b750,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zoo,
#  	chain = 56,
#  	contract = 0x1d229b958d5ddfca92146585a8711aecbe56f095,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = charge,
#  	chain = 56,
#  	contract = 0x1c6bc8e962427deb4106ae06a7fa2d715687395c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lte,
#  	chain = 56,
#  	contract = 0x916c3169c0d31bee7cb15f14e9a94eb10603bc13,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ionz,
#  	chain = 56,
#  	contract = 0x7268192a0e5882b21f13fc857cf78299d8e3d75b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x8961bf99c5bb35fc9659620f2ef383e0a24934db,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x579a6277a6c2c63a5b25006f63bce5dc8d9c25e7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lzn,
#  	chain = 56,
#  	contract = 0x291c4e4277f8717e0552d108dbd7f795a9fef016,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x4b8f0bc4e86ea14b0c22d356af927bd7a43ac2c6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x52f6a03a53840c01470f33a0b016e4c3e3dfe796,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cherry,
#  	chain = 56,
#  	contract = 0x487770734490ac571cda3bc06067048ecc5caa4e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cyc,
#  	chain = 56,
#  	contract = 0x810ee35443639348adbbc467b33310d2ab43c168,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = wlbo,
#  	chain = 56,
#  	contract = 0x8b14a1d887d2f91fe8c0c7dd31a454b64df4211c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = anim,
#  	chain = 56,
#  	contract = 0xf99f6e2a220877679552f81a6a5abf83881cd8fb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = duet,
#  	chain = 56,
#  	contract = 0x95ee03e1e2c5c4877f9a298f1c0d6c98698fab7b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = jaws,
#  	chain = 56,
#  	contract = 0xdd97ab35e3c0820215bc85a395e13671d84ccba2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = avr,
#  	chain = 56,
#  	contract = 0x8337b6fe7a3198fb864ffbde97dda88cfdccbd96,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = crx,
#  	chain = 56,
#  	contract = 0x97a30c692ece9c317235d48287d23d358170fc40,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dali,
#  	chain = 56,
#  	contract = 0x5a119762b09ed0bcb3b16075159ae43a62651383,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = atmup,
#  	chain = 56,
#  	contract = 0xd8e4f8b3adc0dc6ccd90efe8b1ed706d398f81bc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = blogger,
#  	chain = 56,
#  	contract = 0x3928a3dd66d142f312e638deee055540fe332d1a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = babymeta,
#  	chain = 56,
#  	contract = 0x30c49441d326677892891b97b34743306bc97934,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = caps,
#  	chain = 56,
#  	contract = 0xffba7529ac181c2ee1844548e6d7061c9a597df4,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = dago,
#  	chain = 56,
#  	contract = 0x658ce4efd3df2aafdf78179fab81347dab87ff83,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dhg,
#  	chain = 56,
#  	contract = 0xbba24300490443bb0e344bf6ec11bac3aa91df72,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dozen,
#  	chain = 56,
#  	contract = 0xc236a71f9633a0be7d97ad68f8c16de6ec46a252,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shack,
#  	chain = 56,
#  	contract = 0xe79a1163a95734ccfbd006cbaaba954f3e846beb,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ixir,
#  	chain = 56,
#  	contract = 0x17179f506b89d80291b581f200f34b17ff172cd3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xa36d5e816a6e72c99a5b53dcaf964af500436d3e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rev3l,
#  	chain = 56,
#  	contract = 0x4ffa6bb42d1a1a6d8e79935ccf1457d55decff3f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fbl,
#  	chain = 56,
#  	contract = 0x393c44a497706dde15996bb0c7bdf691a79de38a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xenox,
#  	chain = 56,
#  	contract = 0x80df74dc3de4477eaee5c3e14348c6bf7fffad87,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = barmy,
#  	chain = 56,
#  	contract = 0xea04cb26b1ed692c5d903f16d0c6d2d027f99a0a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cbs,
#  	chain = 56,
#  	contract = 0x5a9908ec2173bac7423f490bfd2b24ae9cba7115,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vicat,
#  	chain = 56,
#  	contract = 0x3bfad48181c9e88e1dd9c1b48887e33e2653db4d,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = cord,
#  	chain = 56,
#  	contract = 0xa3506a4f978862a296b29816c4e65cf1a6f54aaa,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = corgi,
#  	chain = 56,
#  	contract = 0x450dcf93160a30be156a4600802c91bf64dffd2e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = corx,
#  	chain = 56,
#  	contract = 0x141383cdb8158982fb3469c3e49cc82f8026d968,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = boon,
#  	chain = 56,
#  	contract = 0xecad387080156f27399ca7df2bd70afb8a5ed67d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xdoge,
#  	chain = 56,
#  	contract = 0x4c0415a6e340eccebff58131799c6c4127cc39fa,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = web3,
#  	chain = 56,
#  	contract = 0xf45de5a6d02c4a6e050b90add33ebf0a34d017e0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = comp,
#  	chain = 56,
#  	contract = 0x52ce071bd9b1c4b00a0b92d298c512478cad67e8,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = bbnana,
#  	chain = 56,
#  	contract = 0xa3be3b30fa5302dad5c9874cdb50e220eaadf092,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x99c2383b5932a785ff4ed0017bc16428bb74510e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bbl,
#  	chain = 56,
#  	contract = 0x8800e9902879ac7fb9823086d1749030c9a5eb91,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ympa,
#  	chain = 56,
#  	contract = 0x5f7871433322b9f9795b97801ec3396276d1d056,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zlda,
#  	chain = 56,
#  	contract = 0x26a7546c8f5e5f706cb598caa68134f6ecf8d657,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zenith,
#  	chain = 56,
#  	contract = 0x57c81885faad67fc4de892102f6fead3b9215f6b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tpg,
#  	chain = 56,
#  	contract = 0xc8ae7ded8b33ea0da0d7c7fc6fed35e3c1822be0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cov,
#  	chain = 56,
#  	contract = 0x0f237db17aa4e6de062e6f052bd9c805789b01c3,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = $splusv2,
#  	chain = 56,
#  	contract = 0xf3aef59ea17d3082f368387fff073d5e05874ad9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ci,
#  	chain = 56,
#  	contract = 0xceafc372af7fddccbfd28f10329710e58bb2f970,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = club,
#  	chain = 56,
#  	contract = 0xae01ac36deb43ec2593855e35f5e62dc992d7c95,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xcf958b53ec9340886d72bb4f5f2977e8c2ab64d3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x43a0ee2e4c005277195f409e77919d1b1a5c9c1f,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = bci,
#  	chain = 56,
#  	contract = 0x967da0d87a60e5fe7331156480c3f62ce4016b28,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bbq,
#  	chain = 56,
#  	contract = 0xd9a88f9b7101046786490baf433f0f6ab3d753e2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bleo,
#  	chain = 56,
#  	contract = 0x6421531af54c7b14ea805719035ebf1e3661c44a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x9b314254762d282c3079083ac9e56290b00150c2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dnky,
#  	chain = 56,
#  	contract = 0x32f3145a98a61813af1ab0631a6a81850ceb8cad,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bnbh,
#  	chain = 56,
#  	contract = 0xd25631648e3ad4863332319e8e0d6f2a8ec6f267,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zooshi,
#  	chain = 56,
#  	contract = 0xa060e0c0588d26caba4a0009513337ace50752dd,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gmm,
#  	chain = 56,
#  	contract = 0x5b6bf0c7f989de824677cfbd507d9635965e9cd3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bgov,
#  	chain = 56,
#  	contract = 0xf8e026dc4c0860771f691ecffbbdfe2fa51c77cf,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bmon,
#  	chain = 56,
#  	contract = 0x08ba0619b1e7a582e0bce5bbe9843322c954c340,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bmic,
#  	chain = 56,
#  	contract = 0xf3f5b390f4524a18d9fe75e62c59370a9e4067dc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = btbs,
#  	chain = 56,
#  	contract = 0x6fefd97f328342a8a840546a55fdcfee7542f9a8,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = zoot,
#  	chain = 56,
#  	contract = 0xb3d691125514db7a5be3326af86a72ecdc2cde16,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = bpkr,
#  	chain = 56,
#  	contract = 0xc83c08e4bfb9ab9346aeb233161f706e5654fc02,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = moolah,
#  	chain = 56,
#  	contract = 0xe51bb42f0f6d01b872cdc7e1764d53b2a81cf0af,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bomb,
#  	chain = 56,
#  	contract = 0x522348779dcb2911539e76a1042aa922f9c47ee3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xa50801a5ddf7afe277fa6695895dffa35ed891a7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = skylands,
#  	chain = 56,
#  	contract = 0xfd2150c67fe2c754ba63920adde3b1ca5cc536e8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = txl,
#  	chain = 56,
#  	contract = 0x1ffd0b47127fdd4097e54521c9e2c7f0d66aafc5,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = bscx,
#  	chain = 56,
#  	contract = 0x5ac52ee5b2a633895292ff6d8a89bb9190451587,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = idle,
#  	chain = 56,
#  	contract = 0xc2555f8aef79160a2cb319781f3a5c726b4a8ae6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x25559a80e1f6e0d6db28848003716a555727ca55,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = buffs,
#  	chain = 56,
#  	contract = 0x140b890bf8e2fe3e26fcd516c75728fb20b31c4f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cakebank,
#  	chain = 56,
#  	contract = 0x5f1b95784a033cd6842cf26eb9a9687f91ad9e78,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = brick,
#  	chain = 56,
#  	contract = 0x4e5ab517719a2bdbafefc22c712d7b5bc5f5544e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bfg,
#  	chain = 56,
#  	contract = 0xbb46693ebbea1ac2070e59b4d043b47e2e095f86,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mast,
#  	chain = 56,
#  	contract = 0xb31fd05caf496cef34c945667e90dd89c20e0d09,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x9f403a84db8b5a91e3f6c14a5514906414d1b7f7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = h2e,
#  	chain = 56,
#  	contract = 0x9d97c70fa2c9e7ad1e4e5d843d852772d63a2cea,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ctr,
#  	chain = 56,
#  	contract = 0xd6cce248263ea1e2b8cb765178c944fc16ed0727,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = wana,
#  	chain = 56,
#  	contract = 0x339c72829ab7dd45c3c52f965e7abe358dd8761e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cate,
#  	chain = 56,
#  	contract = 0xe4fae3faa8300810c835970b9187c268f55d998f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = calo,
#  	chain = 56,
#  	contract = 0xb6b91269413b6b99242b1c0bc611031529999999,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x530fea77c0857ea3d1354d3569d819438272426b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = caf,
#  	chain = 56,
#  	contract = 0x3e0e21f8cc8f479c43b05fed9ad7bed07f0eba02,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = chow,
#  	chain = 56,
#  	contract = 0x925f2c11b99c1a4c46606898ee91ed3d450cfeda,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = oni,
#  	chain = 56,
#  	contract = 0xea89199344a492853502a7a699cc4230854451b8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xea255909e46a54d54255219468991c69ca0e659d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gainz,
#  	chain = 56,
#  	contract = 0xb6a41c1facc08aade9257b068041c9b3420693f3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xfr,
#  	chain = 56,
#  	contract = 0x11c3f759c0aae61078ec923af15f2f6fa2d326ce,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cswap,
#  	chain = 56,
#  	contract = 0xe0b0c16038845bed3fcf70304d3e167df81ce225,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = climb,
#  	chain = 56,
#  	contract = 0x2a1d286ed5edad78befd6e0d8beb38791e8cd69d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = deltaf,
#  	chain = 56,
#  	contract = 0x3d06cb9e8fa1c7638a8b3d8d8b8755f1f6b7164b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cb,
#  	chain = 56,
#  	contract = 0xf66a8a197d5cb0e2799d79be115208899332a0ba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dgold,
#  	chain = 56,
#  	contract = 0x9e545b66afad4836656601b0a6c6c4508b33e2c4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dark,
#  	chain = 56,
#  	contract = 0x12fc07081fab7de60987cad8e8dc407b606fb2f8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = chefcake,
#  	chain = 56,
#  	contract = 0x10e24a15bb2b49f6211401af82f0f3ebed05bf71,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = swd,
#  	chain = 56,
#  	contract = 0xb9b280f4277b49d59ac15283b6ae00a90aac5415,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mtbc,
#  	chain = 56,
#  	contract = 0x4f6b30c94f19a0aa3c93079c8f40e76af597aa01,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bananaz,
#  	chain = 56,
#  	contract = 0xce82d1504d22ecf4eab3b356cc0eb63f31e2a38c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dhr,
#  	chain = 56,
#  	contract = 0x9fef6766ecf9e105b2753f7f8968dc8293a69460,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = desire,
#  	chain = 56,
#  	contract = 0xc8846b0877cec21336ba3136208fd02d42ac7b5e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = devia8,
#  	chain = 56,
#  	contract = 0x48a593ffbb06471415d70b66848a82e65cf61d9f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x239d4e702667f106950ab897ba17802b2d15cc3f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dogesx,
#  	chain = 56,
#  	contract = 0xb8bec9f1b1e27ee3435cd77e44b51a06dd7af5eb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dogedash,
#  	chain = 56,
#  	contract = 0x7ae5709c585ccfb3e61ff312ec632c21a5f03f70,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x9680c8cea945816dc0c0d3ea047925181b6bc06b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = defy,
#  	chain = 56,
#  	contract = 0x92c46bef1d87cbaaf68a0d6730bb395a15d0b9e8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = $di,
#  	chain = 56,
#  	contract = 0xe2ebe6e2358720e5baffecd8d06dd505dd4e898f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dep,
#  	chain = 56,
#  	contract = 0x16f99577b259b069a2d1d166e70d349b11b1d325,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x01db446f7c6d20ce1fca421b4397da789fbb21f1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x52ad40132cbdb1446b66b1198fcf68d602127114,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xf0fcd737fce18f95621cc7841ebe0ea6efccf77e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cwt,
#  	chain = 56,
#  	contract = 0x5a726a26edb0df8fd55f03cc30af8a7cea81e78d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cbt,
#  	chain = 56,
#  	contract = 0xd7314a3b4c80e95125c56a3e7eb2d9f87e9e35b6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dsc,
#  	chain = 56,
#  	contract = 0x662cbbeb9872251a795f85648333be0dbfcad653,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dios,
#  	chain = 56,
#  	contract = 0x08eecf5d03bda3df2467f6af46b160c24d931de7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dvdx,
#  	chain = 56,
#  	contract = 0x4b4135a99775368f349b6f904808b648a9948393,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dyt,
#  	chain = 56,
#  	contract = 0x740623d2c797b7d8d1ecb98e9b4afcf99ec31e14,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xa54c7fa856f0dfd5c1fac07bf4bab876663c42e3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bho,
#  	chain = 56,
#  	contract = 0x57d824ecb229c77ef450c91f09c34ee175ceee4e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ftm,
#  	chain = 56,
#  	contract = 0xa4b6e76bba7413b9b4bd83f4e3aa63cc181d869f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = flvr,
#  	chain = 56,
#  	contract = 0xf1a45e52d6d11d0e591d4f18da9d88a4c266b300,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = flurry,
#  	chain = 56,
#  	contract = 0x47c9bcef4fe2dbcdf3abf508f147f1bbe8d4fef2,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x6826ddfd0fefb094f298a85c92fbbfccab0b3e8e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = eifi,
#  	chain = 56,
#  	contract = 0xbbf33a3c83cf86d0965a66e108669d272dfe4214,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ethm,
#  	chain = 56,
#  	contract = 0x0b33542240d6fa323c796749f6d6869fdb7f13ca,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = rush,
#  	chain = 56,
#  	contract = 0xdaee1f8c328ec96c23e8c3a9699fab130c4b29ea,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bone,
#  	chain = 56,
#  	contract = 0x67915e893b68fbc436a288564fff1476b632b009,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x5609366c91d87e6aad1f880999825da4875c2054,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xe679956bb9029a6b8d915e4a47e3d2826b188e62,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bart,
#  	chain = 56,
#  	contract = 0x721692d13fb70f499e8678ede56bb45e4e320f48,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = elm,
#  	chain = 56,
#  	contract = 0xee351682cda9551f8eed6349f6237cab75f8c495,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ecoin,
#  	chain = 56,
#  	contract = 0x7d38315b92d0e7a85b35b2b7fe969b25935619d7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fan,
#  	chain = 56,
#  	contract = 0xb6d48fcef36e19681ee29896b19c1b6cbd1eab1b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = famy,
#  	chain = 56,
#  	contract = 0xa6ea1ae470ed931a7359cecfe50840458e310dd4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x33af7644b1f60c8e8d62689b19d60a5d132164fc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = foa,
#  	chain = 56,
#  	contract = 0xae7300b51a8cd43d5b74be0dd5047715b7017e3e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = hhnft,
#  	chain = 56,
#  	contract = 0x882fd7db274b32dd0361931c406f7cf058bac822,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = wst,
#  	chain = 56,
#  	contract = 0xaadff17d56d80312b392ced903f3e8dbe5c3ece7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fsdcoin,
#  	chain = 56,
#  	contract = 0x680943981ce014a838536fa03b5398ced3ec6f21,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = join,
#  	chain = 56,
#  	contract = 0x003771227d08ac9961b9160b1219fef136546e90,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ga,
#  	chain = 56,
#  	contract = 0x68db7736df537fcf5504dc701d720457c279719d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = aave,
#  	chain = 56,
#  	contract = 0xfb6115445bff7b52feb98650c87f44907e58f802,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = gfnc,
#  	chain = 56,
#  	contract = 0xa47d87704d8fde73a19eab2a2343947ae8537b02,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = grow,
#  	chain = 56,
#  	contract = 0x8cef274596d334ffa10f8976a920ddc81ba6e29b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = happy,
#  	chain = 56,
#  	contract = 0xf5d8a096cccb31b9d7bce5afe812be23e3d4690d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = hord,
#  	chain = 56,
#  	contract = 0x39d4549908e7adcee9b439429294eeb4c65c2c9e,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = hanu,
#  	chain = 56,
#  	contract = 0xdae4f1dca49408288b55250022f67195eff2445a,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = seor,
#  	chain = 56,
#  	contract = 0x800a25741a414ea6e6e2b382435081a479a8cc3c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cst,
#  	chain = 56,
#  	contract = 0x368eb5efdca39126e8e76aae5187166de7c2766c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = byts,
#  	chain = 56,
#  	contract = 0x2bb14cfe8772bd27037b2eeb5bdd3480186be097,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x3c492f060dca62d9ac2454681a2d258235d122d4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x59a82e36c401f4f6f29fe83833d778af38a398a1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mata,
#  	chain = 56,
#  	contract = 0x175facdd947c995ad547f6ad952d26826758a4da,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = oud,
#  	chain = 56,
#  	contract = 0x128ba6da77f67155a7ef6856c33cc714df94f2dc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xrc,
#  	chain = 56,
#  	contract = 0x8f0342bf1063b1d947b0f2cc611301d611ac3487,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = flaflo,
#  	chain = 56,
#  	contract = 0xe477bb2f425c6184243e40174fe276f281b1c8fb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x11ba78277d800502c84c5aed1374ff0a91f19f7e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pan,
#  	chain = 56,
#  	contract = 0x72e3d54293e2912fc66cf4a93625ac8305e3120d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vft,
#  	chain = 56,
#  	contract = 0x14e8bcd053e68a22f239b9e9bead87932465d245,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sbtc,
#  	chain = 56,
#  	contract = 0x258d3bbdb04c08353a7b7ac44b103c4f80c1fe4c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xb24434065fddcdd2f4b31d8cbd6f146119b37ee1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ltnv2,
#  	chain = 56,
#  	contract = 0x167e5455e4c978883b414e7f02c0147eec9a18e9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = her,
#  	chain = 56,
#  	contract = 0x8c18ffd66d943c9b0ad3dc40e2d64638f1e6e1ab,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = jw,
#  	chain = 56,
#  	contract = 0xab785054251db0fc44538f5deebe7507b748b692,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rusd,
#  	chain = 56,
#  	contract = 0x4be8c674c51674beb729832682bba5e5b105b6e2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = skuy,
#  	chain = 56,
#  	contract = 0xe327ce757cd206721e100812e744fc56e4e0a969,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = v$,
#  	chain = 56,
#  	contract = 0x588ff59ee7ba59c33d1e891468a168770e0ae7d8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lecliente,
#  	chain = 56,
#  	contract = 0xaa66a93346e09d140e203eadf22886a21123a1b9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lotto,
#  	chain = 56,
#  	contract = 0xf301c8435d4dfa51641f71b0615add794b52c8e9,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = mafa,
#  	chain = 56,
#  	contract = 0xaf44400a99a9693bf3c2e89b02652babacc5cdb9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = merd,
#  	chain = 56,
#  	contract = 0xa8d3f6d1dea173a262f7ddb74a15c15858cb0113,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = moonarch,
#  	chain = 56,
#  	contract = 0xaf96a19c2dd4a0f6b077d9481fcc8c9102faa141,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sunrise,
#  	chain = 56,
#  	contract = 0xb8170d3ffaf4d284bc2c3c2fecf9ac9038b85d98,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xce5814efff15d53efd8025b9f2006d4d7d640b9b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = income,
#  	chain = 56,
#  	contract = 0xdfcf44e9a6d99717fc04addd57fb667286bb7dc0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = inftee,
#  	chain = 56,
#  	contract = 0xc350caa89eb963d5d6b964324a0a7736d8d65533,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mexi,
#  	chain = 56,
#  	contract = 0x70d8d5b3416888fd05e806195312dd2d9597d50c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = oryx,
#  	chain = 56,
#  	contract = 0x10bb58010cb58e7249099ef2efdffe342928b639,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = miners,
#  	chain = 56,
#  	contract = 0xeb6b00f8c7e1da78fb919c810c30dde95475bdde,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = many,
#  	chain = 56,
#  	contract = 0x3e2ed75f718251fd011312b9e33bf10a4dbfda54,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mdr,
#  	chain = 56,
#  	contract = 0x4505e2ae4f9c512fd2e7e4d99c99dc94e0e93ccb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x47e28936d9c7944d106e46295d87a8e4c1be818c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x7731cc7c8c3802eb3d3575f481e39865c0e92c91,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bnbtiger,
#  	chain = 56,
#  	contract = 0xac68931b666e086e9de380cfdb0fb5704a35dc2d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kdg,
#  	chain = 56,
#  	contract = 0x87a2d9a9a6b2d61b2a57798f1b4b2ddd19458fb6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fruit,
#  	chain = 56,
#  	contract = 0x4ecfb95896660aa7f54003e967e7b283441a2b0a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x49277cc5be56b519901e561096bfd416277b4f6d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nrv,
#  	chain = 56,
#  	contract = 0x42f6f551ae042cbe50c739158b4f0cac0edb9096,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nbtc,
#  	chain = 56,
#  	contract = 0x8f1b3af2d1e56f7c24e80d8626a4b22d269e1792,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xffa99969608fd3c1ddf68b28d7db2e073c33fd91,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xc6fe6c9aa0c0fa525ecc3422ccc89a3bc539ff8c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = plr,
#  	chain = 56,
#  	contract = 0x790cfdc6ab2e0ee45a433aac5434f183be1f6a20,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = fps,
#  	chain = 56,
#  	contract = 0x213503534d927424a5cdf6d580e9fd408be9337a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = indc,
#  	chain = 56,
#  	contract = 0xd3af8e09894d69e937e37eef46df1cbf82b35c81,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = noc,
#  	chain = 56,
#  	contract = 0x0e6457233baa6477f660666624dc29d8e88d9fdf,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nftd,
#  	chain = 56,
#  	contract = 0xac83271abb4ec95386f08ad2b904a46c61777cef,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = pizza,
#  	chain = 56,
#  	contract = 0x2cc26dd730f548dc4ac291ae7d84a0c96980d2cb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sensei,
#  	chain = 56,
#  	contract = 0x495c3b71de97290361c6a7eabebd5c20cd60326c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pln,
#  	chain = 56,
#  	contract = 0x45e027fca0364333bdb725a524cb401531a0f1d1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pofi,
#  	chain = 56,
#  	contract = 0x461f6c9ae13a7dac7055c73fbf8dab529d667041,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mtvx,
#  	chain = 56,
#  	contract = 0xd10672a959ce3bb8939827391fe78762f518f740,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ares,
#  	chain = 56,
#  	contract = 0xf9752a6e8a5e5f5e6eb3ab4e7d8492460fb319f0,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = moonway,
#  	chain = 56,
#  	contract = 0x01cdec00557c39e43ac24898be9878925b8f49d3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pin,
#  	chain = 56,
#  	contract = 0x5e8f6244a57f4f6c47daafc14aa0723d2a9f594c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = fevr,
#  	chain = 56,
#  	contract = 0x82030cdbd9e4b7c5bb0b811a61da6360d69449cc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = punks,
#  	chain = 56,
#  	contract = 0x7189b1391f24f9a90cdb0e12ac0b3f489939921c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = geni,
#  	chain = 56,
#  	contract = 0xc04a23149efdf9a63697f3eb60705147e9f07ffd,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pube,
#  	chain = 56,
#  	contract = 0x3916984fa787d89b648ccd8d60b5ff07e0e8e4f4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x9ec132c19f2c35272de3f81a75d674752d952da8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = r3fi,
#  	chain = 56,
#  	contract = 0x4f55ab914ce8a633c7eb5d8b4d190a96e9ed7f90,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = poodl,
#  	chain = 56,
#  	contract = 0x4a68c250486a116dc8d6a0c5b0677de07cc09c5d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = adam,
#  	chain = 56,
#  	contract = 0x59802ac95f2399c929a096171c1bee93c27dae90,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rbxs,
#  	chain = 56,
#  	contract = 0x11dbf6e897804fbed56cff8ac54fc7bdae50e86a,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = rbx,
#  	chain = 56,
#  	contract = 0xe833dc9b5a21dabc3ed8559858caa92279ac54dc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x63d55ecdebf08f93d0f2d5533035ddccaa997d7a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sycle,
#  	chain = 56,
#  	contract = 0xefef90b7349a48452cdaaea398d600ddb56aef50,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x902c1101a66e697fa776b0b1c2d0d8ffdf866ed6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = babycats,
#  	chain = 56,
#  	contract = 0x1bd5ddcd740f2d13b2255fc325c02509da35c4e4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rvc,
#  	chain = 56,
#  	contract = 0xbcbdecf8e76a5c32dba69de16985882ace1678c6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = quack,
#  	chain = 56,
#  	contract = 0xf5d4158ab289d844a639dd5ccd9d86da7cac2ff4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x1b1d265f8b0577a85e2edf5714c1deb4fe247f45,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kian,
#  	chain = 56,
#  	contract = 0x5ece3f1542c4e1a06767457e4d8286bea772fc41,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = xpx,
#  	chain = 56,
#  	contract = 0x6f3aaf802f57d045efdd2ac9c06d8879305542af,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x8943b6d1677a4addbe5aa58f429e11e856746fba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rewards,
#  	chain = 56,
#  	contract = 0x7b5b3bc6890c1de78fede739c1b02d2e51b1b58c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dks,
#  	chain = 56,
#  	contract = 0x121235cff4c59eec80b14c1d38b44e7de3a18287,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x8776884a06cb51044ed921e7fa964d5fa3a0a16b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = btcmt,
#  	chain = 56,
#  	contract = 0x410a56541bd912f9b60943fcb344f1e3d6f09567,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x48c39bfdc56534113aacd46b450565a3f3ccc02c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rwsc,
#  	chain = 56,
#  	contract = 0xb44c00a75d63eb9c12ec97add741e554ebc2f4bd,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = c-arcade,
#  	chain = 56,
#  	contract = 0x0b8138e73b55e8e4eb8be3ab9862ebfeae262ea5,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xf3630c7eed28514b4c14222bb86e31b53a5da101,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x86bbc9838c3370e0fd570b4ee8087f5aca299977,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x53035e4e14fb3f82c02357b35d5cc0c5b53928b4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rbh,
#  	chain = 56,
#  	contract = 0xd5779f2f9d7d239228e4e78bc78f50768661a081,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vdora,
#  	chain = 56,
#  	contract = 0x3a5fccbdcc2684be588575f063acba78e09aad4a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x1bdfc4b955ab96ab0abf5e76c09ea9ed537055ed,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = adr,
#  	chain = 56,
#  	contract = 0x36f1f32c728c3f330409ec1f0928fa3ab3c8a76f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x92a0d359c87b8f3fe383aa0a42c19d1a2afe6be0,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = sxi,
#  	chain = 56,
#  	contract = 0xa327179d47fad68d09e4501a838daaaf74fabb7c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = safestar,
#  	chain = 56,
#  	contract = 0x3c00f8fcc8791fa78daa4a480095ec7d475781e2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = srt,
#  	chain = 56,
#  	contract = 0x5b6c496cc837ccf003feacc4835e39d5976105a8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cock,
#  	chain = 56,
#  	contract = 0x9fdce4bafccfc9e9dac362be6bb5fb5d2aba3a58,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sabaka inu,
#  	chain = 56,
#  	contract = 0xc30f12cd65f61ded24db6c415c84f999c9704ebc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sme,
#  	chain = 56,
#  	contract = 0x36dbcbca106353d49e1e0e8974492ffb862a0c92,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x36f66d61db3497f7fdba22efd2a251753a95d0e2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = saito,
#  	chain = 56,
#  	contract = 0x3c6dad0475d3a1696b359dc04c99fd401be134da,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = mcontent,
#  	chain = 56,
#  	contract = 0x799e1cf88a236e42b4a87c544a22a94ae95a6910,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shiblite,
#  	chain = 56,
#  	contract = 0x76ef2a25b1ea6eb5dc4d079ae82c767d55b0a99e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = signa,
#  	chain = 56,
#  	contract = 0x7b0e7e40ee4672599f7095d1ddd730b0805195ba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = scb,
#  	chain = 56,
#  	contract = 0x0d36cc179019db9a65aa3b85db59e4bb52df0b12,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = soldier,
#  	chain = 56,
#  	contract = 0x2921872530f53eb8e6fc388676b141ef41ee2d4e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shibsc,
#  	chain = 56,
#  	contract = 0xdf0816cc717216c8b0863af8d4f0fc20bc65d643,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gems,
#  	chain = 56,
#  	contract = 0xdfdec49462f7d3c3b0a48e729f77a0645cdfa7c0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x5e4e8faa1fd9d4c050e00a57089e69c1904ac121,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tengu,
#  	chain = 56,
#  	contract = 0x6f6350d5d347aa8f7e9731756b60b774a7acf95b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = milk,
#  	chain = 56,
#  	contract = 0xbf37f781473f3b50e82c668352984865eac9853f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = crypt,
#  	chain = 56,
#  	contract = 0x9c0c8156b268a4432191a282bdf4287019526cce,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nuts,
#  	chain = 56,
#  	contract = 0x8893d5fa71389673c5c4b9b3cb4ee1ba71207556,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = protocol,
#  	chain = 56,
#  	contract = 0x19586f727a00ba0a2f9d07c17d57af5e16fd55e3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ultra,
#  	chain = 56,
#  	contract = 0x0b3f42481c228f70756dbfa0309d3ddc2a5e0f6a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xb036f689bd98b4bd3bd648fa09a23e54d839a859,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = trade,
#  	chain = 56,
#  	contract = 0x7af173f350d916358af3e218bdf2178494beb748,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = vbusd,
#  	chain = 56,
#  	contract = 0x95c78222b3d6e262426483d42cfa53685a67ab9d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = spl,
#  	chain = 56,
#  	contract = 0x7fc766baf71aba5c7835975bbdf315bf0bed3289,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vfox,
#  	chain = 56,
#  	contract = 0x4d61577d8fd2208a0afb814ea089fdeae19ed202,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = steel,
#  	chain = 56,
#  	contract = 0x9001ee054f1692fef3a48330cb543b6fec6287eb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = stud,
#  	chain = 56,
#  	contract = 0x56900be791fb3c6abf1932df0f20daae6208dbe0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vox,
#  	chain = 56,
#  	contract = 0xc227f8eecc481a8e8baa30a4754b109b81c4dfa4,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = swingby,
#  	chain = 56,
#  	contract = 0x71de20e0c4616e7fcbfdd3f875d568492cbe4739,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = spacetoast,
#  	chain = 56,
#  	contract = 0x623b3a37e06268e99096a56a8a0c1207a024245d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = super,
#  	chain = 56,
#  	contract = 0x51ba0b044d96c3abfca52b64d733603ccc4f0d4d,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x4ca03b31f51b4436e26f6ee335895f3fa290ee5a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = yae,
#  	chain = 56,
#  	contract = 0x4ee438be38f8682abb089f2bfea48851c5e71eaf,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = zoo,
#  	chain = 56,
#  	contract = 0x7ffc1243232da3ac001994208e2002816b57c669,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nugget,
#  	chain = 56,
#  	contract = 0x9519e42a2a150be93b2cd57b37f8724b62aa1bb9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tau,
#  	chain = 56,
#  	contract = 0x8632055b9caeebef7c7dccd95461608ca5378839,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xe7244e92956428a058c37557551ecfdfd54890ac,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bg,
#  	chain = 56,
#  	contract = 0xd04c116c4f02f3cca44b7d4e5209225c8779c8b8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = itamcube,
#  	chain = 56,
#  	contract = 0x9b08f10d8c250714f6485212300a7b72f973f1fd,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = able,
#  	chain = 56,
#  	contract = 0x2136cd209bb3d8e4c008ec2791b5d6790b5e33a9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tex,
#  	chain = 56,
#  	contract = 0x049dd7532148826cde956c7b45fec8c30b514052,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = bfloki,
#  	chain = 56,
#  	contract = 0x308d6b4bded91f99b58bdaafcc1137fb4cfd4ab2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = babyfb,
#  	chain = 56,
#  	contract = 0x112fbe7f60329e9e2d232008e56f94d1582ae3bc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bag,
#  	chain = 56,
#  	contract = 0x7c650f39d777f40120345314ab8009d11f70c972,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = monsta,
#  	chain = 56,
#  	contract = 0x8a5d7fcd4c90421d21d30fcc4435948ac3618b2f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = babypig,
#  	chain = 56,
#  	contract = 0x7b0b4c304b9149b692c1acbc9db4f4a1c17b2b91,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x7ff78e1cab9a2710eb6486ecbf3d94d125039364,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = adat,
#  	chain = 56,
#  	contract = 0xdce6380b9d2d8beac66b0fba2604c51519d24d77,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lkr,
#  	chain = 56,
#  	contract = 0xa5ff48e326958e0ce6fdf9518de561f2b5f57da3,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = mflokiada,
#  	chain = 56,
#  	contract = 0x48cbc7f87c657fea3b297f658a5133a5deef9b04,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xb950e950f11107bb72195c56fe910c76e26fa08e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shop,
#  	chain = 56,
#  	contract = 0x9bb2b75250fc34e16d9503c04781c718b2d467c8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = minisportz,
#  	chain = 56,
#  	contract = 0xd506ee6a2bb483a953eb311e9b7e5719211702d3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = wswap,
#  	chain = 56,
#  	contract = 0xc72cc401122dbdc812ec88a2150aad5a39467401,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = 7pxs,
#  	chain = 56,
#  	contract = 0x82bec5483dbab4305f32b191d76dc6cb020ae76d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = any,
#  	chain = 56,
#  	contract = 0xf68c9df95a18b2a5a5fa1124d79eeeffbad0b6fa,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = asix,
#  	chain = 56,
#  	contract = 0xc98a8ec7a07f1b743e86896a52434c4c6a0dbc42,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rogan,
#  	chain = 56,
#  	contract = 0xe42f8cb4acde0c81202171a3faf7ed14a33aabee,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mizl,
#  	chain = 56,
#  	contract = 0x3c130a3e73962ebd40136e8a6ac27e837a3f2bed,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mgxy,
#  	chain = 56,
#  	contract = 0xd2477ca77c14c4d2335b2b2ba9d9dd0558cc7ee2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gsc,
#  	chain = 56,
#  	contract = 0x639fc0c006bd7050e2c359295b41a79cb28694ba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x6067490d05f3cf2fdffc0e353b1f5fd6e5ccdf70,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kdoge,
#  	chain = 56,
#  	contract = 0xa60dad644be617d4380ef2a03f3075ebbc9d0770,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pts,
#  	chain = 56,
#  	contract = 0xfa53a4778431712af31a11621edee4d0926df1ac,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = memedoge,
#  	chain = 56,
#  	contract = 0xf1761596cc6568c608cff23895075312ed374bf1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nftsol,
#  	chain = 56,
#  	contract = 0x5007ba81fbb85dfcfba8efcd0008e5c4dc6e303d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = megaland,
#  	chain = 56,
#  	contract = 0x7cd8c22d3f4b66230f73d7ffcb48576233c3fe33,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nst,
#  	chain = 56,
#  	contract = 0xf4476e7e0fcbc84ce730fec6749d37383f3ac39e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = niftsy,
#  	chain = 56,
#  	contract = 0x7728cd70b3dd86210e2bd321437f448231b81733,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = olympic doge,
#  	chain = 56,
#  	contract = 0xe8a7da5c28ab1b29c4389b864fa890e225ddd6c8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = aqua,
#  	chain = 56,
#  	contract = 0x72b7d61e8fc8cf971960dd9cfa59b8c829d91991,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = minifloki,
#  	chain = 56,
#  	contract = 0x5ee57424151d7256739a6e3386561f62d9f6eb05,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ogc,
#  	chain = 56,
#  	contract = 0x33d53608167ac3679c0fe9f7a7a725891cf0f471,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lord,
#  	chain = 56,
#  	contract = 0x2daf1a83aa348afbcbc73f63bb5ee3154d9f5776,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pdao,
#  	chain = 56,
#  	contract = 0x1af3b59a839e97e944c65177ab3a024b499133f8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pex,
#  	chain = 56,
#  	contract = 0x2963dcc52549573bbfbe355674724528532c0867,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x78f87d1613b35468455e8379c94e9cc03d2b666f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x13e971de9181eef7a4aeaeaa67552a6a4cc54f43,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nbusd,
#  	chain = 56,
#  	contract = 0xf71b4b8aa71f7923c94c7e20b8a434a4d9368eee,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = veth,
#  	chain = 56,
#  	contract = 0xf508fcd89b8bd15579dc79a6827cb4686a3592c8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x16a7fa783378da47a4f09613296b0b2dd2b08d06,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = elvn,
#  	chain = 56,
#  	contract = 0xe8de5e3689c42729ce53bb950fff2e625ccf23a7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = metapets,
#  	chain = 56,
#  	contract = 0x24ce3d571fbcfd9d81dc0e1a560504636a4d046d,
# ...
#  ),
#  AvailableAsset(
#  	symbol = alto,
#  	chain = 56,
#  	contract = 0xef783d3af83a1f6841200fc9adcffc4c5f968ab2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = arg,
#  	chain = 56,
#  	contract = 0x701d9a068d1eec64fbc10299b9f1b18fbb355ddb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x196dc2421af765c2673fc6093fb1374b28064270,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mfet,
#  	chain = 56,
#  	contract = 0x6d23970ce32cb0f1929bece7c56d71319e1b4f01,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = movon,
#  	chain = 56,
#  	contract = 0xc4901c34cd8fb49107c1cb874eff5caa2eaed7d1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sleepee,
#  	chain = 56,
#  	contract = 0x80cd73badb406ea36b9a7cdeb8df06aefa7e12d9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = megadao,
#  	chain = 56,
#  	contract = 0xf2e4f2c8109530a92a992c9e8d0e75ebf8071e48,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ethax,
#  	chain = 56,
#  	contract = 0x854f7cd3677737241e3eed0dc3d7f33dfaf72bc4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = artk,
#  	chain = 56,
#  	contract = 0xdbe373d9374cee42cdd40754c71cd3f5eded4da7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mfi,
#  	chain = 56,
#  	contract = 0xeb5bb9d14d27f75c787cf7475e7ed00d21dc7279,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = melon,
#  	chain = 56,
#  	contract = 0xb14784b2a56945aed7b8cd41661d68f8b6ccec8b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = gzm,
#  	chain = 56,
#  	contract = 0x9c57cc93411d59e6f15edb2d244e2453de1ee6c2,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xcc63538944863685834e91e9168c9c2fea20320f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = creo,
#  	chain = 56,
#  	contract = 0x9521728bf66a867bc65a93ece4a543d817871eb7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lndlrd,
#  	chain = 56,
#  	contract = 0xd6da6491a6663b1d413715f4fd8edd74a4b47694,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = elonhype,
#  	chain = 56,
#  	contract = 0x7730ac665114c0e343b141daaaeb097197191f8a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kronos,
#  	chain = 56,
#  	contract = 0xbec68a941fecc79e57762e258fd1490f29235d75,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vlk,
#  	chain = 56,
#  	contract = 0x797bb0beea437d2762a755ea911c0046c1284568,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bip,
#  	chain = 56,
#  	contract = 0xf2ba89a6f9670459ed5aeefbd8db52be912228b8,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = mtb,
#  	chain = 56,
#  	contract = 0x2bad52989afc714c653da8e5c47bf794a8f7b11d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = viva,
#  	chain = 56,
#  	contract = 0x32767ca0b39a1261e4ba392a605f7fab37d059c7,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cens,
#  	chain = 56,
#  	contract = 0x9e1fd9ba2590af57f926177850eae1611d447874,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = usdr,
#  	chain = 56,
#  	contract = 0x275194ed61cff8e6ab6f4a5a6ebe63f6de882276,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ibt,
#  	chain = 56,
#  	contract = 0x7dacc2327528a99aa1de0c1f757539a9a2380c04,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = yuse,
#  	chain = 56,
#  	contract = 0x8526ff6bbd8a976127443b1ce451ca1044aa3ce2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = sosamz,
#  	chain = 56,
#  	contract = 0x9cb314d707c7ac43d65b67c0747d4e8cd9162295,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = neuralink,
#  	chain = 56,
#  	contract = 0xc7a081c50076e0e3d9c76bea8ea948e2a6c11017,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shibib,
#  	chain = 56,
#  	contract = 0xb21226a767f255d96163410ff13b010b644df0a6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xc6cb12df4520b7bf83f64c79c585b8462e18b6aa,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x19b60612f9a93359bca835a788a334d4157e675b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = esm,
#  	chain = 56,
#  	contract = 0xa9a2589c2301456de4b100c79753e3b0bdd4a0dd,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = misa,
#  	chain = 56,
#  	contract = 0x934b0633f4874ca9340341ad66ff2f6ce3124b4c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mon,
#  	chain = 56,
#  	contract = 0x52b7c9d984ea17e9ee31159ca3fff3790981b64a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vtg,
#  	chain = 56,
#  	contract = 0x8de5aa37a7c40a53062ead382b8eead3b08a7a46,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tgnb,
#  	chain = 56,
#  	contract = 0x087b005b57c286886e4c6175822929ea42832719,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tkn,
#  	chain = 56,
#  	contract = 0xa79a1b19f2367e80d1859273d16796e713cc87c2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mzt,
#  	chain = 56,
#  	contract = 0x5ef6b5abaa7e9b75fa4daebf0fc722f9aff12b40,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = imv,
#  	chain = 56,
#  	contract = 0x64c5f47e530841684a4eef408e9a4366585b88f9,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = hkc,
#  	chain = 56,
#  	contract = 0xd48d639f72ef29458b72cdc9a47a95fa46101529,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vitc,
#  	chain = 56,
#  	contract = 0x7c3cc93f39f0dbc9e00f96d1fa4ea52e36b3476b,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = openx,
#  	chain = 56,
#  	contract = 0x9929b92f4c743d014c68dfe022d04c8c8fcfa37a,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = radio,
#  	chain = 56,
#  	contract = 0x30807d3b851a31d62415b8bb7af7dca59390434a,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x4efdfe8ffaff109451fc306e0b529b088597dd8d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cage,
#  	chain = 56,
#  	contract = 0x06ebc9c542357e2129d16717cd02c02fbc835d33,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zgd,
#  	chain = 56,
#  	contract = 0xbf27da33a58de2bc6eb1c7dab6cf2e84e825d7dc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = moonshib,
#  	chain = 56,
#  	contract = 0xf751f649d08ddb5ea383487b33653bb26eebbb43,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mbd,
#  	chain = 56,
#  	contract = 0xf899e83e6c6df1a0d4887cf0209193aa97236322,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vzn,
#  	chain = 56,
#  	contract = 0x527810fef739caf5611bcec15f4a1f5d51e9027e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rhobusd,
#  	chain = 56,
#  	contract = 0xb498cac6725c31a586d9ae81e828ad05535b368b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ezi,
#  	chain = 56,
#  	contract = 0xca0c1c12466a57b26850b05a0ba2fb39f9763a0c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = prm,
#  	chain = 56,
#  	contract = 0x2668babeab11780c516b1d3ad02011668aff8aa0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = exos,
#  	chain = 56,
#  	contract = 0x16b8dba442cc9faa40d0dd53f698087546ccf096,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = zeum,
#  	chain = 56,
#  	contract = 0x482e6bd0a178f985818c5dfb9ac77918e8412fba,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = luffy,
#  	chain = 56,
#  	contract = 0x3f6b2d68980db7371d3d0470117393c9262621ea,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = did,
#  	chain = 56,
#  	contract = 0xe409271e955078baa4788428a084fafdaa249c14,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pomo,
#  	chain = 56,
#  	contract = 0x19af9dab517746257dba18fcd74f7df5383bdf1b,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cls,
#  	chain = 56,
#  	contract = 0x8f5f8e30ab8aff4cd4a290b860e6f372c5d1a3f5,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x3a050a1ea4e062d0e4a0c3571d9f65919d9dc1c2,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = cosmic,
#  	chain = 56,
#  	contract = 0x960cc8f437165b7362a34d95d1ec62dd2a940f00,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mca,
#  	chain = 56,
#  	contract = 0xf3dbdf718667874e19ef368721a10409345fc218,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = stay,
#  	chain = 56,
#  	contract = 0x127415d59e508c70a3990175c8267eb9c49b84fc,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bux,
#  	chain = 56,
#  	contract = 0x211ffbe424b90e25a15531ca322adf1559779e45,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x4b3274e8e9892d7c2ea5d43431b1183ee5e63ad5,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mtvp,
#  	chain = 56,
#  	contract = 0x64d2906391a82721bb24925fc16a3eff20c8756e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dlf,
#  	chain = 56,
#  	contract = 0xf595b2400cb13a140fb162b226e4be3a1bfc3606,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = evm,
#  	chain = 56,
#  	contract = 0xdadf16be87e745aa3efc78135d260ea4960b2f92,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = unc,
#  	chain = 56,
#  	contract = 0x81d5791e65e0db42687e2caf205f14a5e550c2af,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = games,
#  	chain = 56,
#  	contract = 0xf300e4f1a193dd047b0c6747ad4e16dedf886297,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = stc,
#  	chain = 56,
#  	contract = 0x4236d8c6cc30ecf6f62d972c3b0074c7fda05f18,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lgo,
#  	chain = 56,
#  	contract = 0x44c663476ecb54487c95e82c5bd05b9694253a9f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dbea,
#  	chain = 56,
#  	contract = 0xa44b2d7805dc7fc24a7e8e38d8efed5078cdf640,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mtvg,
#  	chain = 56,
#  	contract = 0x1453dea8a8adf80faba94d169435e9e5966847e8,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = chex,
#  	chain = 56,
#  	contract = 0x9ce84f6a69986a83d92c324df10bc8e64771030f,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = treasure,
#  	chain = 56,
#  	contract = 0xc0b943b63e605cf8a75c7832c2baf46629f7f762,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tribex,
#  	chain = 56,
#  	contract = 0xc34c85a3d7a84212b6234146773f7939a931a8af,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bnfy,
#  	chain = 56,
#  	contract = 0xd3a3a69c575d81ce8e7cf1298ce760055a5669c1,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = dis,
#  	chain = 56,
#  	contract = 0x57effde2759b68d86c544e88f7977e3314144859,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = race,
#  	chain = 56,
#  	contract = 0x43bda2973141f4b0a17e9c389e2b75dbc8c9fded,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x248c45af3b2f73bc40fa159f2a90ce9cad7a77ba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = crime,
#  	chain = 56,
#  	contract = 0x5efe0d32f7129497cce3e371223f9aa569e023a9,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x33c6005ae9c0355a595583081120c18818eaecd4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = jm,
#  	chain = 56,
#  	contract = 0x388d819724dd6d71760a38f00dc01d310d879771,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = beet,
#  	chain = 56,
#  	contract = 0xcd619a8ec557adb00a7c818a5ac5dfbd9007d3ac,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xfd91fa8fab5ca11569e256fa8844bc2abecc331d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = hotmoon,
#  	chain = 56,
#  	contract = 0xc1357d32bf23fd5fe3280681a36755b6f150442e,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = qua,
#  	chain = 56,
#  	contract = 0xfd0fd32a20532ad690731c2685d77c351015ebba,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = $dcap,
#  	chain = 56,
#  	contract = 0x7ce910a8e811be8cda9a862f799878a96d276e7c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = boxerdoge,
#  	chain = 56,
#  	contract = 0x5c70b22f1e6ab0f1cde92bbbaf18568baf67b13f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = crox,
#  	chain = 56,
#  	contract = 0x2c094f5a7d1146bb93850f629501eb749f6ed491,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x025c9f1146d4d94f8f369b9d98104300a3c8ca23,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = pmlg,
#  	chain = 56,
#  	contract = 0xa14c04dea16798aa8f25b1da583cd5fbbfd6579e,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x227b7cf98108e971a5a78596ba25a06da9961233,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0xe8813e1c7eaf1de10d331ed6c0b210eb36561356,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ,
#  	chain = 56,
#  	contract = 0x071fa11f7516cdeb366f7f7d91da5049f7086185,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = boomshiba,
#  	chain = 56,
#  	contract = 0x14af0e9d51d9fe25c1675cc580409b640286167f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = rants,
#  	chain = 56,
#  	contract = 0x567bbef0efdf53355c569b7aedde4c4f7c008014,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lambo,
#  	chain = 56,
#  	contract = 0x537a7e796a3c212ff82d4b4790973ed5ae288bc0,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bcoin,
#  	chain = 56,
#  	contract = 0x00e1656e45f18ec6747f5a8496fd39b50b38396d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bugg,
#  	chain = 56,
#  	contract = 0x7d62d515ca6dd901fc920e361559fd394eef3d52,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = tknrm,
#  	chain = 56,
#  	contract = 0xd6f97d97edfa1a4ea8be15714386455b19a67524,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = ufo,
#  	chain = 56,
#  	contract = 0xf080a28bcd70cecb4b422d8f6a23a5faa8b2eccb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = uni,
#  	chain = 56,
#  	contract = 0xbf5140a22578168fd562dccf235e5d43a02ce9b1,
#  	is_default = False,
#  ),
#  AvailableAsset(
#  	symbol = kty,
#  	chain = 56,
#  	contract = 0x86296279c147bd40cbe5b353f83cea9e9cc9b7bb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kmon,
#  	chain = 56,
#  	contract = 0xc732b6586a93b6b7cf5fed3470808bc74998224d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lcdp,
#  	chain = 56,
#  	contract = 0x1e19f5f52527700186339da4409bb19fbc622f2c,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lmn,
#  	chain = 56,
#  	contract = 0x7251c7a2155d8fedb42a1dc4333ade589e4d6919,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = lbcc,
#  	chain = 56,
#  	contract = 0x12d76741f56ffde15d0da9865c05089425337aab,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = shbar,
#  	chain = 56,
#  	contract = 0xf3bebb4f2d348e44cc4547cba2f96c214fe5a25a,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = strm,
#  	chain = 56,
#  	contract = 0xc598275452fa319d75ee5f176fd3b8384925b425,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = movey,
#  	chain = 56,
#  	contract = 0x2b511aa476213e9081dd6a59a3739f0cb9d01162,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mhg,
#  	chain = 56,
#  	contract = 0x3025e70f87072e0442767b5cc9cb1f4cdd314bc3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = mu,
#  	chain = 56,
#  	contract = 0x4c2d292d4c72ea7003793d86014941522b821fda,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = memelon,
#  	chain = 56,
#  	contract = 0x273971059e0082aac306a78acc67ac01551b565f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = afit,
#  	chain = 56,
#  	contract = 0x4516bb582f59befcbc945d8c2dac63ef21fba9f6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = aqdc,
#  	chain = 56,
#  	contract = 0x33aa7797ac6cb8b4652b68e33e5add8ad1218a8d,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = valor,
#  	chain = 56,
#  	contract = 0x798ba46ae7fbbb1c430417079a4fb1e1cb960147,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = nsh,
#  	chain = 56,
#  	contract = 0x53f042f3e809d2dcc9492de2dbf05d1da0ef5fbb,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = vault-s,
#  	chain = 56,
#  	contract = 0x7e1cceed4b908303a4262957abd536509e7af54f,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = earn,
#  	chain = 56,
#  	contract = 0x63a18bc38d1101db7f0efcbcbdcbe927a5879039,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = bscgold,
#  	chain = 56,
#  	contract = 0x34195fd824355aec1bdceea97697b35be691bcb3,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = amb,
#  	chain = 56,
#  	contract = 0x95977a9daa14a00258f89a14f75b6e35d5b730d4,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = singh,
#  	chain = 56,
#  	contract = 0x867b96b33b2c13cc8cb78a9aa95420c6cd42c4c6,
#  	is_default = True,
#  ),
#  AvailableAsset(
#  	symbol = kte,
#  	chain = 56,
#  	contract = 0x61fa01129ac0bb124d1c60dc9f735c6c579a858b,
#  	is_default = True,
#  ),
#  ...]

# %%
pd.DataFrame([a.__dict__ for a in assets])
# Out:
#      symbol  chain                                    contract  is_default
# 0      gals     56  0x8f7e69bfa676097a046612658dab8fc60fa90a5d        True
# 1      fear     56  0x9ba6a67a6f3b21705a46b380a1b97373a33da311       False
# 2       cor     56  0x3581a7b7be2ed2edf98710910fd05b0e8545f1db        True
# 3      fren     56  0x1f8a1efbf6247139fb9cbdb9d4dea34e3d18c20a        True
# 4       frf     56  0x5a29c96fa93ffa8845fb7f8616a03aa85fcc11d6        True
# ...     ...    ...                                         ...         ...
# 6403    drf     56  0x89c1af791d7b4cf046dca8fa10a41dd2298a6a3f        True
# 6404    xts     56  0xe0095510a77cf31989e286ba63f321cf28a8ea13        True
# 6405    smg     56  0x3ca994d9f723736381d44388bc8dd1e7ee8c1653        True
# 6406    dfg     56  0xdae7a4aacbbcaf13e9a101a2bf376fcb3931ad27        True
# 6407    myk     56  0xe0c7227fec46bea77d01ddf4cddb680793fd9d54        True
#
# [6408 rows x 4 columns]

# %%
assets = client.get_assets(chain="avax")
assets
# Out:
# [AvailableAsset(
#  	symbol = wsdq,
#  	chain = 43114,
#  	contract = 0xafc4d521df3c0566d61931f81f02f1a525bad04d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdcbs,
#  	chain = 43114,
#  	contract = 0x6145e8a910ae937913426bf32de2b26039728acf,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = eth,
#  	chain = 43114,
#  	contract = 0x8b82a291f83ca07af22120aba21632088fc92931,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = frax,
#  	chain = 43114,
#  	contract = 0xd24c2ad096400b6fbcd2ad8b24e7acbc21a1da64,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = rose,
#  	chain = 43114,
#  	contract = 0x12af5c1a232675f62f405b5812a80e7a6f75d746,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdcso,
#  	chain = 43114,
#  	contract = 0x0950fc1ad509358daead5eb8020a3c7d8b43b9da,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = laika,
#  	chain = 43114,
#  	contract = 0x1ccca1ce62c62f7be95d4a67722a8fdbed6eecb4,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = domi,
#  	chain = 43114,
#  	contract = 0xfc6da929c031162841370af240dec19099861d3b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = alink,
#  	chain = 43114,
#  	contract = 0x191c10aa4af7c30e871e70c95db0e4eb77237530,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = hotcross,
#  	chain = 43114,
#  	contract = 0x2f86508f41310d8d974b76deb3d246c0caa71cf5,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tryb,
#  	chain = 43114,
#  	contract = 0x564a341df6c126f90cf3ecb92120fd7190acb401,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = wet,
#  	chain = 43114,
#  	contract = 0xb1466d4cf0dcfc0bcddcf3500f473cdacb88b56d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sld,
#  	chain = 43114,
#  	contract = 0xad7476c49d3f82a144f4836aacb9b069c188b759,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wavax,
#  	chain = 43114,
#  	contract = 0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = spellp,
#  	chain = 43114,
#  	contract = 0xe7d06bb5079340bfd68bc3f5e52b5f65b01d75cd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tho,
#  	chain = 43114,
#  	contract = 0xae4aa155d2987b454c29450ef4f862cf00907b61,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ptp,
#  	chain = 43114,
#  	contract = 0x22d4002028f537599be9f666d1c4fa138522f9c8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = statik,
#  	chain = 43114,
#  	contract = 0x97d367a5f900f5c9db4370d0d801fc52332244c7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = feed,
#  	chain = 43114,
#  	contract = 0xab592d197acc575d16c3346f4eb70c703f308d1e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = clavis,
#  	chain = 43114,
#  	contract = 0xa5b0f5ef809fd04c9d4320211c711cb34ef812dd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = snx,
#  	chain = 43114,
#  	contract = 0xbec243c995409e6520d7c41e404da5deba4b209b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = stho,
#  	chain = 43114,
#  	contract = 0x63468133ed352e602beb61dd254d6060ad2fe419,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = vso,
#  	chain = 43114,
#  	contract = 0x846d50248baf8b7ceaa9d9b53bfd12d7d7fbb25a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wine,
#  	chain = 43114,
#  	contract = 0xc55036b5348cfb45a932481744645985010d3a44,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sra,
#  	chain = 43114,
#  	contract = 0x862d2e466c28db7961e953083854e19481478842,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kitty,
#  	chain = 43114,
#  	contract = 0x788ae3b5d153d49f8db649aacba1857f744b739e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = comet,
#  	chain = 43114,
#  	contract = 0x2923e182a6e68c0fe4006736a33b32f805703683,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = volt,
#  	chain = 43114,
#  	contract = 0xf5ee578505f4d876fef288dfd9fd5e15e9ea1318,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ime,
#  	chain = 43114,
#  	contract = 0xf891214fdcf9cdaa5fdc42369ee4f27f226adad6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sdog,
#  	chain = 43114,
#  	contract = 0xde9e52f1838951e4d2bb6c59723b003c353979b6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gma,
#  	chain = 43114,
#  	contract = 0x19cfd1a6b1cd236b542b561ed26b32d697e5a77f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = qi,
#  	chain = 43114,
#  	contract = 0x8729438eb15e2c8b576fcc6aecda6a148776c0f5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hshares,
#  	chain = 43114,
#  	contract = 0xfa4b6db72a650601e7bd50a0a9f537c9e98311b2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cat,
#  	chain = 43114,
#  	contract = 0x094bfac9894d2a2a35771d0bd6d2447689190f32,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = icy,
#  	chain = 43114,
#  	contract = 0x78bf833aae77ebf62c21a9a5a6993a691810f2e1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kiki,
#  	chain = 43114,
#  	contract = 0x781c9ca04c0938b981b3383653ab186961ea9084,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = btcp,
#  	chain = 43114,
#  	contract = 0xc1333a2e6f4a50ec20107c19fa73af9e8cc0419b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avtime,
#  	chain = 43114,
#  	contract = 0x3a47868bee0b553183222eea56e82f83addcd133,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ausd,
#  	chain = 43114,
#  	contract = 0x783c08b5f26e3daf8c4681f3bf49844e425b6393,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = piggy,
#  	chain = 43114,
#  	contract = 0x1a877b68bda77d78eea607443ccde667b31b0cdf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = flake,
#  	chain = 43114,
#  	contract = 0x9559873d5b9e0176e923399cbd2863aea1fb19b9,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pshare,
#  	chain = 43114,
#  	contract = 0xa5e2cfe48fe8c4abd682ca2b10fcaafe34b8774c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = val,
#  	chain = 43114,
#  	contract = 0xe0474c15bc7f8213ee5bfb42f9e68b2d6be2e136,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cake,
#  	chain = 43114,
#  	contract = 0x4eb49a2f9a79053866fae806fac95a3ef5b92c05,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kandy,
#  	chain = 43114,
#  	contract = 0x37ded665a387a6f170fb60376b3057f09df6c0ea,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = fort,
#  	chain = 43114,
#  	contract = 0xf6d46849db378ae01d93732585bec2c4480d1fd5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = any,
#  	chain = 43114,
#  	contract = 0xb44a9b6905af7c801311e8f4e76932ee959c663c,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = sherpa,
#  	chain = 43114,
#  	contract = 0xa5e59761ebd4436fa4d20e1a27cba29fb2471fc6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kitty,
#  	chain = 43114,
#  	contract = 0xbca7f1998dc9ffb70b086543a808960a460abca7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sbr,
#  	chain = 43114,
#  	contract = 0x19613fec180746831bdf819e0790f35741040dfd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = blanc,
#  	chain = 43114,
#  	contract = 0xf481eec738c46f675e077ee966a680a19210af11,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = polar,
#  	chain = 43114,
#  	contract = 0x6c1c0319d8ddcb0ffe1a68c5b3829fd361587db4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hat,
#  	chain = 43114,
#  	contract = 0x82fe038ea4b50f9c957da326c412ebd73462077c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hermes,
#  	chain = 43114,
#  	contract = 0xb15f02f9da8cd1f99e9dd375f21dc96d25ddd82c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = don,
#  	chain = 43114,
#  	contract = 0x1db749847c4abb991d8b6032102383e6bfd9b1c7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = idyp,
#  	chain = 43114,
#  	contract = 0xbd100d061e120b2c67a24453cf6368e63f1be056,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = sun,
#  	chain = 43114,
#  	contract = 0xdc05bff771cd5eb1bdc3a76950144ffd8d64efc0,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cnr,
#  	chain = 43114,
#  	contract = 0x8d88e48465f30acfb8dac0b3e35c9d6d7d36abaf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pln,
#  	chain = 43114,
#  	contract = 0x7b2b702706d9b361dfe3f00bd138c0cfda7fb2cf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = icy,
#  	chain = 43114,
#  	contract = 0xe18950c8f3b01f549cfc79dc44c3944fbd43fb76,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = anortis,
#  	chain = 43114,
#  	contract = 0x218ac1bc9ad8c0562988b03263540ec85c462f5a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = loot,
#  	chain = 43114,
#  	contract = 0x7f041ce89a2079873693207653b24c15b5e6a293,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = milk2,
#  	chain = 43114,
#  	contract = 0x721c299e6bf7d6a430d9bea3364ea197314bce09,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mjewel,
#  	chain = 43114,
#  	contract = 0xb5623f774e568fed0259cf1c28a705405dd5967f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mug,
#  	chain = 43114,
#  	contract = 0xf7ed17f0fb2b7c9d3ddbc9f0679b2e1098993e81,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mu,
#  	chain = 43114,
#  	contract = 0xd036414fa2bcbb802691491e323bff1348c5f4ba,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = acta,
#  	chain = 43114,
#  	contract = 0x4636e16444720075db87a0a4fd998b423c2b5456,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avao,
#  	chain = 43114,
#  	contract = 0xecf4e40e564a1de686d89142a0963d908579daaa,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = onion,
#  	chain = 43114,
#  	contract = 0xf6931e67ef0cb20423351a53069719df2ad76e78,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avat,
#  	chain = 43114,
#  	contract = 0x7086c48c997b8597a1692798155b4fcf2cee7f0f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = blizz,
#  	chain = 43114,
#  	contract = 0xa2776a53da0bf664ea34b8efa1c8ab4241a10968,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = frost,
#  	chain = 43114,
#  	contract = 0x320ada89dbfa3a154613d2731c9bc3a4030dba19,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tempo,
#  	chain = 43114,
#  	contract = 0x88a425b738682f58c0ff9fcf2cceb47a361ef4cf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = glac,
#  	chain = 43114,
#  	contract = 0x368098e9deb1961426e8c8554e0d910e189862db,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ghost,
#  	chain = 43114,
#  	contract = 0xa72eab7327e48bde0ff873eaf1d4fecf6036504f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = yts,
#  	chain = 43114,
#  	contract = 0x488f73cddda1de3664775ffd91623637383d6404,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = crown,
#  	chain = 43114,
#  	contract = 0x39912d83acb4a373321387300f4fbe88aa5d6f14,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pint,
#  	chain = 43114,
#  	contract = 0x3af0eb8bcbd4c4c6e26e309c4e47af59bad5fc2f,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = lost,
#  	chain = 43114,
#  	contract = 0x449674b82f05d498e126dd6615a1057a9c088f2c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = orca,
#  	chain = 43114,
#  	contract = 0x8b1d98a91f853218ddbb066f20b8c63e782e2430,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = chad,
#  	chain = 43114,
#  	contract = 0xc16a1b60175d16be6f2ed0ba506ca0e6efba8e08,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = neibr,
#  	chain = 43114,
#  	contract = 0xe337a99fe0ac0f3e01a97167d21082a2bb96326e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = brig,
#  	chain = 43114,
#  	contract = 0xf2cfc11093edb5a2dc7f49e70a3a3a9cd4f4fee4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = blue,
#  	chain = 43114,
#  	contract = 0xc12e249fabe1c5eb7c558e5f50d187687a244e31,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nhct,
#  	chain = 43114,
#  	contract = 0x3ce2fcec09879af073b53bef5f4d04327a1bc032,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dogeally,
#  	chain = 43114,
#  	contract = 0xecee7b9b7aa9eff9f89f1fe7fc77a2e5f6e491ea,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = xptp,
#  	chain = 43114,
#  	contract = 0x060556209e507d30f2167a101bfc6d256ed2f3e1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = leo,
#  	chain = 43114,
#  	contract = 0x945a6869819cdad404dc80647a2085957cb1f28b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bfc,
#  	chain = 43114,
#  	contract = 0x2d5433e9d475c78542dbd0d16d7016b9aab99c1c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = astro,
#  	chain = 43114,
#  	contract = 0xee2e2868272fd6d51d78412d849500753f9dd579,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = higgs,
#  	chain = 43114,
#  	contract = 0xce0052745a182fff07acb9dd834041e5f29319b2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cly,
#  	chain = 43114,
#  	contract = 0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = aura,
#  	chain = 43114,
#  	contract = 0xc8a251142722ceb4a524876b89cc4c0709585818,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nxusd,
#  	chain = 43114,
#  	contract = 0xf14f4ce569cb3679e99d5059909e23b07bd2f387,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = rgk,
#  	chain = 43114,
#  	contract = 0x46fccf447f74ec97a521615fce111118597071f7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = opsy,
#  	chain = 43114,
#  	contract = 0x8dc4d5f5d7caa96b93f7095fa0c7a2aa8264816d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = shibx,
#  	chain = 43114,
#  	contract = 0x440abbf18c54b2782a4917b80a1746d3a2c2cce1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = awool,
#  	chain = 43114,
#  	contract = 0x5ede350e84223fb50775fd91a723f2ca71034cf7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = vpnd,
#  	chain = 43114,
#  	contract = 0x83a283641c6b4df383bcddf807193284c84c5342,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = space,
#  	chain = 43114,
#  	contract = 0x353af195c0d82820c59427bfbd318a49971aae1a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = crnd,
#  	chain = 43114,
#  	contract = 0x2efb4fec95deaab8c199ca5089e0cfd52373f92d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sushi,
#  	chain = 43114,
#  	contract = 0x37b608519f91f70f2eeb0e5ed9af4061722e4f76,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ele,
#  	chain = 43114,
#  	contract = 0xacd7b3d9c10e97d0efa418903c0c7669e702e4c0,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = lvt,
#  	chain = 43114,
#  	contract = 0xd641e62525e830e98cb9d7d033a538a1f092ff34,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = syn,
#  	chain = 43114,
#  	contract = 0x1f1e7c893855525b303f99bdf5c3c05be09ca251,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = png,
#  	chain = 43114,
#  	contract = 0x60781c2586d68229fde47564546784ab3faca982,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wsohm,
#  	chain = 43114,
#  	contract = 0x8cd309e14575203535ef120b5b0ab4dded0c2073,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mimatic,
#  	chain = 43114,
#  	contract = 0x3b55e45fd6bd7d4724f5c47e0d1bcaedd059263e,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = yak,
#  	chain = 43114,
#  	contract = 0x59414b3089ce2af0010e7523dea7e2b35d776ec7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = roco,
#  	chain = 43114,
#  	contract = 0xb2a85c5ecea99187a977ac34303b80acbddfa208,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ape-x,
#  	chain = 43114,
#  	contract = 0xd039c9079ca7f2a87d632a9c0d7cea0137bacfb5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = parr,
#  	chain = 43114,
#  	contract = 0xf10b5a72f0abeb27a5ddba950082e4edff4c825d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = egg,
#  	chain = 43114,
#  	contract = 0x7761e2338b35bceb6bda6ce477ef012bde7ae611,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cycle,
#  	chain = 43114,
#  	contract = 0x81440c939f2c1e34fc7048e518a637205a632a74,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = party,
#  	chain = 43114,
#  	contract = 0x25afd99fcb474d7c336a2971f26966da652a92bc,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = jolly,
#  	chain = 43114,
#  	contract = 0x30ff717fc266f2dcb3adc1af4043f8c517491e66,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mag,
#  	chain = 43114,
#  	contract = 0x1d60109178c48e4a937d8ab71699d8ebb6f7c5de,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dextf,
#  	chain = 43114,
#  	contract = 0x03e8d118a1864c7dc53bf91e007ab7d91f5a06fa,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tundra,
#  	chain = 43114,
#  	contract = 0x21c5402c3b7d40c89cc472c9df5dd7e51bbab1b1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wmemo,
#  	chain = 43114,
#  	contract = 0x0da67235dd5787d67955420c84ca1cecd4e5bb3b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pxt2,
#  	chain = 43114,
#  	contract = 0x9e20af05ab5fed467dfdd5bb5752f7d5410c832e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cram,
#  	chain = 43114,
#  	contract = 0xd2cd7a59aa8f8fdc68d01b1e8a95747730b927d3,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gaia,
#  	chain = 43114,
#  	contract = 0x9f6aedca032b1092e08b848fc9d6f29139370837,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gaj,
#  	chain = 43114,
#  	contract = 0x595c8481c48894771ce8fade54ac6bf59093f9e8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mead,
#  	chain = 43114,
#  	contract = 0x44a45a9baeb63c6ea4860ecf9ac5732c330c4d4e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gdl,
#  	chain = 43114,
#  	contract = 0xd606199557c8ab6f4cc70bd03facc96ca576f142,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = thor,
#  	chain = 43114,
#  	contract = 0x8f47416cae600bccf9530e9f3aeaa06bdd1caa79,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = relay,
#  	chain = 43114,
#  	contract = 0x78c42324016cd91d1827924711563fb66e33a83a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mistel,
#  	chain = 43114,
#  	contract = 0xf3f8772f92028bfb6d641c28bbcf1dbded424767,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hct,
#  	chain = 43114,
#  	contract = 0x45c13620b55c35a5f539d26e88247011eb10fdbd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = husky,
#  	chain = 43114,
#  	contract = 0x65378b697853568da9ff8eab60c13e1ee9f4a654,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = klo,
#  	chain = 43114,
#  	contract = 0xb27c8941a7df8958a1778c0259f76d1f8b711c35,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kishimoto,
#  	chain = 43114,
#  	contract = 0x8b6663725d7e7368b01eefddc16be085e492498e,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = krw,
#  	chain = 43114,
#  	contract = 0xa5acfeca5270bc9768633fbc86caa959b85ec8b7,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mor,
#  	chain = 43114,
#  	contract = 0x87bade473ea0513d4aa7085484aeaa6cb6ebe7e3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = multi,
#  	chain = 43114,
#  	contract = 0x9fb9a33956351cf4fa040f65a13b835a3c8764e3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = uni,
#  	chain = 43114,
#  	contract = 0x8ebaf22b6f053dffeaf46f4dd9efa95d89ba8580,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = vee,
#  	chain = 43114,
#  	contract = 0x3709e8615e02c15b096f8a9b460ccb8ca8194e86,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = 1inch,
#  	chain = 43114,
#  	contract = 0xd501281565bf7789224523144fe5d98e8b28f267,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = fire,
#  	chain = 43114,
#  	contract = 0xfcc6ce74f4cd7edef0c5429bb99d38a3608043a5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = evrt,
#  	chain = 43114,
#  	contract = 0x3aca5545e76746a3fe13ea66b24bc0ebcc51e6b4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = elk,
#  	chain = 43114,
#  	contract = 0xeeeeeb57642040be42185f49c52f7e9b38f8eeee,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = grape,
#  	chain = 43114,
#  	contract = 0x5541d83efad1f281571b343977648b75d95cdac2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = comp,
#  	chain = 43114,
#  	contract = 0xc3048e19e76cb9a3aa9d77d8c03c29fc906e2437,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = smrtr,
#  	chain = 43114,
#  	contract = 0x6d923f688c7ff287dc3a5943caeefc994f97b290,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = akita,
#  	chain = 43114,
#  	contract = 0xcaf5191fc480f43e4df80106c7695eca56e48b18,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = apein,
#  	chain = 43114,
#  	contract = 0x938fe3788222a74924e062120e7bfac829c719fb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = a.bee,
#  	chain = 43114,
#  	contract = 0xb669c71431bc4372140bc35aa1962c4b980ba507,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = xava,
#  	chain = 43114,
#  	contract = 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sonic,
#  	chain = 43114,
#  	contract = 0x4aca0ad6357b918e3d06bb1a0bcc403619177523,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sno,
#  	chain = 43114,
#  	contract = 0xe761afc921ec7ff11df025f8967d08e3daa805a8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = grav,
#  	chain = 43114,
#  	contract = 0x4e720dd3ac5cfe1e1fbde4935f386bb1c66f4642,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = icube,
#  	chain = 43114,
#  	contract = 0x951c8a8dee33bd5039a71e7bd4244d5659cf1517,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = susd,
#  	chain = 43114,
#  	contract = 0xaafd2577fb67366d3c89db0d627c49d769ee2e5d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = seed,
#  	chain = 43114,
#  	contract = 0x37427c72f3534d854ee462d18f42ad5fbe74aa2b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nftd,
#  	chain = 43114,
#  	contract = 0x9e3ca00f2d4a9e5d4f0add0900de5f15050812cf,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = avohminu,
#  	chain = 43114,
#  	contract = 0xa16693fda89e0c4dd9f2324ebd47118b57e6ba34,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ablock,
#  	chain = 43114,
#  	contract = 0xc931f61b1534eb21d8c11b24f3f5ab2471d4ab50,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = craft,
#  	chain = 43114,
#  	contract = 0x8ae8be25c23833e0a01aa200403e826f611f9cd2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = aurora,
#  	chain = 43114,
#  	contract = 0xa9d633a1ac5aa995c5e4f7d915ade1be565a97e8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = teddy,
#  	chain = 43114,
#  	contract = 0x094bd7b2d99711a1486fb94d4395801c6d0fddcc,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tsd,
#  	chain = 43114,
#  	contract = 0x4fbf0429599460d327bd5f55625e30e4fc066095,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = joe,
#  	chain = 43114,
#  	contract = 0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bag,
#  	chain = 43114,
#  	contract = 0xa1144a6a1304bd9cbb16c800f7a867508726566e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = jgn,
#  	chain = 43114,
#  	contract = 0x4e3642603a75528489c2d94f86e9507260d3c5a1,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = yeti,
#  	chain = 43114,
#  	contract = 0x488f73cddda1de3664775ffd91623637383d6404,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = nado,
#  	chain = 43114,
#  	contract = 0xb80323c7aa915cb960b19b5cca1d88a2132f7bd1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bird,
#  	chain = 43114,
#  	contract = 0x4480b4ddfb15fe6518817ef024d8b493aff2db54,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tractor,
#  	chain = 43114,
#  	contract = 0x542fa0b261503333b90fe60c78f2beed16b7b7fd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tus,
#  	chain = 43114,
#  	contract = 0xf693248f96fe03422fea95ac0afbbbc4a8fdd172,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zrx,
#  	chain = 43114,
#  	contract = 0x596fa47043f99a4e0f122243b841e55375cde0d2,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = lf,
#  	chain = 43114,
#  	contract = 0x5684a087c739a2e845f4aaaabf4fbd261edc2be8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = oh,
#  	chain = 43114,
#  	contract = 0x937e077abaea52d3abf879c9b9d3f2ebd15baa21,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = boofi,
#  	chain = 43114,
#  	contract = 0xb00f1ad977a949a3ccc389ca1d1282a2946963b0,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = lyk,
#  	chain = 43114,
#  	contract = 0xb3f52c360201201d366efd2cda4db78e00cb9d5d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pendle,
#  	chain = 43114,
#  	contract = 0xfb98b335551a418cd0737375a2ea0ded62ea213b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = maxi,
#  	chain = 43114,
#  	contract = 0x7c08413cbf02202a1c13643db173f2694e0f73f0,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = maxi,
#  	chain = 43114,
#  	contract = 0x885d748c00a279b67a7749ec6b03301700dd0455,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = opus,
#  	chain = 43114,
#  	contract = 0x76076880e1ebbce597e6e15c47386cd34de4930f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wbnb,
#  	chain = 43114,
#  	contract = 0x264c1383ea520f73dd837f915ef3a732e204a493,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = wheat,
#  	chain = 43114,
#  	contract = 0x1a51686fb42861aa7e38c1cf8868877f43f82aa4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = wiseavax,
#  	chain = 43114,
#  	contract = 0xb86688eb60be8c6fc09afcc32a9cf4b0b6decffd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = time,
#  	chain = 43114,
#  	contract = 0xb54f16fb19478766a268f172c9480f8da1a7c9c3,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = chihua,
#  	chain = 43114,
#  	contract = 0x4735721ed62713e3a141c939f4aa55ca8ad5f66a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mint,
#  	chain = 43114,
#  	contract = 0x7bf4ca9aec25adaaf7278eedbe959d81893e314f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = myak,
#  	chain = 43114,
#  	contract = 0xddaaad7366b455aff8e7c82940c43ceb5829b604,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = xdo,
#  	chain = 43114,
#  	contract = 0x3509f19581afedeff07c53592bc0ca84e4855475,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = avamim,
#  	chain = 43114,
#  	contract = 0xf97d917a0ef1bb6919c36489eb0fd00db41ffba8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = terra,
#  	chain = 43114,
#  	contract = 0x9f87c6c30f4b23c7b51aa7465a9e0a836514700d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cra,
#  	chain = 43114,
#  	contract = 0xa32608e873f9ddef944b24798db69d80bbb4d1ed,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ccc,
#  	chain = 43114,
#  	contract = 0x4939b3313e73ae8546b90e53e998e82274afdbdb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = slush,
#  	chain = 43114,
#  	contract = 0xd197c8b939f199c7d70d030c1931d3c24442df60,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avme,
#  	chain = 43114,
#  	contract = 0x1ecd47ff4d9598f89721a2866bfeb99505a413ed,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = snob,
#  	chain = 43114,
#  	contract = 0xc38f41a296a4493ff429f1238e030924a1542e50,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sb,
#  	chain = 43114,
#  	contract = 0x7d1232b90d3f809a54eeaeebc639c62df8a8942f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zero,
#  	chain = 43114,
#  	contract = 0x008e26068b3eb40b443d3ea88c1ff99b789c10f7,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bjoe,
#  	chain = 43114,
#  	contract = 0xe703214808c3603a9da2609d52bdcf920e0a0edf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = melt,
#  	chain = 43114,
#  	contract = 0x47eb6f7525c1aa999fbc9ee92715f5231eb1241d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dcau,
#  	chain = 43114,
#  	contract = 0x100cc3a819dd3e8573fd2e46d1e66ee866068f30,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dregg,
#  	chain = 43114,
#  	contract = 0x88c090496125b751b4e3ce4d3fdb8e47dd079c57,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = duo,
#  	chain = 43114,
#  	contract = 0xed4102f3a1a24bd4ef1f29b90cd8bf00a540c0c2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gma,
#  	chain = 43114,
#  	contract = 0xb092214663b7cb2e0497825aa4cecd5dbd3a178b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gf,
#  	chain = 43114,
#  	contract = 0x09ad4a1746ab9ecc96bb67d919de3c6b54cc879f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gro,
#  	chain = 43114,
#  	contract = 0x72699ba15cc734f8db874fa9652c8de12093f187,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = hatter,
#  	chain = 43114,
#  	contract = 0x01c5e2a4af2bd9f62c7d55c6105b8a64e6905be5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hlth,
#  	chain = 43114,
#  	contract = 0x0342993a0a3bcff7668578082c3ad17b5277d97d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = hoop,
#  	chain = 43114,
#  	contract = 0x0592af5414f2f8d90a5ae3c25e937804d3965c87,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dyp,
#  	chain = 43114,
#  	contract = 0x961c8c0b1aad0c0b10a51fef6a867e3091bcef17,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = xcrs,
#  	chain = 43114,
#  	contract = 0x70b4ae8eb7bd572fc0eb244cd8021066b3ce7ee4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = xmtl,
#  	chain = 43114,
#  	contract = 0x4c1057455747e3ee5871d374fdd77a304ce10989,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = xslr,
#  	chain = 43114,
#  	contract = 0xe6ee049183b474ecf7704da3f6f555a1dcaf240f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bnb,
#  	chain = 43114,
#  	contract = 0x264c1383ea520f73dd837f915ef3a732e204a493,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = avai,
#  	chain = 43114,
#  	contract = 0x346a59146b9b4a77100d369a3d18e8007a9f46a6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = papa,
#  	chain = 43114,
#  	contract = 0x70b33ebc5544c12691d055b49762d0f8365d99fe,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pefi,
#  	chain = 43114,
#  	contract = 0xe896cdeaac9615145c0ca09c8cd5c25bced6384c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pb,
#  	chain = 43114,
#  	contract = 0x0e75cdb914ddcca683357dd94d26caa39bc14b16,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = plt,
#  	chain = 43114,
#  	contract = 0xecfe536a209e405db19887830b366e397f5b917a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ple,
#  	chain = 43114,
#  	contract = 0x47aa3650cff9930f277d4670db138da818e1a3ca,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = racex,
#  	chain = 43114,
#  	contract = 0x7086e045b78e1e72f741f25231c08d238812cf8a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = rug,
#  	chain = 43114,
#  	contract = 0xb8ef3a190b68175000b74b4160d325fd5024760e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = rugpull,
#  	chain = 43114,
#  	contract = 0x61ecd63e42c27415696e10864d70ecea4aa11289,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = snrw,
#  	chain = 43114,
#  	contract = 0xe677bdc4f5ac7ef7701f4199f25abad34d41fd7f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = aave,
#  	chain = 43114,
#  	contract = 0x63a72806098bd3d9520cc43356dd78afe5d386d9,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = safemoona,
#  	chain = 43114,
#  	contract = 0x4501e37a79cf953116331a105b3644d07b74c0f8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sing,
#  	chain = 43114,
#  	contract = 0xf9a075c9647e91410bf6c402bdf166e1540f67f0,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sl3,
#  	chain = 43114,
#  	contract = 0x2841a8a2ce98a9d21ad8c3b7fc481527569bd7bb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = void,
#  	chain = 43114,
#  	contract = 0x02fe8adc1b58a63ccb1bb8c39930dcedd7cef4db,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = anyan,
#  	chain = 43114,
#  	contract = 0xf54501fbc97d5cb9c8b96480996a397e07516b2e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avapay,
#  	chain = 43114,
#  	contract = 0x3f3fea5dd9b1940c2ee4822d7b7a06f19d58656e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ave,
#  	chain = 43114,
#  	contract = 0x78ea17559b3d2cf85a7f9c2c704eda119db5e6de,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avxl,
#  	chain = 43114,
#  	contract = 0xbee994ad257dcc84672c0c6e6168a4701041f39f,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = avxt,
#  	chain = 43114,
#  	contract = 0x397bbd6a0e41bdf4c3f971731e180db8ad06ebc1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = axial,
#  	chain = 43114,
#  	contract = 0xcf8419a615c57511807236751c0af38db4ba3351,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bamboo,
#  	chain = 43114,
#  	contract = 0x9a928d7dcd8d7e5cb6860b7768ec2d87b8934267,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = blzz,
#  	chain = 43114,
#  	contract = 0x0f34919404a290e71fc6a510cb4a6acb8d764b24,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avax,
#  	chain = 43114,
#  	contract = FvwEAhmxKfeiG8SnEvq42hc6whRyY3EFYAvebMqDNDGCgxN5Z,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = spore,
#  	chain = 43114,
#  	contract = 0x6e7f5c0b9f4432716bdd0a77a3601291b9d9e985,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = storm,
#  	chain = 43114,
#  	contract = 0x6afd5a1ea4b793cc1526d6dc7e99a608b356ef7b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = uma,
#  	chain = 43114,
#  	contract = 0x3bd2b1c7ed8d396dbb98ded3aebb41350a5b2339,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = univ,
#  	chain = 43114,
#  	contract = 0x959b88966fc5b261df8359961357d34f4ee27b4a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nrk,
#  	chain = 43114,
#  	contract = 0x61a47034276eb993e1c5e67bf1375ad0a48f10f6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = akitax,
#  	chain = 43114,
#  	contract = 0xe06fba763c2104db5027f57f6a5be0a0d86308af,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = stomb,
#  	chain = 43114,
#  	contract = 0x9e6832d13b29d0b1c1c3465242681039b31c7a05,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gb,
#  	chain = 43114,
#  	contract = 0x90842eb834cfd2a1db0b1512b254a18e4d396215,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cream,
#  	chain = 43114,
#  	contract = 0xae21d31a6494829a9e4b2b291f4984aae8121757,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = usdc,
#  	chain = 43114,
#  	contract = 0xa7d7079b0fead91f3e65f86e8915cb59c1a4c664,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = more,
#  	chain = 43114,
#  	contract = 0xd9d90f882cddd6063959a9d837b05cb748718a05,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mndl,
#  	chain = 43114,
#  	contract = 0xd3df6106346ac91ce76d1adf291a68581d3fa782,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cshare,
#  	chain = 43114,
#  	contract = 0x155f794b56353533e0afbf76e1b1fc57dfad5bd7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nodec,
#  	chain = 43114,
#  	contract = 0x224db37f1745a2f5d49e06a204ad6a38ba827fa8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kacy,
#  	chain = 43114,
#  	contract = 0xf32398dae246c5f672b52a54e9b413dffcae1a44,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = acn,
#  	chain = 43114,
#  	contract = 0x3b1468a6f1e6030abf31d81337c5d5d73d5ed5c4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = aavaxb,
#  	chain = 43114,
#  	contract = 0x6c6f910a79639dcc94b4feef59ff507c2e843929,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = playmates,
#  	chain = 43114,
#  	contract = 0x490bf3abcab1fb5c88533d850f2a8d6d38298465,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = luna,
#  	chain = 43114,
#  	contract = 0x70928e5b188def72817b7775f0bf6325968e563b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = slot,
#  	chain = 43114,
#  	contract = 0x924157b5dbb387a823719916b25256410a4ad470,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nobel,
#  	chain = 43114,
#  	contract = 0x75ecfc5825dc0f1b346db945d5c463d212cdf2a3,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gton,
#  	chain = 43114,
#  	contract = 0x4e720dd3ac5cfe1e1fbde4935f386bb1c66f4642,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = gem,
#  	chain = 43114,
#  	contract = 0x4d3ddeec55f148b3f8765a2abc00252834ed7e62,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cash,
#  	chain = 43114,
#  	contract = 0x5e15c0a2dd5cf2e78d57bbf8c1a288495dceee77,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = busdbs,
#  	chain = 43114,
#  	contract = 0xa41a6c7e25ddd361343e8cb8cfa579bbe5eedb7a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = isa,
#  	chain = 43114,
#  	contract = 0x3eefb18003d033661f84e48360ebecd181a84709,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = libre,
#  	chain = 43114,
#  	contract = 0x8afa62fa8dde8888405c899d7da077a61a87eed3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = less,
#  	chain = 43114,
#  	contract = 0x4a4f77d74cf5fd4ea4ab71ba79988c055a5c27b2,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = lyd,
#  	chain = 43114,
#  	contract = 0x4c9b4e1ac6f24cde3660d5e4ef1ebf77c710c084,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mage,
#  	chain = 43114,
#  	contract = 0x921f99719eb6c01b4b8f0ba7973a7c24891e740a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mkr,
#  	chain = 43114,
#  	contract = 0x88128fd4b259552a9a1d457f435a6527aab72d42,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mim,
#  	chain = 43114,
#  	contract = 0x130966628846bfd36ff31a822705796e8cb8c18d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mfi,
#  	chain = 43114,
#  	contract = 0x9fda7ceec4c18008096c2fe2b85f05dc300f94d0,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mrfi,
#  	chain = 43114,
#  	contract = 0x05e481b19129b560e921e487adb281e70bdba463,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = olive,
#  	chain = 43114,
#  	contract = 0x617724974218a18769020a70162165a539c07e8a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = onx,
#  	chain = 43114,
#  	contract = 0x3d8f74620857dd8ed6d0da02ceb13fd0ed8ba678,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = rai,
#  	chain = 43114,
#  	contract = 0x97cd1cfe2ed5712660bb6c14053c0ecb031bff7d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = qi,
#  	chain = 43114,
#  	contract = 0xa56f9a54880afbc30cf29bb66d2d9adcdcaeadd6,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = shake,
#  	chain = 43114,
#  	contract = 0xc1d02e488a9ce2481bfdcd797d5373dd2e70a9c2,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = spell,
#  	chain = 43114,
#  	contract = 0xce1bffbd5374dac86a2893119683f4911a2f7814,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = boo,
#  	chain = 43114,
#  	contract = 0xbd83010eb60f12112908774998f65761cf9f6f9a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = grt,
#  	chain = 43114,
#  	contract = 0x8a0cac13c7da965a312f08ea4229c37869e85cb9,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdt,
#  	chain = 43114,
#  	contract = 0xc7198437980c041c805a1edcba50c1ce5db95118,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tngl,
#  	chain = 43114,
#  	contract = 0xd17584633bc8d190e5a14502976dad9640456d6d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ust,
#  	chain = 43114,
#  	contract = 0xb599c3590f42f8f995ecfa0f85d2980b76862fc1,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tok,
#  	chain = 43114,
#  	contract = 0xae9d2385ff2e2951dd4fa061e74c4d3dedd24347,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = swap,
#  	chain = 43114,
#  	contract = 0xc7b5d72c836e718cda8888eaf03707faef675079,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = urqa,
#  	chain = 43114,
#  	contract = 0xbd3936ec8d83a5d4e73eca625ecfa006da8c8f52,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tomb,
#  	chain = 43114,
#  	contract = 0xb84527d59b6ecb96f433029ecc890d4492c5dce1,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = tusd,
#  	chain = 43114,
#  	contract = 0x1c20e891bab6b1727d14da358fae2984ed9b59eb,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = wtf,
#  	chain = 43114,
#  	contract = 0x873801ae2ff12d816db9a7b082f5796bec64c82c,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = woo,
#  	chain = 43114,
#  	contract = 0xabc9547b534519ff73921b1fba6e672b5f58d083,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = wow,
#  	chain = 43114,
#  	contract = 0xa384bc7cdc0a93e686da9e7b8c0807cd040f4e0b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = wbtc,
#  	chain = 43114,
#  	contract = 0x50b7545627a5162f82a992c33b87adc75187b218,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = yfi,
#  	chain = 43114,
#  	contract = 0x9eaac1b23d935365bd7b542fe22ceee2922f52dc,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = anyp,
#  	chain = 43114,
#  	contract = 0x0356ed6caec19d3f353821480ca44bf7db6d713d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = agf,
#  	chain = 43114,
#  	contract = 0xb67a9374da03d4114a6fb8f0e7f2b82b5cb34ee3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ampl,
#  	chain = 43114,
#  	contract = 0x027dbca046ca156de9622cd1e2d907d375e53aa7,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = yay,
#  	chain = 43114,
#  	contract = 0x01c2086facfd7aa38f69a6bd8c91bef3bb5adfca,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bifi,
#  	chain = 43114,
#  	contract = 0xd6070ae98b8069de6b494332d1a1a81b6179d960,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = busd,
#  	chain = 43114,
#  	contract = 0x19860ccb0a68fd4213ab9d8266f7bbf05a8dde98,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bsgg,
#  	chain = 43114,
#  	contract = 0x63682bdc5f875e9bf69e201550658492c9763f89,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = btcbr,
#  	chain = 43114,
#  	contract = 0xb355f4f4cc84a9429a59d5c2b98d77016f7ec482,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bog,
#  	chain = 43114,
#  	contract = 0xb09fe1613fe03e7361319d2a43edc17422f36b09,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ctsi,
#  	chain = 43114,
#  	contract = 0x6b289cceaa8639e3831095d75a3e43520fabf552,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = dai,
#  	chain = 43114,
#  	contract = 0xd586e7f844cea2f87f50152665bcbc2c279d8d70,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = cerby,
#  	chain = 43114,
#  	contract = 0xdef1fac7bf08f173d286bbbdcbeeade695129840,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = link,
#  	chain = 43114,
#  	contract = 0x5947bb275c521040051d82396192181b413227a3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = cook,
#  	chain = 43114,
#  	contract = 0x637afeff75ca669ff92e4570b14d6399a658902f,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bnpl,
#  	chain = 43114,
#  	contract = 0x1263fea931b86f3e8ce8afbf29f66631b7be9347,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = frm,
#  	chain = 43114,
#  	contract = 0xe5caef4af8780e59df925470b050fb23c43ca68c,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = rise,
#  	chain = 43114,
#  	contract = 0xc17c30e98541188614df99239cabd40280810ca3,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = gmx,
#  	chain = 43114,
#  	contract = 0x62edc0692bd897d2295872a9ffcac5425011c661,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdcet,
#  	chain = 43114,
#  	contract = 0xb24ca28d4e2742907115fecda335b40dbda07a4c,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = hec,
#  	chain = 43114,
#  	contract = 0xc7f4debc8072e23fe9259a5c0398326d8efb7f5c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = usdtbs,
#  	chain = 43114,
#  	contract = 0xa67bcc0d06d7d13a13a2ae30bf30f1b434f5a28b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = sol,
#  	chain = 43114,
#  	contract = 0xfe6b19286885a4f7f55adad09c3cd1f906d2478f,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = cake,
#  	chain = 43114,
#  	contract = 0x98a4d09036cc5337810096b1d004109686e56afc,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = hon,
#  	chain = 43114,
#  	contract = 0xed2b42d3c9c6e97e11755bb37df29b6375ede3eb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = knc,
#  	chain = 43114,
#  	contract = 0x39fc9e94caeacb435842fadedecb783589f50f5f,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = whirl,
#  	chain = 43114,
#  	contract = 0xd806a4a473e44578796898a4c546f575d7247b2b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = imx,
#  	chain = 43114,
#  	contract = 0xea6887e4a9cda1b77e70129e5fba830cdb5cddef,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = insur,
#  	chain = 43114,
#  	contract = 0x544c42fbb96b39b21df61cf322b5edc285ee7429,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = dsla,
#  	chain = 43114,
#  	contract = 0xd7c295e399ca928a3a14b01d760e794f1adf8990,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = set,
#  	chain = 43114,
#  	contract = 0x37d87e316cb4e35163881fdb6c6bc0cdba91dc0a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = liqr,
#  	chain = 43114,
#  	contract = 0x33333ee26a7d02e41c33828b42fb1e0889143477,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = weth,
#  	chain = 43114,
#  	contract = 0x49d5c2bdffac6ce2bfdb6640f4f80f226bc10bab,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bat,
#  	chain = 43114,
#  	contract = 0x98443b96ea4b0858fdf3219cd13e98c7a4690588,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = abr,
#  	chain = 43114,
#  	contract = 0xafc43610c7840b20b90caaf93759be5b54b291c9,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdtso,
#  	chain = 43114,
#  	contract = 0xf0ff231e3f1a50f83136717f287adab862f89431,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdcpo,
#  	chain = 43114,
#  	contract = 0x543672e9cbec728cbba9c3ccd99ed80ac3607fa8,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ooe,
#  	chain = 43114,
#  	contract = 0x0ebd9537a25f56713e34c45b38f421a1e7191469,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = fxs,
#  	chain = 43114,
#  	contract = 0x214db107654ff987ad859f34125307783fc8e387,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = nido,
#  	chain = 43114,
#  	contract = 0x4e2e489237298ab0208909bfb5131477583b118f,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = start,
#  	chain = 43114,
#  	contract = 0xf44fb887334fa17d2c5c0f970b5d320ab53ed557,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = sure,
#  	chain = 43114,
#  	contract = 0x5fc17416925789e0852fbfcd81c490ca4abc51f9,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = usdc,
#  	chain = 43114,
#  	contract = 0xb97ef9ef8734c71904d8002f8b6bc66dd9c48a6e,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = digits,
#  	chain = 43114,
#  	contract = 0x18e2269f98db2eda3cfc06e6cca384b291e553d9,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = swapxi,
#  	chain = 43114,
#  	contract = 0x312ee43df66d1fd1ea28e5b28f355da84dca13c2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = cds,
#  	chain = 43114,
#  	contract = 0x23f07a1c03e7c6d0c88e0e05e79b6e3511073fd5,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = oddz,
#  	chain = 43114,
#  	contract = 0xb0a6e056b587d0a85640b39b1cb44086f7a26a1e,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bribe,
#  	chain = 43114,
#  	contract = 0xce2fbed816e320258161ced52c2d0cebcdfd8136,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ftomb,
#  	chain = 43114,
#  	contract = 0x7dfce792c83f283ecfe7ea7ed308f9b891073540,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = milk,
#  	chain = 43114,
#  	contract = 0x4d81911f0e30d2e12dcc954091701b39dc59e34a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = flot,
#  	chain = 43114,
#  	contract = 0x155dbbb7ce079f7b8ecfff9688adf6e6efb69a24,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = haku,
#  	chain = 43114,
#  	contract = 0x695fa794d59106cebd40ab5f5ca19f458c723829,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zshare,
#  	chain = 43114,
#  	contract = 0x12c48230729b4c6d2c34e6c8264ef8e484435b74,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = strz,
#  	chain = 43114,
#  	contract = 0x1d67454f6b393542290a7bbeea32c66148909b34,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = $nodac,
#  	chain = 43114,
#  	contract = 0x803e78269f7f013b7d13ba13243be10c66418a70,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ufarm,
#  	chain = 43114,
#  	contract = 0xd60effed653f3f1b69047f2d2dc4e808a548767b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = acre,
#  	chain = 43114,
#  	contract = 0x00ee200df31b869a321b10400da10b561f3ee60d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = savax,
#  	chain = 43114,
#  	contract = 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = smrt,
#  	chain = 43114,
#  	contract = 0xcc2f1d827b18321254223df4e84de399d9ff116c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gem,
#  	chain = 43114,
#  	contract = 0xdebb1d6a2196f2335ad51fbde7ca587205889360,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ydr,
#  	chain = 43114,
#  	contract = 0xf03dccaec9a28200a6708c686cf0b8bf26ddc356,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = radi,
#  	chain = 43114,
#  	contract = 0x9c5bbb5169b66773167d86818b3e149a4c7e1d1a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = businesses,
#  	chain = 43114,
#  	contract = 0x15c841043e13ffaa9a99fabea236d40f45615623,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = fief,
#  	chain = 43114,
#  	contract = 0xea068fba19ce95f12d252ad8cb2939225c4ea02d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gohm,
#  	chain = 43114,
#  	contract = 0x321e7092a180bb43555132ec53aaa65a5bf84251,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bridge,
#  	chain = 43114,
#  	contract = 0xc0367f9b1f84ca8de127226ac2a994ea4bf1e41b,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = o3,
#  	chain = 43114,
#  	contract = 0xee9801669c6138e84bd50deb500827b776777d28,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = north,
#  	chain = 43114,
#  	contract = 0xd0755413bfe2e08db6be72761cdd56d77d4b60f1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zabu,
#  	chain = 43114,
#  	contract = 0xdd453dbd253fa4e5e745047d93667ce9da93bbcf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pole,
#  	chain = 43114,
#  	contract = 0x65069e550c5526c029dc9135edd02f6683859ac1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = pizza,
#  	chain = 43114,
#  	contract = 0x6121191018baf067c6dc6b18d42329447a164f05,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = h2o,
#  	chain = 43114,
#  	contract = 0x026187bdbc6b751003517bcb30ac7817d5b766f8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mito,
#  	chain = 43114,
#  	contract = 0x96084fd213088e5a0d686fc7778f6d42974fe1d6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = snoshare,
#  	chain = 43114,
#  	contract = 0xe7a102fbc8ab3581d62830ddb599eccaae5e7875,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bava,
#  	chain = 43114,
#  	contract = 0xe19a1684873fab5fb694cfd06607100a632ff21c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sno,
#  	chain = 43114,
#  	contract = 0x1fe4869f2c5181b9cd780a7e16194fa2c4c4293d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kshare,
#  	chain = 43114,
#  	contract = 0x94d649e017625de1aa04733aa046de0161df18ef,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = $alpha,
#  	chain = 43114,
#  	contract = 0x325a98f258a5732c7b06555603f6af5bc1c17f0a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = king,
#  	chain = 43114,
#  	contract = 0xf3ec49acb3084618121741e4bbb20996d383e9b2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zilla,
#  	chain = 43114,
#  	contract = 0xbfb8dd604b903f30da21354ab41b91de3f1c94e5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = onston,
#  	chain = 43114,
#  	contract = 0x72bc9d71dd9ad563f52270c6ce5fb30f617c7a1d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = elxr,
#  	chain = 43114,
#  	contract = 0x2d63bf11948413a53930f5155a5ad8a1c887c18b,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = $caesar,
#  	chain = 43114,
#  	contract = 0xeddef578a930ddc6f8ceef10f4b00829c54686c2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zshare,
#  	chain = 43114,
#  	contract = 0x82aadcbaad8357644c090a847d3c6a926726c5d5,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = avaxd,
#  	chain = 43114,
#  	contract = 0x1aa76d4a622adaa89c443047c0e5955d1b575407,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = metag,
#  	chain = 43114,
#  	contract = 0x2b0b320b47d8e0dd0e4477cf90c307c7ed984ad2,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ethp,
#  	chain = 43114,
#  	contract = 0x2b3a6972a3450697c64a0b50ef0d859dbe657b77,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = fuku,
#  	chain = 43114,
#  	contract = 0x685b63cfe0179b3efb70a01dcb1d648549aa192d,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bnb,
#  	chain = 43114,
#  	contract = 0x442f7f22b1ee2c842beaff52880d4573e9201158,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = nfsg,
#  	chain = 43114,
#  	contract = 0xf69c2fcd9128d49dfa22348c69177f9380438eb8,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dep,
#  	chain = 43114,
#  	contract = 0xd4d026322c88c2d49942a75dff920fcfbc5614c1,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = dune,
#  	chain = 43114,
#  	contract = 0x314f3bee25e49ea4bcea9a3d1321c74c95f10eab,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = gold,
#  	chain = 43114,
#  	contract = 0x2d052048fe7e4f59277e5e5ed5d21d35419fe747,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = vtx,
#  	chain = 43114,
#  	contract = 0x5817d4f0b62a59b17f75207da1848c2ce75e7af4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = apeu,
#  	chain = 43114,
#  	contract = 0x6b0d2a3c37d551963275bb104f045f6a68ab6374,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = burn,
#  	chain = 43114,
#  	contract = 0x2f4fc16308be09e7611a047b9576881eb5298dd6,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nrgy,
#  	chain = 43114,
#  	contract = 0xecc5c2015a9a5320bcbb08ee445d2cf374f3ac14,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ecd,
#  	chain = 43114,
#  	contract = 0xeb8343d5284caec921f035207ca94db6baaacbcd,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = rbx,
#  	chain = 43114,
#  	contract = 0x94960952876e3ed6a7760b198354fcc5319a406a,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = zeus,
#  	chain = 43114,
#  	contract = 0x4156f18bf7c1ef04248632c66aa119de152d8f2e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = albt,
#  	chain = 43114,
#  	contract = 0x9e037de681cafa6e661e6108ed9c2bd1aa567ecd,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = army,
#  	chain = 43114,
#  	contract = 0xb323c7f46f7f1ca0215553e794f7407c2fa71eeb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dfiat,
#  	chain = 43114,
#  	contract = 0xafe3d2a31231230875dee1fa1eef14a412443d22,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = rides,
#  	chain = 43114,
#  	contract = 0x73f2af605ea8a3d8410b83ee05b8d6fc0da1aca4,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = afm,
#  	chain = 43114,
#  	contract = 0x431289cb3a2ec0875351e33767e175c816c73b3a,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = alot,
#  	chain = 43114,
#  	contract = 0x093783055f9047c2bff99c4e414501f8a147bc69,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = usdt,
#  	chain = 43114,
#  	contract = 0xc7198437980c041c805a1edcba50c1ce5db95118,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = dino,
#  	chain = 43114,
#  	contract = 0x8d8db824bafdb617646e80360509274909c48127,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = asnd,
#  	chain = 43114,
#  	contract = 0xfd0c58f03c83d6960bb9dbfd45076d78df2f095d,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = maticpo,
#  	chain = 43114,
#  	contract = 0xf2f13f0b7008ab2fa4a2418f4ccc3684e49d20eb,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = money,
#  	chain = 43114,
#  	contract = 0x0f577433bf59560ef2a79c124e9ff99fca258948,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = bios,
#  	chain = 43114,
#  	contract = 0xd7783a275e53fc6746dedfbad4a06059937502a4,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = fly,
#  	chain = 43114,
#  	contract = 0x78ea3fef1c1f07348199bf44f45b803b9b0dbe28,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = nnt,
#  	chain = 43114,
#  	contract = 0x771c01e1917b5ab5b791f7b96f0cd69e22f6dbcf,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = antg,
#  	chain = 43114,
#  	contract = 0xca1068444196cdfe676fd15a29f35e502580a69e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = deg,
#  	chain = 43114,
#  	contract = 0x9f285507ea5b4f33822ca7abb5ec8953ce37a645,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = tic,
#  	chain = 43114,
#  	contract = 0x75739a693459f33b1fbcc02099eea3ebcf150cbe,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = mead,
#  	chain = 43114,
#  	contract = 0xd21cdca47fa45a0a51eec030e27af390ab3aa489,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ausdt,
#  	chain = 43114,
#  	contract = 0x6ab707aca953edaefbc4fd23ba73294241490620,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = adai,
#  	chain = 43114,
#  	contract = 0x82e64f49ed5ec1bc6e43dad4fc8af9bb3a2312ee,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = aweth,
#  	chain = 43114,
#  	contract = 0xe50fa9b3c56ffb159cb0fca61f5c9d750e8128c8,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = banana,
#  	chain = 43114,
#  	contract = 0xeacd4f4d93527cb5d0cdfe5930d612ccfd5af436,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = ausdc,
#  	chain = 43114,
#  	contract = 0x625e7708f30ca75bfd92586e17077590c60eb4cd,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = awbtc,
#  	chain = 43114,
#  	contract = 0x078f358208685046a11c85e8ad32895ded33a249,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = bag,
#  	chain = 43114,
#  	contract = 0x2dee42737d769f7444f8e0c0365e0ee1f992a88c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = stg,
#  	chain = 43114,
#  	contract = 0x2f6f07cdcf3588944bf4c42ac74ff24bf56e7590,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = oto,
#  	chain = 43114,
#  	contract = 0x3e5a9f09923936427ad6e487b24e23a862fcf6b7,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = beta,
#  	chain = 43114,
#  	contract = 0x511d35c52a3c244e7b8bd92c0c297755fbd89212,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mind,
#  	chain = 43114,
#  	contract = 0x9867cc2419fb317e986a648e02cf7c35aa87a336,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = jpeg,
#  	chain = 43114,
#  	contract = 0x6241af3817db48a7f9e19fd9446d78e50936d275,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = snowy,
#  	chain = 43114,
#  	contract = 0x6da767394f079c1524b3e797d2110c23c3ecf322,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = favax,
#  	chain = 43114,
#  	contract = 0xf9a49321d3d34cf94c4abd1957c219572a646692,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = smrt,
#  	chain = 43114,
#  	contract = 0x712b05710bcfe9c9b1df08d0f846f42c3d457f3e,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = kdao,
#  	chain = 43114,
#  	contract = 0x29debf83eb8bc91ce9a13ac7e42d37e6e2abb480,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = zoo,
#  	chain = 43114,
#  	contract = 0x1b88d7ad51626044ec62ef9803ea264da4442f32,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = ncash,
#  	chain = 43114,
#  	contract = 0xc69eba65e87889f0805db717af06797055a0ba07,
#  	is_default = False,
#  ), AvailableAsset(
#  	symbol = mobl,
#  	chain = 43114,
#  	contract = 0xae85d5aa526b1ecc5e90e466cbd2bdec22c606ff,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = suv,
#  	chain = 43114,
#  	contract = 0xfd4a382823145b1c381b769ed53bc0f2b93c82a1,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = eths,
#  	chain = 43114,
#  	contract = 0x1efe6a8af01920912f0b4f7f26fc16e294664c4c,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = sin,
#  	chain = 43114,
#  	contract = 0x23ba4272a5c5b5641c751521d57e3413c6703131,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = crystal,
#  	chain = 43114,
#  	contract = 0x04b9da42306b023f3572e106b11d82aad9d32ebb,
#  	is_default = True,
#  ), AvailableAsset(
#  	symbol = alpha,
#  	chain = 43114,
#  	contract = 0x2147efff675e4a4ee1c2f918d181cdbd7a8e208f,
#  	is_default = False,
#  )]

# %%
pd.DataFrame([a.__dict__ for a in assets])
# Out:
#      symbol  chain                                    contract  is_default
# 0      gals     56  0x8f7e69bfa676097a046612658dab8fc60fa90a5d        True
# 1      fear     56  0x9ba6a67a6f3b21705a46b380a1b97373a33da311       False
# 2       cor     56  0x3581a7b7be2ed2edf98710910fd05b0e8545f1db        True
# 3      fren     56  0x1f8a1efbf6247139fb9cbdb9d4dea34e3d18c20a        True
# 4       frf     56  0x5a29c96fa93ffa8845fb7f8616a03aa85fcc11d6        True
# ...     ...    ...                                         ...         ...
# 6403    drf     56  0x89c1af791d7b4cf046dca8fa10a41dd2298a6a3f        True
# 6404    xts     56  0xe0095510a77cf31989e286ba63f321cf28a8ea13        True
# 6405    smg     56  0x3ca994d9f723736381d44388bc8dd1e7ee8c1653        True
# 6406    dfg     56  0xdae7a4aacbbcaf13e9a101a2bf376fcb3931ad27        True
# 6407    myk     56  0xe0c7227fec46bea77d01ddf4cddb680793fd9d54        True
#
# [6408 rows x 4 columns]
