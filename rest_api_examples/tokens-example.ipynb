# %% [markdown]
# # Tokens Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting Tokens
#
# Returns list of top tokens by its market cap or liquidity, with pagination.
#
# ***Parameters:***
#
# `chain`
# - It is an optional parameter with the default value `"bsc"` (_Binance Smart Chain_). The chain can be specified as a string (case insensitive) or an integer (chain id).
#
# `extended`
# - The boolean parameter with default value _False_.
#
# `limit`
# - By default, number of items is 10. Maximal allowed value is 100.
#
# `page`
# - Optional parameter, by default equal to 1.
#
# `sort`
# - Optional parameter for sorting the items. Items are sorted descending according to time by default.
#
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
tokens = client.get_tokens()
tokens
# Out:
# [TokenResponseExtended(
#  	name = Wrapped BNB,
#  	symbol = WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5531154.591167131,
#  	circulating_supply = 5531147.758404688,
#  	market_cap = 1766707686.084522,
#  	liquidity_usd = 6.925396091360226e+20,
#  	price_usd = 324.2208729599436,
#  	price_peg = 1.0,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c,
#  ), TokenResponseExtended(
#  	name = BUSD Token,
#  	symbol = BUSD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4850999328.62941,
#  	circulating_supply = 4850774279.286532,
#  	market_cap = 4844783911.0250635,
#  	liquidity_usd = 2.4982848096973046e+18,
#  	price_usd = 0.9987650693326273,
#  	price_peg = 0.0030805082356805,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  ), TokenResponseExtended(
#  	name = PancakeSwap Token,
#  	symbol = Cake,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 746123735.7510512,
#  	circulating_supply = 299237677.7204769,
#  	market_cap = 1797480804.2039278,
#  	liquidity_usd = 4.208305673378179e+17,
#  	price_usd = 6.0990410763274765,
#  	price_peg = 0.0188113770409985,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82,
#  ), TokenResponseExtended(
#  	name = Tether USD,
#  	symbol = USDT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4479997922.172658,
#  	circulating_supply = 4479964704.34631,
#  	market_cap = 4073745383.701686,
#  	liquidity_usd = 1.5213732928690102e+16,
#  	price_usd = 0.9984755986946676,
#  	price_peg = 0.0030796154164264,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x55d398326f99059fF775485246999027B3197955,
#  ), TokenResponseExtended(
#  	name = Bitcoin,
#  	symbol = XBTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2.1e+16,
#  	circulating_supply = 2.1e+16,
#  	market_cap = 1.7531576736010955e+25,
#  	liquidity_usd = 421563091008038.4,
#  	price_usd = 834836987.4290931,
#  	price_peg = 2068396.7733265972,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x3E7B06B9c88ef97cF43C53F88F4f0689bDBd52AB,
#  ), TokenResponseExtended(
#  	name = Bitcoin,
#  	symbol = BTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21000000000000.0,
#  	circulating_supply = 21000000000000.0,
#  	market_cap = 1.72341343932878e+22,
#  	liquidity_usd = 419454777493569.7,
#  	price_usd = 820673066.347038,
#  	price_peg = 2048877.8795465103,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x74042a20eb5F24cbE38AA1D5DaFc9bA6f07Eb35d,
#  ), TokenResponseExtended(
#  	name = dead money token,
#  	symbol = DDM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000000000000.0,
#  	circulating_supply = 10000000000000.0,
#  	market_cap = 4.942687073320144e+16,
#  	liquidity_usd = 5078106519667.743,
#  	price_usd = 4942.687073320144,
#  	price_peg = 11.758158140293192,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xe6A9C705165b27E5Ac2570A7C727921aAEa78bB8,
#  ), TokenResponseExtended(
#  	name = dead money token,
#  	symbol = DDM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000000000000.0,
#  	circulating_supply = 10000000000000.0,
#  	market_cap = 4.9785362916855e+16,
#  	liquidity_usd = 5041540320532.249,
#  	price_usd = 4978.5362916855,
#  	price_peg = 11.843439844858523,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x37b53A16573DbFE9A1DcF5496C16E6C9d01b9618,
#  ), TokenResponseExtended(
#  	name = Gold Nugget,
#  	symbol = GOLD NUGGET,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 7989633.891251368,
#  	circulating_supply = 2786817.511253081,
#  	market_cap = 12633.896873874734,
#  	liquidity_usd = 1592617208442.4287,
#  	price_usd = 0.004533449651030057,
#  	price_peg = 1.46809702722e-05,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xE0B58022487131eC9913C1F3AcFD8F74FC6A6C7E,
#  ), TokenResponseExtended(
#  	name = radium,
#  	symbol = Radium,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000000000.0,
#  	circulating_supply = 1000000000.0,
#  	market_cap = 659.3260138219551,
#  	liquidity_usd = 466246308916.36127,
#  	price_usd = 6.593260138219552e-07,
#  	price_peg = 1.5512459e-09,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x2b92f4284C6D375eeC13e4Ad6d9db476B9B812CB,
#  )]

# %%
pd.DataFrame([t.__dict__ for t in tokens]).drop(columns=["price_change_24_h", "price_change_7_d", "volume_24_h"])
# Out:
#                 name       symbol chain  decimals  total_supply  \
# 0        Wrapped BNB         WBNB   BSC      18.0  5.531155e+06
# 1         BUSD Token         BUSD   BSC      18.0  4.850999e+09
# 2  PancakeSwap Token         Cake   BSC      18.0  7.461237e+08
# 3         Tether USD         USDT   BSC      18.0  4.479998e+09
# 4            Bitcoin         XBTC   BSC      18.0  2.100000e+16
# 5            Bitcoin          BTC   BSC      18.0  2.100000e+13
# 6   dead money token          DDM   BSC      18.0  1.000000e+13
# 7   dead money token          DDM   BSC      18.0  1.000000e+13
# 8        Gold Nugget  GOLD NUGGET   BSC      18.0  7.989634e+06
# 9             radium       Radium   BSC      18.0  1.000000e+09
#
#    circulating_supply    market_cap  liquidity_usd     price_usd  \
# 0        5.531148e+06  1.766708e+09   6.925396e+20  3.242209e+02
# 1        4.850774e+09  4.844784e+09   2.498285e+18  9.987651e-01
# 2        2.992377e+08  1.797481e+09   4.208306e+17  6.099041e+00
# 3        4.479965e+09  4.073745e+09   1.521373e+16  9.984756e-01
# 4        2.100000e+16  1.753158e+25   4.215631e+14  8.348370e+08
# 5        2.100000e+13  1.723413e+22   4.194548e+14  8.206731e+08
# 6        1.000000e+13  4.942687e+16   5.078107e+12  4.942687e+03
# 7        1.000000e+13  4.978536e+16   5.041540e+12  4.978536e+03
# 8        2.786818e+06  1.263390e+04   1.592617e+12  4.533450e-03
# 9        1.000000e+09  6.593260e+02   4.662463e+11  6.593260e-07
#
#       price_peg                                    contract
# 0  1.000000e+00  0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 1  3.080508e-03  0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56
# 2  1.881138e-02  0x0E09FaBB73Bd3Ade0a17ECC321fD13a19e81cE82
# 3  3.079615e-03  0x55d398326f99059fF775485246999027B3197955
# 4  2.068397e+06  0x3E7B06B9c88ef97cF43C53F88F4f0689bDBd52AB
# 5  2.048878e+06  0x74042a20eb5F24cbE38AA1D5DaFc9bA6f07Eb35d
# 6  1.175816e+01  0xe6A9C705165b27E5Ac2570A7C727921aAEa78bB8
# 7  1.184344e+01  0x37b53A16573DbFE9A1DcF5496C16E6C9d01b9618
# 8  1.468097e-05  0xE0B58022487131eC9913C1F3AcFD8F74FC6A6C7E
# 9  1.551246e-09  0x2b92f4284C6D375eeC13e4Ad6d9db476B9B812CB

# %%
tokens = client.get_tokens(
    extended = True,
    limit = 100,
    page = 1,
    sort = "-price_peg", # the same as "price_peg.desc"
)
tokens
# Out:
# [TokenResponseExtended(
#  	name = 3P,
#  	symbol = 3P,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1e+39,
#  	circulating_supply = 5.0714539286e-06,
#  	market_cap = 16249.32321379475,
#  	liquidity_usd = 8040.960958401638,
#  	price_usd = 1624932321.379475,
#  	price_peg = 4192874.2477848814,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xf2d980E7898Aa2fb943692b3F6460398909edc38,
#  ), TokenResponseExtended(
#  	name = Bitcoin,
#  	symbol = XBTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2.1e+16,
#  	circulating_supply = 2.1e+16,
#  	market_cap = 1.7531576736010955e+25,
#  	liquidity_usd = 421563091008038.4,
#  	price_usd = 834836987.4290931,
#  	price_peg = 2068396.7733265972,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x3E7B06B9c88ef97cF43C53F88F4f0689bDBd52AB,
#  ), TokenResponseExtended(
#  	name = Bitcoin,
#  	symbol = BTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21000000000000.0,
#  	circulating_supply = 21000000000000.0,
#  	market_cap = 1.72341343932878e+22,
#  	liquidity_usd = 419454777493569.7,
#  	price_usd = 820673066.347038,
#  	price_peg = 2048877.8795465103,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x74042a20eb5F24cbE38AA1D5DaFc9bA6f07Eb35d,
#  ), TokenResponseExtended(
#  	name = Ruggy Inu,
#  	symbol = RUGGYINU,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000.0,
#  	circulating_supply = 10000.0,
#  	market_cap = 24455464185.642834,
#  	liquidity_usd = 61.735823518397396,
#  	price_usd = 2445546.4185642833,
#  	price_peg = 7923.925779368992,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 961332954.4114491,
#  	contract = 0x9C6895D19017f4bdf0EAfCe36045A8aa7c0CD9ea,
#  ), TokenResponseExtended(
#  	name = ONLYONE,
#  	symbol = ONLYONE,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.0,
#  	circulating_supply = 0.4761032121513865,
#  	market_cap = 385859.3702942513,
#  	liquidity_usd = 21595.731456363403,
#  	price_usd = 810453.1967987639,
#  	price_peg = 2738.490278085888,
#  	price_change_24_h = -13.135,
#  	price_change_7_d = -22.483,
#  	volume_24_h = 455.3709838493269,
#  	contract = 0xb899dB682e6D6164D885ff67C1e676141deaaA40,
#  ), TokenResponseExtended(
#  	name = Binance-Peg BSC-HOS,
#  	symbol = BSC-HOS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100000.0,
#  	circulating_supply = 100000.0,
#  	market_cap = 57037303770.067474,
#  	liquidity_usd = 22497.48103667867,
#  	price_usd = 570373.0377006747,
#  	price_peg = 1820.2758253777893,
#  	price_change_24_h = -17.253,
#  	price_change_7_d = 206.346,
#  	volume_24_h = 1233798138.6807897,
#  	contract = 0xa0949F33FA921ca2571d469A1a4b08649838D34C,
#  ), TokenResponseExtended(
#  	name = Gravitoken,
#  	symbol = GRV,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 0.308450313,
#  	circulating_supply = 0.30423646,
#  	market_cap = 119244.82342271342,
#  	liquidity_usd = 13214.67198232093,
#  	price_usd = 391947.84025134076,
#  	price_peg = 1206.319565825503,
#  	price_change_24_h = -9.386,
#  	price_change_7_d = -18.052,
#  	volume_24_h = 51.32752942011433,
#  	contract = 0x1337ace33C2B3Fc17d85f33dbD0Ed73a896148B5,
#  ), TokenResponseExtended(
#  	name = XPHV2,
#  	symbol = XPHV2,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 955524.979655966,
#  	circulating_supply = 955524.979655966,
#  	market_cap = 185867173024.6392,
#  	liquidity_usd = 90532.8634539854,
#  	price_usd = 283800.9302963668,
#  	price_peg = 641.7166436070175,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 264033178.93743008,
#  	contract = 0xE949a82d5338429d1825a630904a1B0E3F429B15,
#  ), TokenResponseExtended(
#  	name = Only 1 Token,
#  	symbol = O1T,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.0,
#  	circulating_supply = 0.9999990058071053,
#  	market_cap = 58583.68000808972,
#  	liquidity_usd = 13517.077062133138,
#  	price_usd = 58583.73824317534,
#  	price_peg = 200.08438056275926,
#  	price_change_24_h = -16.724,
#  	price_change_7_d = -23.079,
#  	volume_24_h = 262.76822716545905,
#  	contract = 0xBB994E80E2eDc45dCe9065bda73ADc7E9337b64F,
#  ), TokenResponseExtended(
#  	name = RentechCoin,
#  	symbol = RTC,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 5100000.0,
#  	circulating_supply = 5100000.0,
#  	market_cap = 311414014837.0749,
#  	liquidity_usd = 2454699.97542748,
#  	price_usd = 61061.57153668135,
#  	price_peg = 151.37920461054043,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xD2F0ab7ef2562f3FB405C1e7F5BF095DF2C6D761,
#  ), TokenResponseExtended(
#  	name = BTCB Token,
#  	symbol = BTCB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 112501.0,
#  	circulating_supply = 112494.16115864519,
#  	market_cap = 3549175625.662814,
#  	liquidity_usd = 5939246045.495563,
#  	price_usd = 31549.86524729563,
#  	price_peg = 97.17664653399252,
#  	price_change_24_h = -4.441,
#  	price_change_7_d = -17.542,
#  	volume_24_h = 154625889.4430625,
#  	contract = 0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c,
#  ), TokenResponseExtended(
#  	name = AOCODS,
#  	symbol = AOCODS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2170.5203767123276,
#  	circulating_supply = 2170.5203767123276,
#  	market_cap = 66055294.04223769,
#  	liquidity_usd = 2833978.3338165293,
#  	price_usd = 30977.642723555364,
#  	price_peg = 96.01244196654689,
#  	price_change_24_h = -0.162,
#  	price_change_7_d = -6.417,
#  	volume_24_h = 82838.84539748296,
#  	contract = 0x7E7DFecBb402EAFBC71EF6eC2a90849A92583309,
#  ), TokenResponseExtended(
#  	name = renBTC,
#  	symbol = renBTC,
#  	chain = BSC,
#  	decimals = 8.0,
#  	total_supply = 252.99321767,
#  	circulating_supply = 252.99321767,
#  	market_cap = 9195793.668013062,
#  	liquidity_usd = 153424.2582731519,
#  	price_usd = 33883.177909721,
#  	price_peg = 95.2128883486062,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -9.403,
#  	volume_24_h = 2402.2326058544445,
#  	contract = 0xfCe146bF3146100cfe5dB4129cf6C82b0eF4Ad8c,
#  ), TokenResponseExtended(
#  	name = GreenWhaleS,
#  	symbol = GWS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.0,
#  	circulating_supply = 1.0,
#  	market_cap = 30176.365280850838,
#  	liquidity_usd = 28198.432531780672,
#  	price_usd = 30176.365280850838,
#  	price_peg = 86.86243584062744,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -13.118,
#  	volume_24_h = 0.0,
#  	contract = 0x259B9a530721293CCBbB9d28a7Eac50F8fd966Da,
#  ), TokenResponseExtended(
#  	name = W3D,
#  	symbol = W3D,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2100000.0,
#  	circulating_supply = 2090550.756724086,
#  	market_cap = 40211945019.41619,
#  	liquidity_usd = 145967.25054972185,
#  	price_usd = 19233.32599669218,
#  	price_peg = 53.59308366105293,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 22873.553,
#  	volume_24_h = 1972308.5066628992,
#  	contract = 0x8B847d376B5E0FA078AA0B6e7779930ff42c44b8,
#  ), TokenResponseExtended(
#  	name = GreenWhaleS,
#  	symbol = GWHALES,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.0,
#  	circulating_supply = 1.0,
#  	market_cap = 16436.72468691027,
#  	liquidity_usd = 10532.481776587138,
#  	price_usd = 16436.72468691027,
#  	price_peg = 47.494812574838996,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -58.637,
#  	volume_24_h = 0.0,
#  	contract = 0xBA2925Cca341d386459352449b3b9C6b53f088d3,
#  ), TokenResponseExtended(
#  	name = yearn.finance,
#  	symbol = YFI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 900.0,
#  	circulating_supply = 900.0,
#  	market_cap = 13053086.042011943,
#  	liquidity_usd = 386017.36377709935,
#  	price_usd = 14503.428935568825,
#  	price_peg = 44.7335618485077,
#  	price_change_24_h = -4.035,
#  	price_change_7_d = -16.21,
#  	volume_24_h = 130053.89886883461,
#  	contract = 0x88f1A5ae2A3BF98AEAF342D26B30a79438c9142e,
#  ), TokenResponseExtended(
#  	name = pTokens BTC,
#  	symbol = pBTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 238.49276437006043,
#  	circulating_supply = 238.49276437006043,
#  	market_cap = 2921743.70774961,
#  	liquidity_usd = 53992.535706606584,
#  	price_usd = 12250.869394159263,
#  	price_peg = 38.609239259413755,
#  	price_change_24_h = -13.081,
#  	price_change_7_d = -1.197,
#  	volume_24_h = 919.533022810012,
#  	contract = 0xeD28A457A5A76596ac48d87C0f577020F6Ea1c4C,
#  ), TokenResponseExtended(
#  	name = Test BTC,
#  	symbol = TBTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000000000.0,
#  	circulating_supply = 1000000000.0,
#  	market_cap = 11464776800099.102,
#  	liquidity_usd = 122470.69936323044,
#  	price_usd = 11464.776800099102,
#  	price_peg = 30.723768516574847,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x4A0DDf775183FB05E0f9CAed273dbF5D2E869D14,
#  ), TokenResponseExtended(
#  	name = XHZ,
#  	symbol = XHZ,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 12000.0,
#  	circulating_supply = 6765.51140487641,
#  	market_cap = 102266198.13595976,
#  	liquidity_usd = 43622.76884922761,
#  	price_usd = 8522.183177996647,
#  	price_peg = 20.13153877981633,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 481901.2091683191,
#  	contract = 0xB0A8b0209dC1ae590a23D2A1b4a3A85595882D03,
#  ), TokenResponseExtended(
#  	name = The Force,
#  	symbol = JEDI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1.0,
#  	circulating_supply = 0.9908449313026813,
#  	market_cap = 5503.2964824996925,
#  	liquidity_usd = 4391.706413844045,
#  	price_usd = 5554.145062098073,
#  	price_peg = 18.124510888051166,
#  	price_change_24_h = -41.498,
#  	price_change_7_d = -41.498,
#  	volume_24_h = 538.4220055056178,
#  	contract = 0x8DE07304bBE4767Dd20b0914c16709B04B5E6087,
#  ), TokenResponseExtended(
#  	name = HST Coin,
#  	symbol = HST,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000.0,
#  	circulating_supply = 1000.0,
#  	market_cap = 6648491.944867059,
#  	liquidity_usd = 52157.12145625529,
#  	price_usd = 6648.491944867059,
#  	price_peg = 17.403471794286936,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xf1E7FA297e08602c19528A4815b9548E43c722D6,
#  ), TokenResponseExtended(
#  	name = Badger Sett Digg,
#  	symbol = bDIGG,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 45.276656751240445,
#  	circulating_supply = 45.27659210768698,
#  	market_cap = 292629.54773674865,
#  	liquidity_usd = 17558.204745209547,
#  	price_usd = 6292.042003959193,
#  	price_peg = 15.501498914269739,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 7346.572116008865,
#  	contract = 0x5986D5c77c65e5801a5cAa4fAE80089f870A71dA,
#  ), TokenResponseExtended(
#  	name = HSBT,
#  	symbol = HSBT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21000000.0,
#  	circulating_supply = 21000000.0,
#  	market_cap = 87492369661.68109,
#  	liquidity_usd = 12907.966674655943,
#  	price_usd = 4166.303317222909,
#  	price_peg = 12.067674888411199,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -35.7,
#  	volume_24_h = 0.0,
#  	contract = 0x31F065323d15ea714C733CdB9Fc5b457167024C7,
#  ), TokenResponseExtended(
#  	name = dead money token,
#  	symbol = DDM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000000000000.0,
#  	circulating_supply = 10000000000000.0,
#  	market_cap = 4.9785362916855e+16,
#  	liquidity_usd = 5041540320532.249,
#  	price_usd = 4978.5362916855,
#  	price_peg = 11.843439844858523,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x37b53A16573DbFE9A1DcF5496C16E6C9d01b9618,
#  ), TokenResponseExtended(
#  	name = dead money token,
#  	symbol = DDM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000000000000.0,
#  	circulating_supply = 10000000000000.0,
#  	market_cap = 4.942687073320144e+16,
#  	liquidity_usd = 5078106519667.743,
#  	price_usd = 4942.687073320144,
#  	price_peg = 11.758158140293192,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xe6A9C705165b27E5Ac2570A7C727921aAEa78bB8,
#  ), TokenResponseExtended(
#  	name = UP,
#  	symbol = UP,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 435.4136626835212,
#  	circulating_supply = 435.4136626835212,
#  	market_cap = 1379990.948757262,
#  	liquidity_usd = 5964.514107845737,
#  	price_usd = 3169.497824128079,
#  	price_peg = 10.235770924154908,
#  	price_change_24_h = -21.246,
#  	price_change_7_d = -21.246,
#  	volume_24_h = 28.159568734186653,
#  	contract = 0xb4E8D978bFf48c2D8FA241C0F323F71C1457CA81,
#  ), TokenResponseExtended(
#  	name = ROOTKIT,
#  	symbol = ROOT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 110.93180966020057,
#  	circulating_supply = 110.93180966020057,
#  	market_cap = 298464.0380141925,
#  	liquidity_usd = 280564.8098621401,
#  	price_usd = 2714.739371378159,
#  	price_peg = 8.550579636590053,
#  	price_change_24_h = -10.189,
#  	price_change_7_d = -24.007,
#  	volume_24_h = 460.11110146912415,
#  	contract = 0xF2F9889E797D2aADdc234F4f3027C62C28165AF4,
#  ), TokenResponseExtended(
#  	name = Wrapped Ether (Wormhole),
#  	symbol = WETH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 289.1353964,
#  	circulating_supply = 289.1353964,
#  	market_cap = 695281.0122626825,
#  	liquidity_usd = 623341.7472263888,
#  	price_usd = 2393.8904636683246,
#  	price_peg = 7.396052857281432,
#  	price_change_24_h = -1.696,
#  	price_change_7_d = -15.854,
#  	volume_24_h = 213141.59684366957,
#  	contract = 0x4DB5a66E937A9F4473fA95b1cAF1d1E1D62E29EA,
#  ), TokenResponseExtended(
#  	name = Ethereum Token,
#  	symbol = ETH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1404999.9999985595,
#  	circulating_supply = 1404988.3342565163,
#  	market_cap = 3364800806.817112,
#  	liquidity_usd = 213738397.4996137,
#  	price_usd = 2394.895903956155,
#  	price_peg = 7.376511199263648,
#  	price_change_24_h = -1.62,
#  	price_change_7_d = -15.819,
#  	volume_24_h = 133936344.40863255,
#  	contract = 0x2170Ed0880ac9A755fd29B2688956BD959F933F8,
#  ), TokenResponseExtended(
#  	name = Wrapped Mirror GOOGL Token,
#  	symbol = mGOOGL,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 32.72835407734332,
#  	circulating_supply = 32.72835407734332,
#  	market_cap = 75868.88793263708,
#  	liquidity_usd = 7322.2072345932775,
#  	price_usd = 2296.104186385078,
#  	price_peg = 7.130572784097162,
#  	price_change_24_h = -18.522,
#  	price_change_7_d = -12.462,
#  	volume_24_h = 8358.701603429692,
#  	contract = 0x62D71B23bF15218C7d2D7E48DBbD9e9c650B173f,
#  ), TokenResponseExtended(
#  	name = Binance Beacon ETH,
#  	symbol = BETH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100000000.0,
#  	circulating_supply = 99999998.68136765,
#  	market_cap = 227001574551.11697,
#  	liquidity_usd = 4833855.779476688,
#  	price_usd = 2270.015775444332,
#  	price_peg = 7.0133764979665685,
#  	price_change_24_h = -2.788,
#  	price_change_7_d = -17.566,
#  	volume_24_h = 360716.51967136736,
#  	contract = 0x250632378E573c6Be1AC2f97Fcdf00515d0Aa91B,
#  ), TokenResponseExtended(
#  	name = FH,
#  	symbol = FH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 998.1423744766922,
#  	circulating_supply = 998.1423744766922,
#  	market_cap = 2184644.5080985026,
#  	liquidity_usd = 52053.69669648257,
#  	price_usd = 2188.1566641901486,
#  	price_peg = 6.686788825423134,
#  	price_change_24_h = -5.647,
#  	price_change_7_d = -17.288,
#  	volume_24_h = 1670.1638134287198,
#  	contract = 0x02824CB0421FC24B1C9e9fb01ea32f580f2c87B3,
#  ), TokenResponseExtended(
#  	name = Wrapped Mirror AMZN Token,
#  	symbol = mAMZN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 13.395474874787741,
#  	circulating_supply = 13.395471556278327,
#  	market_cap = 27211.73350978473,
#  	liquidity_usd = 9563.470355392863,
#  	price_usd = 2088.010071860264,
#  	price_peg = 6.483997289935229,
#  	price_change_24_h = -19.616,
#  	price_change_7_d = -25.145,
#  	volume_24_h = 8134.152739768668,
#  	contract = 0x3947B992DC0147D2D89dF0392213781b04B25075,
#  ), TokenResponseExtended(
#  	name = pBNB,
#  	symbol = pBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 233.69789514015173,
#  	circulating_supply = 233.69789514015173,
#  	market_cap = 384454.65952198027,
#  	liquidity_usd = 451780.5127152372,
#  	price_usd = 2081.151217482063,
#  	price_peg = 6.41741498407566,
#  	price_change_24_h = -12.498,
#  	price_change_7_d = 209.794,
#  	volume_24_h = 282022.6641045379,
#  	contract = 0xA2315cC5A1e4aE3D0a491ED4Fe45EBF8356fEaC7,
#  ), TokenResponseExtended(
#  	name = ESHARE,
#  	symbol = ESHARE,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 25074.91023592085,
#  	circulating_supply = 25074.91023592085,
#  	market_cap = 45166996.931643024,
#  	liquidity_usd = 2514068.3966319305,
#  	price_usd = 1803.728225648782,
#  	price_peg = 5.555657647043865,
#  	price_change_24_h = 7.915,
#  	price_change_7_d = -26.562,
#  	volume_24_h = 9282109.89276388,
#  	contract = 0xDB20F6A8665432CE895D724b417f77EcAC956550,
#  ), TokenResponseExtended(
#  	name = AFIX,
#  	symbol = AFIX,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 180000.0,
#  	circulating_supply = 179999.6005413555,
#  	market_cap = 372554228.5485749,
#  	liquidity_usd = 5246.129947664106,
#  	price_usd = 2069.75030737904,
#  	price_peg = 4.9293766442127875,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xcf496c03F630C343333a28749a7FC4d589b1137A,
#  ), TokenResponseExtended(
#  	name = Bit360Token,
#  	symbol = BIT360,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2100.0,
#  	circulating_supply = 2100.0,
#  	market_cap = 3156232.560655375,
#  	liquidity_usd = 210416.14821718156,
#  	price_usd = 1502.967886026369,
#  	price_peg = 4.64697650260091,
#  	price_change_24_h = -1.899,
#  	price_change_7_d = -9.301,
#  	volume_24_h = 25111.821439256837,
#  	contract = 0xBf8FeEAa4799f8765eCb3Ae6e1569eDe0fEe0366,
#  ), TokenResponseExtended(
#  	name = TAD,
#  	symbol = TAD,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000.0,
#  	circulating_supply = 10000.0,
#  	market_cap = 12915518.187205939,
#  	liquidity_usd = 535220.3247538406,
#  	price_usd = 1291.551818720594,
#  	price_peg = 4.155646880029781,
#  	price_change_24_h = 18.419,
#  	price_change_7_d = 1489.142,
#  	volume_24_h = 63181.40432471326,
#  	contract = 0xa3F2d13e003F2Fe1F113cF265b2a629494af4459,
#  ), TokenResponseExtended(
#  	name = LydianStater,
#  	symbol = LYS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 88888888.0,
#  	circulating_supply = 88888888.0,
#  	market_cap = 1491789003964.3843,
#  	liquidity_usd = 258283.939639671,
#  	price_usd = 1678.2626311381948,
#  	price_peg = 4.09145040129159,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 20.061170436943637,
#  	contract = 0xD5F66F1DF008Aeb8F782f9781794682c87eE2689,
#  ), TokenResponseExtended(
#  	name = Maker,
#  	symbol = MKR,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5000.0,
#  	circulating_supply = 4999.99998543572,
#  	market_cap = 5921269.2283386635,
#  	liquidity_usd = 9110.2551480793,
#  	price_usd = 1184.2538491172936,
#  	price_peg = 3.6484409476655055,
#  	price_change_24_h = -1.023,
#  	price_change_7_d = -19.715,
#  	volume_24_h = 752.5188627085075,
#  	contract = 0x5f0Da599BB2ccCfcf6Fdfd7D81743B6020864350,
#  ), TokenResponseExtended(
#  	name = FRMx Token,
#  	symbol = FRMX,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10999.697276882222,
#  	circulating_supply = 10999.697276882222,
#  	market_cap = 12593031.885194736,
#  	liquidity_usd = 174409.43443003608,
#  	price_usd = 1144.8524708810467,
#  	price_peg = 3.5469020603109427,
#  	price_change_24_h = -0.165,
#  	price_change_7_d = -20.284,
#  	volume_24_h = 65576.23443821447,
#  	contract = 0x8523518001ad5d24b2A04e8729743C0643A316c0,
#  ), TokenResponseExtended(
#  	name = Noahs ark,
#  	symbol = NSK,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 8000.0,
#  	circulating_supply = 6912.356108303045,
#  	market_cap = 8510302.406057326,
#  	liquidity_usd = 4838074.700875719,
#  	price_usd = 1231.172450133876,
#  	price_peg = 3.4247139746725694,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 265.137,
#  	volume_24_h = 295115.4856271301,
#  	contract = 0x47fB260e384C807C7f365F754239408cD1ff34f2,
#  ), TokenResponseExtended(
#  	name = beefy.finance,
#  	symbol = BIFI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 80000.0,
#  	circulating_supply = 79999.99713689132,
#  	market_cap = 67448650.15634595,
#  	liquidity_usd = 1012124.0618572002,
#  	price_usd = 843.1081571282028,
#  	price_peg = 2.6005949997099354,
#  	price_change_24_h = -16.42,
#  	price_change_7_d = -34.077,
#  	volume_24_h = 2068223.7055198909,
#  	contract = 0xCa3F508B8e4Dd382eE878A314789373D80A5190A,
#  ), TokenResponseExtended(
#  	name = Wrapped Mirror TSLA Token,
#  	symbol = mTSLA,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 121.72652429334364,
#  	circulating_supply = 121.72652429334364,
#  	market_cap = 97577.72806707479,
#  	liquidity_usd = 17584.49172384759,
#  	price_usd = 796.7200958714375,
#  	price_peg = 2.474073895088827,
#  	price_change_24_h = -26.626,
#  	price_change_7_d = -34.061,
#  	volume_24_h = 19437.011350043547,
#  	contract = 0xF215A127A196e3988C09d052e16BcFD365Cd7AA3,
#  ), TokenResponseExtended(
#  	name = HG,
#  	symbol = HG,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 2100.0,
#  	circulating_supply = 2100.0,
#  	market_cap = 1676040.4655312544,
#  	liquidity_usd = 1069946.3720581639,
#  	price_usd = 798.1145073958354,
#  	price_peg = 2.473758134217229,
#  	price_change_24_h = -16.408,
#  	price_change_7_d = -30.811,
#  	volume_24_h = 61488.43574039839,
#  	contract = 0x5DDD28577a7635372517Cc52dDAcbCd05e48C87f,
#  ), TokenResponseExtended(
#  	name = ETH,
#  	symbol = ETH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000000000.0,
#  	circulating_supply = 1000000000.0,
#  	market_cap = 834852908811.7306,
#  	liquidity_usd = 9093.21117506218,
#  	price_usd = 834.8529088117306,
#  	price_peg = 2.2373198578242,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x6df134F074Dd7ae67287944bc9fB52A0daF5b7C9,
#  ), TokenResponseExtended(
#  	name = CLUB,
#  	symbol = CLUB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2100.0,
#  	circulating_supply = 2033.0,
#  	market_cap = 1697293.7221585389,
#  	liquidity_usd = 745803.292754806,
#  	price_usd = 834.8714816323359,
#  	price_peg = 2.2110372270180423,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 53353.66639327438,
#  	contract = 0x240259a6902f083f8a71D76F0189992839ae09eA,
#  ), TokenResponseExtended(
#  	name = QJI Token,
#  	symbol = QJI,
#  	chain = BSC,
#  	decimals = 6.0,
#  	total_supply = 14888.794868,
#  	circulating_supply = 14888.794868,
#  	market_cap = 12354149.053811228,
#  	liquidity_usd = 2222230.986651433,
#  	price_usd = 819.5216035926773,
#  	price_peg = 2.099473409170236,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 79363.00232239239,
#  	contract = 0x4C2200082Ad960f03BF105971E5D85bb835ddB83,
#  ), TokenResponseExtended(
#  	name = PIOGOLD,
#  	symbol = PIO,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 110000000.0,
#  	circulating_supply = 110000000.0,
#  	market_cap = 70344839447.42087,
#  	liquidity_usd = 9626.95067635283,
#  	price_usd = 639.4985404310988,
#  	price_peg = 1.97166964728303,
#  	price_change_24_h = 10.096,
#  	price_change_7_d = 4.542,
#  	volume_24_h = 2584.478099035192,
#  	contract = 0x7DEF49Be7DD390fe4D78c82A0499E51C2087B870,
#  ), TokenResponseExtended(
#  	name = AUT,
#  	symbol = AUT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 672.0,
#  	circulating_supply = 672.0,
#  	market_cap = 408892.2787925861,
#  	liquidity_usd = 162211.90233386855,
#  	price_usd = 608.4706529651579,
#  	price_peg = 1.9358335880270403,
#  	price_change_24_h = -6.84,
#  	price_change_7_d = -5.805,
#  	volume_24_h = 4644.70152032306,
#  	contract = 0xafAD97E8e25Da643e7f41650938f8316461302F1,
#  ), TokenResponseExtended(
#  	name = YYDS,
#  	symbol = YYDS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000.0,
#  	circulating_supply = 991.0,
#  	market_cap = 602094.1141598178,
#  	liquidity_usd = 167905.31279423097,
#  	price_usd = 602.0941141598178,
#  	price_peg = 1.8651139161410895,
#  	price_change_24_h = -1.778,
#  	price_change_7_d = 44.056,
#  	volume_24_h = 83095.1728149762,
#  	contract = 0x5dCEFB65401278d6072583a618e1b3B6b49922Cd,
#  ), TokenResponseExtended(
#  	name = OKPI,
#  	symbol = OKPI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100000000.0,
#  	circulating_supply = 100000000.0,
#  	market_cap = 71042806309.14656,
#  	liquidity_usd = 3913946.5873987484,
#  	price_usd = 710.4280630914656,
#  	price_peg = 1.8200644382372058,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x9d28F460F6aCc69453b6DD226985B7e36C7227b3,
#  ), TokenResponseExtended(
#  	name = TAKE OFF,
#  	symbol = TKF,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 3000.0,
#  	circulating_supply = 3000.0,
#  	market_cap = 1750031.740107964,
#  	liquidity_usd = 845590.0293354656,
#  	price_usd = 583.3439133693214,
#  	price_peg = 1.807286690579147,
#  	price_change_24_h = -3.591,
#  	price_change_7_d = -26.287,
#  	volume_24_h = 12807.123826732455,
#  	contract = 0x724E740766B0ECc806ea1D7eEc63e563E9407925,
#  ), TokenResponseExtended(
#  	name = Micromachines 3.0 - Rise of the Warbots,
#  	symbol = MMAC,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 2000.0,
#  	circulating_supply = 2000.0,
#  	market_cap = 1052138.944629581,
#  	liquidity_usd = 12469.545119836497,
#  	price_usd = 526.0694723147905,
#  	price_peg = 1.7438027445638824,
#  	price_change_24_h = -8.558,
#  	price_change_7_d = -8.94,
#  	volume_24_h = 518.1053360333074,
#  	contract = 0xcc116e59Dd51DF5460E8B11Ff615E3E706a9202A,
#  ), TokenResponseExtended(
#  	name = BabyDot,
#  	symbol = bDOT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 101.0,
#  	circulating_supply = 101.0,
#  	market_cap = 52190.54413852176,
#  	liquidity_usd = 8627.875977320984,
#  	price_usd = 516.7380607774431,
#  	price_peg = 1.5939671262945725,
#  	price_change_24_h = -7.879,
#  	price_change_7_d = -18.429,
#  	volume_24_h = 0.0799206343445577,
#  	contract = 0x08bd7F9849f8EEC12fd78c9fED6ba4e47269e3d5,
#  ), TokenResponseExtended(
#  	name = Universal Store of Value,
#  	symbol = USV,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 11829.516505626,
#  	circulating_supply = 11829.516505626,
#  	market_cap = 7091474.745473174,
#  	liquidity_usd = 1289283.84183288,
#  	price_usd = 606.7326017272377,
#  	price_peg = 1.5626134616070313,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -13.648,
#  	volume_24_h = 5245.924100825203,
#  	contract = 0xaf6162DC717CFC8818eFC8d6f46a41Cf7042fCBA,
#  ), TokenResponseExtended(
#  	name = TAM,
#  	symbol = TAM,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 6247.720922709067,
#  	circulating_supply = 6247.720922709067,
#  	market_cap = 3080010.1121759806,
#  	liquidity_usd = 112219.91134862101,
#  	price_usd = 492.93685637145745,
#  	price_peg = 1.520040120002992,
#  	price_change_24_h = -8.585,
#  	price_change_7_d = -38.583,
#  	volume_24_h = 1156.976003756404,
#  	contract = 0x67EE26fcd22216e055cba7fb6a62B8e12888CFA5,
#  ), TokenResponseExtended(
#  	name = Killer Whale,
#  	symbol = KW,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9999.0,
#  	circulating_supply = 9999.0,
#  	market_cap = 4166812.352009648,
#  	liquidity_usd = 518316.5898642846,
#  	price_usd = 416.72290749171395,
#  	price_peg = 1.338890541162308,
#  	price_change_24_h = -2.47,
#  	price_change_7_d = 2.236,
#  	volume_24_h = 44548.2960037006,
#  	contract = 0x81afD511565CFd8384679fCEc1b39BA9798DE543,
#  ), TokenResponseExtended(
#  	name = Super.Yearn.Finance,
#  	symbol = SYFI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 873.3213817625731,
#  	circulating_supply = 872.3576212080549,
#  	market_cap = 350131.80255984736,
#  	liquidity_usd = 12281.13188060502,
#  	price_usd = 401.2556575510198,
#  	price_peg = 1.3126645351453492,
#  	price_change_24_h = -13.23,
#  	price_change_7_d = -41.17,
#  	volume_24_h = 702.0259631636965,
#  	contract = 0x52255193483c4C0Ab6e88A5B8c7117C767ecF33F,
#  ), TokenResponseExtended(
#  	name = UniCrypt on xDai on BSC,
#  	symbol = UNCX,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4642.702673604186,
#  	circulating_supply = 4642.702673604186,
#  	market_cap = 1904450.2071819063,
#  	liquidity_usd = 455411.2203596129,
#  	price_usd = 404.44557557120544,
#  	price_peg = 1.2528777320743052,
#  	price_change_24_h = -2.602,
#  	price_change_7_d = -7.065,
#  	volume_24_h = 108452.19861309155,
#  	contract = 0x09a6c44c3947B69E2B45F4D51b67E6a39ACfB506,
#  ), TokenResponseExtended(
#  	name = MAY 22 JRT Futures,
#  	symbol = JRT-MAY22,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100.0,
#  	circulating_supply = 100.0,
#  	market_cap = 37742.82741267895,
#  	liquidity_usd = 15793.5922179553,
#  	price_usd = 377.4282741267895,
#  	price_peg = 1.1629746166542063,
#  	price_change_24_h = -8.447,
#  	price_change_7_d = -34.241,
#  	volume_24_h = 714.8741374381674,
#  	contract = 0x0170845736fA0127E0e28dd03609CBB5402713A6,
#  ), TokenResponseExtended(
#  	name = SHAKE token by SpaceSwap v2,
#  	symbol = SHAKE,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 345.1378366009939,
#  	circulating_supply = 345.1378366000729,
#  	market_cap = 120940.73827525062,
#  	liquidity_usd = 65689.333199899,
#  	price_usd = 351.6765612899388,
#  	price_peg = 1.137794458263232,
#  	price_change_24_h = -11.917,
#  	price_change_7_d = -29.942,
#  	volume_24_h = 13756.531656845906,
#  	contract = 0xbA8A6Ef5f15ED18e7184f44a775060a6bF91d8d0,
#  ), TokenResponseExtended(
#  	name = Liquidity Staked BNB,
#  	symbol = LBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 631.5458758687578,
#  	circulating_supply = 631.5458758687578,
#  	market_cap = 282282.2206670824,
#  	liquidity_usd = 191850.12891266507,
#  	price_usd = 435.2148177672754,
#  	price_peg = 1.1300566975045558,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -4.885,
#  	volume_24_h = 0.0,
#  	contract = 0x43C37e8240d0fCCEF747d12e201Bf295e4226388,
#  ), TokenResponseExtended(
#  	name = MIC,
#  	symbol = MIC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21000.0,
#  	circulating_supply = 20999.99,
#  	market_cap = 7258862.968213648,
#  	liquidity_usd = 2306555.4275372387,
#  	price_usd = 345.6603059436527,
#  	price_peg = 1.121108470283875,
#  	price_change_24_h = -16.907,
#  	price_change_7_d = 51.875,
#  	volume_24_h = 5893489.945621591,
#  	contract = 0x71Fc2c893e41EaBDF9C4Afda3b2Cdb46B93Cd8Aa,
#  ), TokenResponseExtended(
#  	name = StaFi rBNB,
#  	symbol = rBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 110.57629093,
#  	circulating_supply = 110.57629093,
#  	market_cap = 47358.31607900776,
#  	liquidity_usd = 46735.09500293301,
#  	price_usd = 422.14919920109884,
#  	price_peg = 1.0602135701668036,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0xF027E525D491ef6ffCC478555FBb3CFabB3406a6,
#  ), TokenResponseExtended(
#  	name = Ankr BNB Reward Bearing Certificate,
#  	symbol = aBNBc,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 29735.964293326706,
#  	circulating_supply = 29735.964288326704,
#  	market_cap = 9800503.23388256,
#  	liquidity_usd = 2139330.425491161,
#  	price_usd = 325.83223684990764,
#  	price_peg = 1.0057976787815888,
#  	price_change_24_h = -5.03,
#  	price_change_7_d = -17.053,
#  	volume_24_h = 58003.060690672966,
#  	contract = 0xE85aFCcDaFBE7F2B096f268e31ccE3da8dA2990A,
#  ), TokenResponseExtended(
#  	name = CCN,
#  	symbol = CCN,
#  	chain = BSC,
#  	decimals = 8.0,
#  	total_supply = 10100.0,
#  	circulating_supply = 10089.45846807,
#  	market_cap = 4227846.901753828,
#  	liquidity_usd = 14598.284822917542,
#  	price_usd = 418.59870314394334,
#  	price_peg = 1.0031096398836392,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 19741.394120951132,
#  	contract = 0x3bc1eaa2Ef413fA0E6CAC2Bb5f3CF8a8D4B83977,
#  ), TokenResponseExtended(
#  	name = WBNB,
#  	symbol = WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100000000.0,
#  	circulating_supply = 100000000.0,
#  	market_cap = 39100229024.670616,
#  	liquidity_usd = 7111395.580845174,
#  	price_usd = 391.00229024670614,
#  	price_peg = 1.001208277770061,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 0.0,
#  	contract = 0x5F1166dC2183F42a095f10Cf8c88875A9F10765F,
#  ), TokenResponseExtended(
#  	name = Wrapped BNB,
#  	symbol = WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5531154.591167131,
#  	circulating_supply = 5531147.758404688,
#  	market_cap = 1769127758.494813,
#  	liquidity_usd = 6.925396091358852e+20,
#  	price_usd = 324.6649973590567,
#  	price_peg = 1.0,
#  	price_change_24_h = -4.813,
#  	price_change_7_d = -16.644,
#  	volume_24_h = 1034802218.117606,
#  	contract = 0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c,
#  ), TokenResponseExtended(
#  	name = Synthetic BNB,
#  	symbol = SBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 24643.21124185452,
#  	circulating_supply = 24643.21124185452,
#  	market_cap = 7211985.236573028,
#  	liquidity_usd = 7140147.347239948,
#  	price_usd = 292.6560652259495,
#  	price_peg = 0.9942035336148793,
#  	price_change_24_h = -15.31,
#  	price_change_7_d = -24.211,
#  	volume_24_h = 11699.300154399589,
#  	contract = 0xE90444C38a8Cd2DCEEe9D954042ac817a794E9A9,
#  ), TokenResponseExtended(
#  	name = Wrapped BNB,
#  	symbol = WBNB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 4918.653116392668,
#  	circulating_supply = 4918.653116392668,
#  	market_cap = 850924.5692869503,
#  	liquidity_usd = 1640507.0918887313,
#  	price_usd = 336.3524442589483,
#  	price_peg = 0.9578656846349206,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 6.994,
#  	volume_24_h = 3660430.831612226,
#  	contract = 0x0efb5FD2402A0967B92551d6AF54De148504A115,
#  ), TokenResponseExtended(
#  	name = Teneo BNB,
#  	symbol = tenBNB,
#  	chain = BSC,
#  	decimals = 22.0,
#  	total_supply = 26.800340508300202,
#  	circulating_supply = 26.800340508300202,
#  	market_cap = 20381.594653016582,
#  	liquidity_usd = 6473.007692462776,
#  	price_usd = 349.24409922801703,
#  	price_peg = 0.9269830435819651,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 943.2693975893962,
#  	contract = 0xfE55EaD876A85b84E125De26fF5086d7eB99BD14,
#  ), TokenResponseExtended(
#  	name = MJ,
#  	symbol = MJ,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 13141.0,
#  	circulating_supply = 10504.431682756138,
#  	market_cap = 2994548.2971497234,
#  	liquidity_usd = 140479.23373808747,
#  	price_usd = 285.06201918299274,
#  	price_peg = 0.8830301491060178,
#  	price_change_24_h = -1.392,
#  	price_change_7_d = -17.871,
#  	volume_24_h = 7808.35961189673,
#  	contract = 0x8688C28f11585aB8D6ACF72c63125E89E75E9243,
#  ), TokenResponseExtended(
#  	name = BelugaToken,
#  	symbol = BELUGA,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5000.0,
#  	circulating_supply = 5000.0,
#  	market_cap = 1415278.9304250625,
#  	liquidity_usd = 11132.317654024586,
#  	price_usd = 283.0557860850125,
#  	price_peg = 0.862674285494461,
#  	price_change_24_h = 1.235,
#  	price_change_7_d = -16.977,
#  	volume_24_h = 1417.8492871022333,
#  	contract = 0x181dE8C57C4F25eBA9Fd27757BBd11Cc66a55d31,
#  ), TokenResponseExtended(
#  	name = DJT,
#  	symbol = DJT,
#  	chain = BSC,
#  	decimals = 9.0,
#  	total_supply = 33333.0,
#  	circulating_supply = 33322.2265,
#  	market_cap = 9061697.59779914,
#  	liquidity_usd = 75923.17770331487,
#  	price_usd = 271.9415402148815,
#  	price_peg = 0.8376128202262265,
#  	price_change_24_h = -23.09,
#  	price_change_7_d = -62.412,
#  	volume_24_h = 40595.94495919022,
#  	contract = 0x41D8675E6C64939c3245908EEaf827A995Fc47Ff,
#  ), TokenResponseExtended(
#  	name = Milk,
#  	symbol = Milk,
#  	chain = BSC,
#  	decimals = 6.0,
#  	total_supply = 200000.0,
#  	circulating_supply = 200000.0,
#  	market_cap = 53168582.849706724,
#  	liquidity_usd = 316094.1584517904,
#  	price_usd = 265.8429142485336,
#  	price_peg = 0.8196287868872868,
#  	price_change_24_h = -6.514,
#  	price_change_7_d = -19.729,
#  	volume_24_h = 11819.772023719357,
#  	contract = 0x71F78f6884Acf32129b728157615540aAdB579C6,
#  ), TokenResponseExtended(
#  	name = NanoMeter Beacon,
#  	symbol = nmBEN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2100.0,
#  	circulating_supply = 2100.0,
#  	market_cap = 554186.9116803338,
#  	liquidity_usd = 246133.16958768404,
#  	price_usd = 263.89852937158753,
#  	price_peg = 0.8178904124580463,
#  	price_change_24_h = -18.287,
#  	price_change_7_d = -26.85,
#  	volume_24_h = 28676.867255115212,
#  	contract = 0xAB7E37268cb8a7417A81BADcd665B6b43fD06A06,
#  ), TokenResponseExtended(
#  	name = Virtual Treasure Coin,
#  	symbol = VTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 21000.0,
#  	circulating_supply = 20999.999,
#  	market_cap = 6180465.798352435,
#  	liquidity_usd = 51250.452056403,
#  	price_usd = 294.30790917430215,
#  	price_peg = 0.8082734032996192,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 18257.71514347484,
#  	contract = 0xa67De3024d457E0260B51Afa51ef93942F1b8Acc,
#  ), TokenResponseExtended(
#  	name = BoringDAO Token,
#  	symbol = BOR,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1489.1682902573243,
#  	circulating_supply = 1489.1682902573243,
#  	market_cap = 386753.2945025334,
#  	liquidity_usd = 5006.710275403065,
#  	price_usd = 259.7109386714805,
#  	price_peg = 0.8001156372951133,
#  	price_change_24_h = -6.203,
#  	price_change_7_d = -18.902,
#  	volume_24_h = 1295.0892461289022,
#  	contract = 0x92D7756c60dcfD4c689290E8A9F4d263b3b32241,
#  ), TokenResponseExtended(
#  	name = PinkSale,
#  	symbol = PINKSALE,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 100000.0,
#  	circulating_supply = 94705.42808454159,
#  	market_cap = 24892062.341885515,
#  	liquidity_usd = 1087348.65717645,
#  	price_usd = 257.86941028823696,
#  	price_peg = 0.797489048283022,
#  	price_change_24_h = -6.043,
#  	price_change_7_d = -25.582,
#  	volume_24_h = 79740.86447755551,
#  	contract = 0x602bA546A7B06e0FC7f58fD27EB6996eCC824689,
#  ), TokenResponseExtended(
#  	name = POKER,
#  	symbol = POKER,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 511.0,
#  	circulating_supply = 511.0,
#  	market_cap = 144675.84766277808,
#  	liquidity_usd = 40686.92099460558,
#  	price_usd = 283.12298955533873,
#  	price_peg = 0.7879003683374107,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -6.496,
#  	volume_24_h = 0.0,
#  	contract = 0x82caA54eC9aAF213FF611aF63d4B650ACcFF53ae,
#  ), TokenResponseExtended(
#  	name = SOCCER,
#  	symbol = SOCCER,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 553.5,
#  	circulating_supply = 553.5,
#  	market_cap = 127594.11716557233,
#  	liquidity_usd = 36102.51254481214,
#  	price_usd = 230.52234356923637,
#  	price_peg = 0.767786124169456,
#  	price_change_24_h = -18.886,
#  	price_change_7_d = -26.858,
#  	volume_24_h = 21355.392896887486,
#  	contract = 0x338d44d19c8d45ed9771b8D2B95D988F0e42187F,
#  ), TokenResponseExtended(
#  	name = CAR,
#  	symbol = CAR,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 687.0,
#  	circulating_supply = 687.0,
#  	market_cap = 198798.76388075834,
#  	liquidity_usd = 48153.1979810186,
#  	price_usd = 289.3722909472465,
#  	price_peg = 0.7654669124647724,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -8.976,
#  	volume_24_h = 0.0,
#  	contract = 0x176a25637e5078519230A4d80A7A47350940264a,
#  ), TokenResponseExtended(
#  	name = Tao Te Ching ,
#  	symbol = TTC,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 5162.0,
#  	circulating_supply = 5162.0,
#  	market_cap = 1265668.983739349,
#  	liquidity_usd = 491273.39202909864,
#  	price_usd = 245.18965202234583,
#  	price_peg = 0.7551109746532969,
#  	price_change_24_h = 2.336,
#  	price_change_7_d = 1.348,
#  	volume_24_h = 10986.226430684348,
#  	contract = 0x152ad7Dc399269FA65D19BD7A790Ea8aa5b23DaD,
#  ), TokenResponseExtended(
#  	name = Bitcoin Cash Token,
#  	symbol = BCH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 160000.0,
#  	circulating_supply = 159995.51078447734,
#  	market_cap = 38343226.846590124,
#  	liquidity_usd = 182279.76608274304,
#  	price_usd = 239.651891847394,
#  	price_peg = 0.7389478970872535,
#  	price_change_24_h = -5.128,
#  	price_change_7_d = -16.36,
#  	volume_24_h = 106018.22117918156,
#  	contract = 0x8fF795a6F4D97E7887C79beA79aba5cc76444aDf,
#  ), TokenResponseExtended(
#  	name = AUTOv2,
#  	symbol = AUTO,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 80638.18932503244,
#  	circulating_supply = 78242.11863482135,
#  	market_cap = 18379890.71810475,
#  	liquidity_usd = 709822.1338518574,
#  	price_usd = 234.91044259536258,
#  	price_peg = 0.7280824239186728,
#  	price_change_24_h = -7.774,
#  	price_change_7_d = -30.733,
#  	volume_24_h = 158732.5328203696,
#  	contract = 0xa184088a740c695E156F91f5cC086a06bb78b827,
#  ), TokenResponseExtended(
#  	name = TigerDAO,
#  	symbol = TigerDAO,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 2022.0,
#  	circulating_supply = 1586.4,
#  	market_cap = 328460.9568970672,
#  	liquidity_usd = 95560.29282324311,
#  	price_usd = 207.04800611262428,
#  	price_peg = 0.6966996290380201,
#  	price_change_24_h = -12.926,
#  	price_change_7_d = -24.871,
#  	volume_24_h = 805.2316824391062,
#  	contract = 0xC91E7A08f72B44f800831A22bf69A0b7E1735226,
#  ), TokenResponseExtended(
#  	name = ATHENA,
#  	symbol = ATH,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 10000.0,
#  	circulating_supply = 8419.30132975581,
#  	market_cap = 2322274.9710744726,
#  	liquidity_usd = 301799.5350099348,
#  	price_usd = 275.0674025181974,
#  	price_peg = 0.6950182714284142,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = -21.524,
#  	volume_24_h = 25178.117384162044,
#  	contract = 0x2e50fC6070c93c78bEbf3A68dF1c720c7d596300,
#  ), TokenResponseExtended(
#  	name = LHGOXI,
#  	symbol = LHGOXI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9655.037403805067,
#  	circulating_supply = 9655.037403805067,
#  	market_cap = 1901198.7823639545,
#  	liquidity_usd = 645306.8657578287,
#  	price_usd = 196.8279419083251,
#  	price_peg = 0.6457944081436275,
#  	price_change_24_h = -0.247,
#  	price_change_7_d = 11.252,
#  	volume_24_h = 10049.157730035322,
#  	contract = 0x14a9C53CaddA4B5cA5201776e5364C914aAb3f7d,
#  ), TokenResponseExtended(
#  	name = Wrapped Mirror NFLX Token,
#  	symbol = mNFLX,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 79.13964530485836,
#  	circulating_supply = 79.13964530485836,
#  	market_cap = 16306.930290989008,
#  	liquidity_usd = 9551.848807924385,
#  	price_usd = 206.05260774384504,
#  	price_peg = 0.6398654255170472,
#  	price_change_24_h = -7.305,
#  	price_change_7_d = -12.82,
#  	volume_24_h = 5315.959059105817,
#  	contract = 0xa04F060077D90Fe2647B61e4dA4aD1F97d6649dc,
#  ), TokenResponseExtended(
#  	name = Cosmic element,
#  	symbol = YZB,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 29892.697512270686,
#  	circulating_supply = 29892.697512270686,
#  	market_cap = 6774054.115588535,
#  	liquidity_usd = 520848.6501491705,
#  	price_usd = 226.43061089775483,
#  	price_peg = 0.6377546733769363,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 259595.44917640433,
#  	contract = 0x83AAa9246d38F5CDf4508552610919c788a8E2bb,
#  ), TokenResponseExtended(
#  	name = UNICN,
#  	symbol = UNICN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 9999.0,
#  	circulating_supply = 9999.0,
#  	market_cap = 1931197.7197008815,
#  	liquidity_usd = 830736.7027158412,
#  	price_usd = 193.139085878676,
#  	price_peg = 0.6337245083329394,
#  	price_change_24_h = -1.24,
#  	price_change_7_d = 3.389,
#  	volume_24_h = 4294.172049287925,
#  	contract = 0x17eD13FaD90700c1CE7E098329dED4Ea44022e66,
#  ), TokenResponseExtended(
#  	name = The Web3 Project,
#  	symbol = WEB3,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 232643.98838217437,
#  	circulating_supply = 232643.98820240685,
#  	market_cap = 43680119.59777342,
#  	liquidity_usd = 1352088.607344751,
#  	price_usd = 194.24565695956002,
#  	price_peg = 0.5988939877660504,
#  	price_change_24_h = -11.0,
#  	price_change_7_d = -30.651,
#  	volume_24_h = 260719.1919003218,
#  	contract = 0x333FD139cAeF6Aa31056cC905987b77B1044d259,
#  ), TokenResponseExtended(
#  	name = Shen Nong Token,
#  	symbol = SN,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 8888.0,
#  	circulating_supply = 6611.132532979882,
#  	market_cap = 1259503.092303532,
#  	liquidity_usd = 893821.3851023077,
#  	price_usd = 190.25271414928727,
#  	price_peg = 0.5907628161134535,
#  	price_change_24_h = -3.085,
#  	price_change_7_d = -25.128,
#  	volume_24_h = 28727.40982439445,
#  	contract = 0xb3d728c6D10c1324ef4C3D3DE11c6B465d5C33D6,
#  ), TokenResponseExtended(
#  	name = MetaFinance,
#  	symbol = MFI,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 420000.0,
#  	circulating_supply = 420000.0,
#  	market_cap = 75458336.35965462,
#  	liquidity_usd = 220062.3271434143,
#  	price_usd = 179.6627056182253,
#  	price_peg = 0.5834437477669066,
#  	price_change_24_h = -1.487,
#  	price_change_7_d = -8.853,
#  	volume_24_h = 23299.077394801076,
#  	contract = 0x808f1350dff684C099F4837A01D863fC61A86BC6,
#  ), TokenResponseExtended(
#  	name = VIPi,
#  	symbol = VIPi,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000.0,
#  	circulating_supply = 1000.0,
#  	market_cap = 183819.38160836173,
#  	liquidity_usd = 39218.76603974698,
#  	price_usd = 183.8193816083617,
#  	price_peg = 0.5669963263071339,
#  	price_change_24_h = 10.733,
#  	price_change_7_d = -30.789,
#  	volume_24_h = 4545.611259400419,
#  	contract = 0xe5680cC2925e6CDFA420A5f53AedFB8eF43e919B,
#  ), TokenResponseExtended(
#  	name = MBUS,
#  	symbol = MBUS,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 30000.0,
#  	circulating_supply = 23493.671695232635,
#  	market_cap = 4218711.447480092,
#  	liquidity_usd = 504967.41243351327,
#  	price_usd = 178.86822426120864,
#  	price_peg = 0.551009710697894,
#  	price_change_24_h = -4.761,
#  	price_change_7_d = 0.37,
#  	volume_24_h = 47463.2077299299,
#  	contract = 0x019601ee0AA825Ec2A53C413924BE30D7eE1e573,
#  ), TokenResponseExtended(
#  	name = ApeJet,
#  	symbol = JET,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 110000.0,
#  	circulating_supply = 110000.0,
#  	market_cap = 18925237.27512311,
#  	liquidity_usd = 133122.84425727988,
#  	price_usd = 172.04761159202826,
#  	price_peg = 0.5333728808922966,
#  	price_change_24_h = -12.304,
#  	price_change_7_d = 35.895,
#  	volume_24_h = 30009.0646229894,
#  	contract = 0x8925F9607d2E3fC31E11ca476b7Aa1b383E9a471,
#  ), TokenResponseExtended(
#  	name = Bounty Token,
#  	symbol = BHT,
#  	chain = BSC,
#  	decimals = 18.0,
#  	total_supply = 1000000.0,
#  	circulating_supply = 944192.8588073538,
#  	market_cap = 193646348.19253236,
#  	liquidity_usd = 7565.5876491333,
#  	price_usd = 198.98738737982492,
#  	price_peg = 0.4940082299268457,
#  	price_change_24_h = 0.0,
#  	price_change_7_d = 0.0,
#  	volume_24_h = 356573.0791292057,
#  	contract = 0x155119293F542763735B5d37DF617CA0Ad404Dc2,
#  )]

# %%
pd.DataFrame([t.__dict__ for t in tokens])
# Out:
#             name    symbol chain  decimals  total_supply  circulating_supply  \
# 0             3P        3P   BSC      18.0  1.000000e+39        5.071454e-06
# 1        Bitcoin      XBTC   BSC      18.0  2.100000e+16        2.100000e+16
# 2        Bitcoin       BTC   BSC      18.0  2.100000e+13        2.100000e+13
# 3      Ruggy Inu  RUGGYINU   BSC      18.0  1.000000e+04        1.000000e+04
# 4        ONLYONE   ONLYONE   BSC      18.0  1.000000e+00        4.761032e-01
# ..           ...       ...   ...       ...           ...                 ...
# 95   MetaFinance       MFI   BSC      18.0  4.200000e+05        4.200000e+05
# 96          VIPi      VIPi   BSC      18.0  1.000000e+03        1.000000e+03
# 97          MBUS      MBUS   BSC      18.0  3.000000e+04        2.349367e+04
# 98        ApeJet       JET   BSC      18.0  1.100000e+05        1.100000e+05
# 99  Bounty Token       BHT   BSC      18.0  1.000000e+06        9.441929e+05
#
#       market_cap  liquidity_usd     price_usd     price_peg  \
# 0   1.624932e+04   8.040961e+03  1.624932e+09  4.192874e+06
# 1   1.753158e+25   4.215631e+14  8.348370e+08  2.068397e+06
# 2   1.723413e+22   4.194548e+14  8.206731e+08  2.048878e+06
# 3   2.445546e+10   6.173582e+01  2.445546e+06  7.923926e+03
# 4   3.858594e+05   2.159573e+04  8.104532e+05  2.738490e+03
# ..           ...            ...           ...           ...
# 95  7.545834e+07   2.200623e+05  1.796627e+02  5.834437e-01
# 96  1.838194e+05   3.921877e+04  1.838194e+02  5.669963e-01
# 97  4.218711e+06   5.049674e+05  1.788682e+02  5.510097e-01
# 98  1.892524e+07   1.331228e+05  1.720476e+02  5.333729e-01
# 99  1.936463e+08   7.565588e+03  1.989874e+02  4.940082e-01
#
#     price_change_24_h  price_change_7_d   volume_24_h  \
# 0               0.000             0.000  0.000000e+00
# 1               0.000             0.000  0.000000e+00
# 2               0.000             0.000  0.000000e+00
# 3               0.000             0.000  9.613330e+08
# 4             -13.135           -22.483  4.553710e+02
# ..                ...               ...           ...
# 95             -1.487            -8.853  2.329908e+04
# 96             10.733           -30.789  4.545611e+03
# 97             -4.761             0.370  4.746321e+04
# 98            -12.304            35.895  3.000906e+04
# 99              0.000             0.000  3.565731e+05
#
#                                       contract
# 0   0xf2d980E7898Aa2fb943692b3F6460398909edc38
# 1   0x3E7B06B9c88ef97cF43C53F88F4f0689bDBd52AB
# 2   0x74042a20eb5F24cbE38AA1D5DaFc9bA6f07Eb35d
# 3   0x9C6895D19017f4bdf0EAfCe36045A8aa7c0CD9ea
# 4   0xb899dB682e6D6164D885ff67C1e676141deaaA40
# ..                                         ...
# 95  0x808f1350dff684C099F4837A01D863fC61A86BC6
# 96  0xe5680cC2925e6CDFA420A5f53AedFB8eF43e919B
# 97  0x019601ee0AA825Ec2A53C413924BE30D7eE1e573
# 98  0x8925F9607d2E3fC31E11ca476b7Aa1b383E9a471
# 99  0x155119293F542763735B5d37DF617CA0Ad404Dc2
#
# [100 rows x 14 columns]
