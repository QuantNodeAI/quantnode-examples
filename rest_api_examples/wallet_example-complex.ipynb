# %% [markdown]
# # Wallet Example

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import numpy as np
import pandas as pd

from helixirapi.helixir_api import HelixirApi

# %% [markdown]
# ## Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Select desired wallet

# %%
WALLET = "0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa"
# WALLET = "0x4bCe83f16B2A3F9Dad4C689E64c53A785EB49288",
# WALLET = "0xc28DA9E36FEFa4de9c4d483Fce236074bcf2169E",
# WALLET = "0x8894E0a0c962CB723c1976a4421c95949bE2D4E3"
# WALLET = ""

# %% [markdown]
# ## Farm Portfolio

# %%
client.get_farm_portfolio(address=WALLET)
# Out:
# []

# %% [markdown]
# ## Historic Farm Portfolio
#
# _Note_: Wallet has to be whitelisted.

# %%
client.get_historic_farm_portfolio(address=WALLET)

# %% [markdown]
# ## Historic Portfolio
# _Note_: Wallet has to be whitelisted.

# %%
client.get_historic_portfolio(address=WALLET)

# %% [markdown]
# ## Portfolio

# %%
portfolio = client.get_wallets_portfolio(address=WALLET)
portfolio
# Out:
# [TokenPortfolioResponse(
#  	token_name = Stakeable,
#  	token_symbol = STAKE,
#  	token_address = 0x5eC2A778717Cf1A5018C6aE3A7A2957582A92007,
#  	token_icon = ,
#  	balance = 10000.0,
#  	usd_value = 0.0,
#  ), TokenPortfolioResponse(
#  	token_name = Project Quantum,
#  	token_symbol = QBIT,
#  	token_address = 0xA38898a4Ae982Cb0131104a6746f77fA0dA57aAA,
#  	token_icon = ,
#  	balance = 66146.46,
#  	usd_value = 0.0,
#  ), TokenPortfolioResponse(
#  	token_name = NFTArt.Finance,
#  	token_symbol = NFTART,
#  	token_address = 0xF7844CB890F4C339c497aeAb599aBDc3c874B67A,
#  	token_icon = ,
#  	balance = 294674306.44909215,
#  	usd_value = 0.10151759007068324,
#  ), TokenPortfolioResponse(
#  	token_name = Helicopter Finance,
#  	token_symbol = $COPTER,
#  	token_address = 0xBC12aD556581ff7162E595E5956F5F3845FDB38c,
#  	token_icon = ,
#  	balance = 3394978378.530305,
#  	usd_value = 3.1130847964236064,
#  ), TokenPortfolioResponse(
#  	token_name = Binance Coin,
#  	token_symbol = BNB,
#  	token_address = ,
#  	token_icon = ,
#  	balance = 0.1331518702266046,
#  	usd_value = 56.023505991609056,
#  ), TokenPortfolioResponse(
#  	token_name = MicroPets,
#  	token_symbol = PETS,
#  	token_address = 0xA77346760341460B42C230ca6D21d4c8E743Fa9c,
#  	token_icon = ,
#  	balance = 4650000.0,
#  	usd_value = 5.28664294025826,
#  ), TokenPortfolioResponse(
#  	token_name = Burger Swap,
#  	token_symbol = BURGER,
#  	token_address = 0xAe9269f27437f0fcBC232d39Ec814844a51d6b8f,
#  	token_icon = ,
#  	balance = 9.298421781e-07,
#  	usd_value = 1.313505054477285e-06,
#  ), TokenPortfolioResponse(
#  	token_name = SafeMoon,
#  	token_symbol = SAFEMOON,
#  	token_address = 0x8076C74C5e3F5852037F31Ff0093Eeb8c8ADd8D3,
#  	token_icon = ,
#  	balance = 8.852433383,
#  	usd_value = 4.929614818740148e-06,
#  ), TokenPortfolioResponse(
#  	token_name = Tether USD,
#  	token_symbol = USDT,
#  	token_address = 0x55d398326f99059fF775485246999027B3197955,
#  	token_icon = ,
#  	balance = 0.000926164513067,
#  	usd_value = 0.0009284891951860637,
#  ), TokenPortfolioResponse(
#  	token_name = Papel,
#  	token_symbol = PAPEL,
#  	token_address = 0x557dd6700e66818AF340ccE17FD4508CED81fBc1,
#  	token_icon = ,
#  	balance = 467925629.4145258,
#  	usd_value = 4.846606296215754,
#  ), TokenPortfolioResponse(
#  	token_name = Pig Token,
#  	token_symbol = PIG,
#  	token_address = 0x8850D2c68c632E3B258e612abAA8FadA7E6958E5,
#  	token_icon = ,
#  	balance = 6124129.569702409,
#  	usd_value = 0.2939714589503713,
#  ), TokenPortfolioResponse(
#  	token_name = SafeMoon,
#  	token_symbol = SFM,
#  	token_address = 0x42981d0bfbAf196529376EE702F2a9Eb9092fcB5,
#  	token_icon = ,
#  	balance = 18490.136768171,
#  	usd_value = 11.124108021954502,
#  ), TokenPortfolioResponse(
#  	token_name = BLinkToken,
#  	token_symbol = blink,
#  	token_address = 0x63870A18B6e42b01Ef1Ad8A2302ef50B7132054F,
#  	token_icon = ,
#  	balance = 9e-06,
#  	usd_value = 3.0910429248138995e-08,
#  ), TokenPortfolioResponse(
#  	token_name = DigitalFinancialExch,
#  	token_symbol = DIFX,
#  	token_address = 0x697bd938e7E572E787ecd7bC74a31f1814C21264,
#  	token_icon = ,
#  	balance = 104.64581544928086,
#  	usd_value = 36.99183902165906,
#  ), TokenPortfolioResponse(
#  	token_name = SHIBA INU,
#  	token_symbol = SHIB,
#  	token_address = 0x2859e4544C4bB03966803b044A93563Bd2D0DD4D,
#  	token_icon = ,
#  	balance = 0.0010356816038916,
#  	usd_value = 2.5782666238959085e-08,
#  ), TokenPortfolioResponse(
#  	token_name = ENHANCE,
#  	token_symbol = ENH,
#  	token_address = 0xA001862BA0866Ee3e3a2613fAb5954861452B9Bf,
#  	token_icon = ,
#  	balance = 434342220.8158318,
#  	usd_value = 2.9907428677727776,
#  ), TokenPortfolioResponse(
#  	token_name = SafeRocket,
#  	token_symbol = SAFEROCKET,
#  	token_address = 0x95AAC643E2760267cbE4c52b2BAc5505B9049a1E,
#  	token_icon = ,
#  	balance = 504634337.8475141,
#  	usd_value = 0.042719787151303694,
#  ), TokenPortfolioResponse(
#  	token_name = TreeDefi Token,
#  	token_symbol = SEED,
#  	token_address = 0x40B34cC972908060D6d527276e17c105d224559d,
#  	token_icon = ,
#  	balance = 0.02,
#  	usd_value = 0.00462388040500063,
#  ), TokenPortfolioResponse(
#  	token_name = Exchange99,
#  	token_symbol = EX99,
#  	token_address = 0xa5B517b0a8e28909B92DC052D31F1335d7a1cCC0,
#  	token_icon = ,
#  	balance = 176.64,
#  	usd_value = 0.027521254410454884,
#  ), TokenPortfolioResponse(
#  	token_name = CumRocket,
#  	token_symbol = CUMMIES,
#  	token_address = 0x27Ae27110350B98d564b9A3eeD31bAeBc82d878d,
#  	token_icon = ,
#  	balance = 0.0093307280666362,
#  	usd_value = 4.901161401137885e-05,
#  ), TokenPortfolioResponse(
#  	token_name = Crypto Inu,
#  	token_symbol = ABCD,
#  	token_address = 0xa0CC3A881AEf241d6cB3B7Db3168BD26094560BE,
#  	token_icon = ,
#  	balance = 123456.66666911,
#  	usd_value = 0.0004223730951165658,
#  ), TokenPortfolioResponse(
#  	token_name = CHEEMSINU,
#  	token_symbol = $CINU,
#  	token_address = 0xdFE6891ce8E5a5c7Cf54fFdE406A6C2C54145F71,
#  	token_icon = ,
#  	balance = 1623733812228350.8,
#  	usd_value = 0.0,
#  ), TokenPortfolioResponse(
#  	token_name = FOX,
#  	token_symbol = FOX,
#  	token_address = 0xFAd8E46123D7b4e77496491769C167FF894d2ACB,
#  	token_icon = ,
#  	balance = 1366584170.1288667,
#  	usd_value = 3.9649175335197397,
#  ), TokenPortfolioResponse(
#  	token_name = SpacePi Token,
#  	token_symbol = SpacePi,
#  	token_address = 0x69b14e8D3CEBfDD8196Bfe530954A0C226E5008E,
#  	token_icon = ,
#  	balance = 2500000.0,
#  	usd_value = 0.018763173567083093,
#  ), TokenPortfolioResponse(
#  	token_name = Meta Ruffy,
#  	token_symbol = MR,
#  	token_address = 0x2456BBAD80BfAD346AecEa45fA38C81a6963132D,
#  	token_icon = ,
#  	balance = 88.55080041502342,
#  	usd_value = 0.025155125854045488,
#  ), TokenPortfolioResponse(
#  	token_name = SafeStar,
#  	token_symbol = SAFESTAR,
#  	token_address = 0x3C00F8FCc8791fa78DAA4A480095Ec7D475781e2,
#  	token_icon = ,
#  	balance = 1425194223.3572311,
#  	usd_value = 3.7971115381974876,
#  ), TokenPortfolioResponse(
#  	token_name = METAGALAXY LAND,
#  	token_symbol = MEGALAND,
#  	token_address = 0x7CD8c22D3F4b66230F73D7FfCB48576233c3fe33,
#  	token_icon = ,
#  	balance = 14700006237.452452,
#  	usd_value = 32.11912615127813,
#  ), TokenPortfolioResponse(
#  	token_name = ADAL Token,
#  	token_symbol = ADAL,
#  	token_address = 0xAE1107fC7CeF1294F09185aC475c9886527DcD8a,
#  	token_icon = ,
#  	balance = 81.51834631050939,
#  	usd_value = 24.34599378960906,
#  ), TokenPortfolioResponse(
#  	token_name = ElonGate,
#  	token_symbol = ElonGate,
#  	token_address = 0x2A9718defF471f3Bb91FA0ECEAB14154F150a385,
#  	token_icon = ,
#  	balance = 157614185.1774906,
#  	usd_value = 4.124876793639075,
#  ), TokenPortfolioResponse(
#  	token_name = HashPanda,
#  	token_symbol = PANDA,
#  	token_address = 0x8578Eb576e126f67913a8bC0622e0A22EBa0989A,
#  	token_icon = ,
#  	balance = 92783224.74494363,
#  	usd_value = 0.32423777838976714,
#  ), TokenPortfolioResponse(
#  	token_name = Wall Street Games,
#  	token_symbol = WSG,
#  	token_address = 0xA58950F05FeA2277d2608748412bf9F802eA4901,
#  	token_icon = ,
#  	balance = 3000000.0,
#  	usd_value = 0.032669284742385965,
#  ), TokenPortfolioResponse(
#  	token_name = TasteNFT,
#  	token_symbol = TASTE,
#  	token_address = 0xdB238123939637D65a03E4b2b485650B4f9D91CB,
#  	token_icon = ,
#  	balance = 788.133958298,
#  	usd_value = 2.044526683280907e-06,
#  ), TokenPortfolioResponse(
#  	token_name = NFTTONE,
#  	token_symbol = TONE,
#  	token_address = 0xbCdfD50ead6b6da1970464985FAb894Fb83d17C0,
#  	token_icon = ,
#  	balance = 0.01596457,
#  	usd_value = 6.549563164212614e-12,
#  ), TokenPortfolioResponse(
#  	token_name = Ethereum Token,
#  	token_symbol = ETH,
#  	token_address = 0x2170Ed0880ac9A755fd29B2688956BD959F933F8,
#  	token_icon = ,
#  	balance = 0.000933,
#  	usd_value = 2.8347708905801556,
#  ), TokenPortfolioResponse(
#  	token_name = Military Finance Token,
#  	token_symbol = MIL,
#  	token_address = 0xf5015995376a35b10dcBD96BA6B6e9de1c9f87c5,
#  	token_icon = ,
#  	balance = 1377205.98622,
#  	usd_value = 1.429901126798536,
#  ), TokenPortfolioResponse(
#  	token_name = TCGCoin 2.0,
#  	token_symbol = TCG2,
#  	token_address = 0xF73d8276C15Ce56b2f4AeE5920e62F767A7f3aEA,
#  	token_icon = ,
#  	balance = 70.0,
#  	usd_value = 39.10747260662557,
#  ), TokenPortfolioResponse(
#  	token_name = MoonStar,
#  	token_symbol = MOONSTAR,
#  	token_address = 0xCe5814eFfF15D53EFd8025B9F2006D4d7D640b9B,
#  	token_icon = ,
#  	balance = 2486027.745058016,
#  	usd_value = 0.003583627653531977,
#  ), TokenPortfolioResponse(
#  	token_name = FRAT BEP-20 Token,
#  	token_symbol = FRAT,
#  	token_address = 0x7352eEBeda1Ff0E625452Cc27D811A88216243fB,
#  	token_icon = ,
#  	balance = 139.31120642162148,
#  	usd_value = 6.502559880713942,
#  ), TokenPortfolioResponse(
#  	token_name = ZEON,
#  	token_symbol = ZEON,
#  	token_address = 0x3021ce06BCAaAAd15D48a51DfcB712e3D1eA732e,
#  	token_icon = ,
#  	balance = 407.7,
#  	usd_value = 2.260814133875832,
#  ), TokenPortfolioResponse(
#  	token_name = DogeDash,
#  	token_symbol = DogeDash,
#  	token_address = 0x7AE5709c585cCFB3e61fF312EC632C21A5F03F70,
#  	token_icon = ,
#  	balance = 0.0713508254343524,
#  	usd_value = 2.827248884990235e-05,
#  ), TokenPortfolioResponse(
#  	token_name = TCGCoin,
#  	token_symbol = TCGCoin,
#  	token_address = 0xC070C8Ae94977f78d04553D33449DEf944F24254,
#  	token_icon = ,
#  	balance = 16290988228.368645,
#  	usd_value = 0.6087512385406612,
#  ), TokenPortfolioResponse(
#  	token_name = Zepe.io,
#  	token_symbol = Zepe.io,
#  	token_address = 0xb0557906c617f0048A700758606f64b33D0C41A6,
#  	token_icon = ,
#  	balance = 750000.0,
#  	usd_value = 117872.5385192025,
#  ), TokenPortfolioResponse(
#  	token_name = LITTLE RABBIT,
#  	token_symbol = LTRBT,
#  	token_address = 0x17D749D3E2ac204a07e19D8096d9a05c423ea3af,
#  	token_icon = ,
#  	balance = 2641254008.306359,
#  	usd_value = 0.0,
#  ), TokenPortfolioResponse(
#  	token_name = Great Ape,
#  	token_symbol = GREATAPE,
#  	token_address = 0x7f4a15F5cf12E1650f090FB7Bc7B0f240f1bDe98,
#  	token_icon = ,
#  	balance = 2313842.127408083,
#  	usd_value = 4.0964765641210175,
#  ), TokenPortfolioResponse(
#  	token_name = BUSD Token,
#  	token_symbol = BUSD,
#  	token_address = 0xe9e7CEA3DedcA5984780Bafc599bD69ADd087D56,
#  	token_icon = ,
#  	balance = 8.284104525770084,
#  	usd_value = 8.292460607253895,
#  ), TokenPortfolioResponse(
#  	token_name = Quidax Token,
#  	token_symbol = QDX,
#  	token_address = 0x9e3a9F1612028eeE48F85cA85f8Bed2f37d76848,
#  	token_icon = ,
#  	balance = 1.0,
#  	usd_value = 0.010562658477813692,
#  ), TokenPortfolioResponse(
#  	token_name = MOOCHII,
#  	token_symbol = MOOCHII,
#  	token_address = 0xef032F652FCE3a0eFfce3796A68eb978b465a336,
#  	token_icon = ,
#  	balance = 0.000295436,
#  	usd_value = 2.403074328073375e-13,
#  ), TokenPortfolioResponse(
#  	token_name = GAMER,
#  	token_symbol = GMR,
#  	token_address = 0x0523215DCafbF4E4aA92117d13C6985a3BeF27D7,
#  	token_icon = ,
#  	balance = 294429391.4311665,
#  	usd_value = 0.2884563468941735,
#  ), TokenPortfolioResponse(
#  	token_name = Revoluzion,
#  	token_symbol = RVZ,
#  	token_address = 0x7D89c67d3c4E72E8c5c64BE201dC225F99d16aCa,
#  	token_icon = ,
#  	balance = 37651.875306836,
#  	usd_value = 13.410389846210657,
#  ), TokenPortfolioResponse(
#  	token_name = Refinable,
#  	token_symbol = FINE,
#  	token_address = 0x4e6415a5727ea08aAE4580057187923aeC331227,
#  	token_icon = ,
#  	balance = 5.352323721423822,
#  	usd_value = 0.3916540852980946,
#  )]

# %%
df = pd.DataFrame(
    [p.__dict__ for p in portfolio],
)
df
# Out:
#                 token_name token_symbol  \
# 0                Stakeable        STAKE
# 1          Project Quantum         QBIT
# 2           NFTArt.Finance       NFTART
# 3       Helicopter Finance      $COPTER
# 4             Binance Coin          BNB
# 5                MicroPets         PETS
# 6              Burger Swap       BURGER
# 7                 SafeMoon     SAFEMOON
# 8               Tether USD         USDT
# 9                    Papel        PAPEL
# 10               Pig Token          PIG
# 11                SafeMoon          SFM
# 12              BLinkToken        blink
# 13    DigitalFinancialExch         DIFX
# 14               SHIBA INU         SHIB
# 15                 ENHANCE          ENH
# 16              SafeRocket   SAFEROCKET
# 17          TreeDefi Token         SEED
# 18              Exchange99         EX99
# 19               CumRocket      CUMMIES
# 20              Crypto Inu         ABCD
# 21               CHEEMSINU        $CINU
# 22                     FOX          FOX
# 23           SpacePi Token      SpacePi
# 24              Meta Ruffy           MR
# 25                SafeStar     SAFESTAR
# 26         METAGALAXY LAND     MEGALAND
# 27              ADAL Token         ADAL
# 28                ElonGate     ElonGate
# 29               HashPanda        PANDA
# 30       Wall Street Games          WSG
# 31                TasteNFT        TASTE
# 32                 NFTTONE         TONE
# 33          Ethereum Token          ETH
# 34  Military Finance Token          MIL
# 35             TCGCoin 2.0         TCG2
# 36                MoonStar     MOONSTAR
# 37       FRAT BEP-20 Token         FRAT
# 38                    ZEON         ZEON
# 39                DogeDash     DogeDash
# 40                 TCGCoin      TCGCoin
# 41                 Zepe.io      Zepe.io
# 42           LITTLE RABBIT        LTRBT
# 43               Great Ape     GREATAPE
# 44              BUSD Token         BUSD
# 45            Quidax Token          QDX
# 46                 MOOCHII      MOOCHII
# 47                   GAMER          GMR
# 48              Revoluzion          RVZ
# 49               Refinable         FINE
#
#                                  token_address token_icon       balance  \
# 0   0x5eC2A778717Cf1A5018C6aE3A7A2957582A92007             1.000000e+04
# 1   0xA38898a4Ae982Cb0131104a6746f77fA0dA57aAA             6.614646e+04
# 2   0xF7844CB890F4C339c497aeAb599aBDc3c874B67A             2.946743e+08
# 3   0xBC12aD556581ff7162E595E5956F5F3845FDB38c             3.394978e+09
# 4                                                          1.331519e-01
# 5   0xA77346760341460B42C230ca6D21d4c8E743Fa9c             4.650000e+06
# 6   0xAe9269f27437f0fcBC232d39Ec814844a51d6b8f             9.298422e-07
# 7   0x8076C74C5e3F5852037F31Ff0093Eeb8c8ADd8D3             8.852433e+00
# 8   0x55d398326f99059fF775485246999027B3197955             9.261645e-04
# 9   0x557dd6700e66818AF340ccE17FD4508CED81fBc1             4.679256e+08
# 10  0x8850D2c68c632E3B258e612abAA8FadA7E6958E5             6.124130e+06
# 11  0x42981d0bfbAf196529376EE702F2a9Eb9092fcB5             1.849014e+04
# 12  0x63870A18B6e42b01Ef1Ad8A2302ef50B7132054F             9.000000e-06
# 13  0x697bd938e7E572E787ecd7bC74a31f1814C21264             1.046458e+02
# 14  0x2859e4544C4bB03966803b044A93563Bd2D0DD4D             1.035682e-03
# 15  0xA001862BA0866Ee3e3a2613fAb5954861452B9Bf             4.343422e+08
# 16  0x95AAC643E2760267cbE4c52b2BAc5505B9049a1E             5.046343e+08
# 17  0x40B34cC972908060D6d527276e17c105d224559d             2.000000e-02
# 18  0xa5B517b0a8e28909B92DC052D31F1335d7a1cCC0             1.766400e+02
# 19  0x27Ae27110350B98d564b9A3eeD31bAeBc82d878d             9.330728e-03
# 20  0xa0CC3A881AEf241d6cB3B7Db3168BD26094560BE             1.234567e+05
# 21  0xdFE6891ce8E5a5c7Cf54fFdE406A6C2C54145F71             1.623734e+15
# 22  0xFAd8E46123D7b4e77496491769C167FF894d2ACB             1.366584e+09
# 23  0x69b14e8D3CEBfDD8196Bfe530954A0C226E5008E             2.500000e+06
# 33  2.834771e+00
# 34  1.429901e+00
# 35  3.910747e+01
# 36  3.583628e-03
# 37  6.502560e+00
# 38  2.260814e+00
# 39  2.827249e-05
# 40  6.087512e-01
# 41  1.178725e+05
# 42  0.000000e+00
# 43  4.096477e+00
# 44  8.292461e+00
# 45  1.056266e-02
# 46  2.403074e-13
# 47  2.884563e-01
# 48  1.341039e+01
# 49  3.916541e-01

# %%
print(f"Total value in USD is: {df['usd_value'].sum()}.")
# Out:
# Total value in USD is: 118141.37754438195.

# %% [markdown]
# ## LP swaps

# %%
client.get_lps_swaps(
    from_wallet=WALLET,
    # contract = "XXX", # specify LP token
    # token_contract = "XXX", # specify queried token
    validate_params=False,
)
# Out:
# []

# %% [markdown]
# ## Wallet Transactions

# %%
transactions = client.get_wallets_txs(
    address = WALLET,
    limit = 10,
    page = 1,
    from_ = "2022-01-02",
    to = "2022-02-01",
)
transactions
# Out:
# [TransactionResponse(
#  	tx_hash = 0x0f23094024ef9ff734e1024d3625adff070c373fb3b074cb2cd075ce174e735a,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-04 11:16:23+00:00,
#  	block = 14069436,
#  	value = 0.0,
#  	tx_fee = 0.001856465,
#  ), TransactionResponse(
#  	tx_hash = 0x35fbf4e1e0ca5bc37643f06417d406c495cd8824249e1da3bc7800ecec3e752b,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x187452821892Ff83B86C7d5b43dDC553E8c054bF,
#  	time = 2022-01-04 11:17:47+00:00,
#  	block = 14069464,
#  	value = 1.45,
#  	tx_fee = 0.000105,
#  ), TransactionResponse(
#  	tx_hash = 0x48e69a647eed4a801576fcdd6016313deded3be1cb22363e6fa1174f8fe76d1c,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-06 17:29:12+00:00,
#  	block = 14134316,
#  	value = 0.1,
#  	tx_fee = 0.000678315,
#  ), TransactionResponse(
#  	tx_hash = 0x8e54db189427096f8a4e40f7bb6114a195dd0adf5cf50fb46d132181e3b53296,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x42981d0bfbAf196529376EE702F2a9Eb9092fcB5,
#  	time = 2022-01-07 15:48:30+00:00,
#  	block = 14161005,
#  	value = 0.0,
#  	tx_fee = 0.00024674,
#  ), TransactionResponse(
#  	tx_hash = 0xf8b1f8bc0b73ac7438aa692a93ac98e9bcb4b54495acfc91b9ca5c5182a561fc,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-07 15:49:00+00:00,
#  	block = 14161015,
#  	value = 0.0,
#  	tx_fee = 0.00302564,
#  ), TransactionResponse(
#  	tx_hash = 0x4a8da906290686f95fae537ee8dfeb039de47d04120723660f2c07eb7a2786ef,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-12 19:14:35+00:00,
#  	block = 14308859,
#  	value = 0.0762971041863534,
#  	tx_fee = 0.002624595,
#  ), TransactionResponse(
#  	tx_hash = 0x5a39d494e6973f2b57afa98790bbff4c2f50a55092cae77fb2ff7ba7950e4a65,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-16 16:34:35+00:00,
#  	block = 14420589,
#  	value = 0.0,
#  	tx_fee = 0.002780515,
#  ), TransactionResponse(
#  	tx_hash = 0xc1f78087dda1844bf3bbc33ac343148052afeb7588520d3d25814431711f6d26,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-16 16:35:26+00:00,
#  	block = 14420606,
#  	value = 0.02,
#  	tx_fee = 0.00097066,
#  ), TransactionResponse(
#  	tx_hash = 0xd6b44d980c44d5d738b2748d17a3b425c414de82a9f96cdf3d8dbd349e104bca,
#  	from_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	to_address = 0x10ED43C718714eb63d5aA57B78B54704E256024E,
#  	time = 2022-01-16 16:36:38+00:00,
#  	block = 14420630,
#  	value = 0.0768328910802409,
#  	tx_fee = 0.008075645,
#  ), TransactionResponse(
#  	tx_hash = 0x6c18c377cadb008dc4b90fca785e94a7d9a207b315b3b7929fe3dfe58dc484a8,
#  	from_address = 0xdccF3B77dA55107280bd850ea519DF3705D1a75a,
#  	to_address = 0xC225b973733f38D293B8cFdaB7bA87D7dA7D92Fa,
#  	time = 2022-01-24 02:33:36+00:00,
#  	block = 14633030,
#  	value = 0.1547122,
#  	tx_fee = 0.00021,
#  )]

# %%
df = pd.DataFrame(
    [t.__dict__ for t in transactions],
).set_index("time")
df
# Out:
#                                                                      tx_hash  \
# time
# 2022-01-04 11:16:23+00:00  0x0f23094024ef9ff734e1024d3625adff070c373fb3b0...
# 2022-01-04 11:17:47+00:00  0x35fbf4e1e0ca5bc37643f06417d406c495cd8824249e...
# 2022-01-06 17:29:12+00:00  0x48e69a647eed4a801576fcdd6016313deded3be1cb22...
# 2022-01-07 15:48:30+00:00  0x8e54db189427096f8a4e40f7bb6114a195dd0adf5cf5...
# 2022-01-07 15:49:00+00:00  0xf8b1f8bc0b73ac7438aa692a93ac98e9bcb4b54495ac...
# 2022-01-12 19:14:35+00:00  0x4a8da906290686f95fae537ee8dfeb039de47d041207...
# 2022-01-16 16:34:35+00:00  0x5a39d494e6973f2b57afa98790bbff4c2f50a55092ca...
