# %% [markdown]
# # LP Swaps Example

# %% [markdown]
# ## Intro

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from dotenv import load_dotenv

# %%
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm, trange

from helixirapi.helixir_api import HelixirApi

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %% [markdown]
# ### Create client instance

# %%
load_dotenv()
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
client = HelixirApi(auth_token=AUTH_TOKEN)
client

# %% [markdown]
# ## Getting Data
#
# Method `get_lps_swaps` returns most recent swaps for given wallet and token, with pagination.
#
# ***Parameters:***
#
# `chain`
# - It is an optional parameter with the default value `"bsc"` (_Binance Smart Chain_). The chain can be specified as a string (case insensitive) or an integer (chain id).
#
# `symbol`
# - The symbol is an optional parameter. It could be used instead of the `contract` parameter; however, the symbol must be unique (at least within the chain), so it could be used only for some tokens.
#
# `contract`
# - The contract parameter is required. However, as mentioned above, it could be omitted if the `symbol` is specified.
#
# `from_wallet`
# - Required parameter of wallet address (in string format).
#
# `token_contract`
# - Optional parameter with filter functionality.
#
# `from_`
# - `from_` is the required parameter; however, the start of data history is used if omitted. The date could be entered as a timestamp (integer number) or by a human-readable string (e.g., `2022-05-01`).
#
# `to`
# - The default value is _now_. The format is the same as for parameter `from_`, so a timestamp or a string could be entered. Maximal allowed range between `from_` and `to` is one month.
#
# `limit`
# - By default, number of items is 10. Maximal allowed value is 100.
#
# `page`
# - Optional parameter, by default equal to 1.
#
# `sort`
# - Optional parameter for sorting the items. Items are sorted descending according to time by default.
#
# `validate_params`
# - An optional parameter with a default value equal to _True_.

# %%
client.get_token(
    contract = "0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c",
)
# Out:
# TokenResponse(
# 	name = Wrapped BNB,
# 	symbol = WBNB,
# 	chain = BSC,
# 	decimals = 18.0,
# 	total_supply = 5531154.591167131,
# 	circulating_supply = 5531147.758404688,
# 	contract = 0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c,
# )

# %%
swaps = client.get_lps_swaps(
    from_ = "2022-04-01",
    limit = 100,
    contract="0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6",
)
swaps
# Out:
# [LPMoveResponse(
#  	time = 2022-04-20 20:30:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -26638563399.26871,
#  	amount_1 = 1e-15,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:22:37+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 1e+18,
#  	amount_1 = -0.6017646225419792,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:22:10+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 29852473.50182407,
#  	amount_1 = -0.0002888287717587,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:19:55+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -206268251.2238177,
#  	amount_1 = 0.002,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:18:13+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 60819828600.49318,
#  	amount_1 = -25.50125289786584,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:17:43+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 25628087.984773017,
#  	amount_1 = -0.4676351162232947,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:17:43+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 1683165.980085744,
#  	amount_1 = -0.030699216661148,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:17:37+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 1852614.359932333,
#  	amount_1 = -0.033819506575094,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:15:19+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5996050.891419035,
#  	amount_1 = 0.11,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:15:07+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -4857048.082820003,
#  	amount_1 = 0.089088971,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:14:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -2726286.147252904,
#  	amount_1 = 0.05,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:13:04+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -38762677.00795112,
#  	amount_1 = 0.7104314824569234,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:12:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -268776369.16770095,
#  	amount_1 = 5.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:12:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 616739538.895719,
#  	amount_1 = -11.352418394161784,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:12:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -616739538.895719,
#  	amount_1 = 11.310367136871351,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:11:22+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5507665.28768213,
#  	amount_1 = 0.1,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:10:52+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -270000.0,
#  	amount_1 = 0.0049018057826547,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:10:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -18968955.097464297,
#  	amount_1 = 0.3442721125808709,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:09:49+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -36544679.08828954,
#  	amount_1 = 0.6626689992133022,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:09:37+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1730818.220871093,
#  	amount_1 = 0.0313659407745909,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:09:28+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -60870372.31529207,
#  	amount_1 = 1.101990064336196,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:09:10+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1658758.391342119,
#  	amount_1 = 0.03,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:08:31+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -4712672.555386763,
#  	amount_1 = 0.0852238499905769,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:07:40+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1659096.152143615,
#  	amount_1 = 0.03,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:07:40+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -55353638.77737456,
#  	amount_1 = 1.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:07:19+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -38805822.94424526,
#  	amount_1 = 0.7,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:06:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -86075697.94565679,
#  	amount_1 = 1.5495886723731456,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:06:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 42414596.2974809,
#  	amount_1 = -0.7592329119824346,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:05:58+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -15537083.404079229,
#  	amount_1 = 0.2796328146892766,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:05:13+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -51730759.006937355,
#  	amount_1 = 0.9300401900148483,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:04:46+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -72932756.19035202,
#  	amount_1 = 1.3086192651322086,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:03:52+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -11161433.242031353,
#  	amount_1 = 0.2,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:03:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -103122105.53081244,
#  	amount_1 = 1.8444729081038278,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:03:01+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -7006137.180443778,
#  	amount_1 = 0.1250950240299569,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:02:34+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -28018844.826627947,
#  	amount_1 = 0.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:02:13+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -18057568.23094291,
#  	amount_1 = 0.3220042263438388,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:01:10+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -23280104.789223857,
#  	amount_1 = 0.4148608103762561,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:00:49+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -55417125.90057598,
#  	amount_1 = 0.9863234522220324,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:00:10+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -84401830.93460917,
#  	amount_1 = 1.498873998317514,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 17:00:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 5985162.92273677,
#  	amount_1 = -0.1056273728135533,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:59:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -72536352.74644268,
#  	amount_1 = 1.2852054285911114,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:59:10+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -42660564.85679426,
#  	amount_1 = 0.7544887054204753,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:58:14+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -19796852.944756083,
#  	amount_1 = 0.3497791909995094,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:57:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5134833.737241856,
#  	amount_1 = 0.090688732,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:57:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -15178609.05201593,
#  	amount_1 = 0.2679905940320349,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:56:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -23873644.57848741,
#  	amount_1 = 0.4212486487188562,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:56:14+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -73254332.22979517,
#  	amount_1 = 1.2905871459050464,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:56:05+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -4546405.969423505,
#  	amount_1 = 0.08,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:55:50+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 105322480.8222739,
#  	amount_1 = -1.8469628571038277,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:55:11+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -7737138.335888361,
#  	amount_1 = 0.1365706278359611,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:54:44+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -87632417.33725655,
#  	amount_1 = 1.5444992373560151,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:54:11+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -28421135.069261454,
#  	amount_1 = 0.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:53:20+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -81673879.94494446,
#  	amount_1 = 1.434360453411584,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:52:23+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -218530963.4860647,
#  	amount_1 = 3.8197734402171943,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:52:20+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1361436.207298642,
#  	amount_1 = 0.0237150296089858,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:51:41+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -282553942.672736,
#  	amount_1 = 4.9,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:51:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -290913152.8762812,
#  	amount_1 = 5.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:50:29+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -17538750.69063913,
#  	amount_1 = 0.3,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:50:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -156195448.0734879,
#  	amount_1 = 2.66451854,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:49:47+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -80575153.41011918,
#  	amount_1 = 1.3694854,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:48:50+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -44533538.68145611,
#  	amount_1 = 0.75544426,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:47:14+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5599113.165199898,
#  	amount_1 = 0.0949069195274994,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:46:17+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -165626410.77249548,
#  	amount_1 = 2.8,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:45:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -185952303.5499989,
#  	amount_1 = 3.126614754,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:44:11+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 616737.964468163,
#  	amount_1 = -0.0102887056281358,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:43:56+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -894661.788955494,
#  	amount_1 = 0.015,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:43:32+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -109528293.5246823,
#  	amount_1 = 1.8332454,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:43:23+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5985162.92273677,
#  	amount_1 = 0.1,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:42:17+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -29852473.50182407,
#  	amount_1 = 0.4985,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:41:32+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -17978572.952321466,
#  	amount_1 = 0.3,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:41:26+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1422887.981214261,
#  	amount_1 = 0.0237360016496958,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:40:35+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 604553.784866321,
#  	amount_1 = -0.0100344173104343,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:40:20+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -374016775.8680695,
#  	amount_1 = 6.20351451,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:40:17+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -604553.784866321,
#  	amount_1 = 0.00997,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:40:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -4836832.230080754,
#  	amount_1 = 0.07976,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:38:24+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -2226537.945638755,
#  	amount_1 = 0.0367119488788975,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:37:54+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -91102991.17410012,
#  	amount_1 = 1.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:37:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 35036752.423622295,
#  	amount_1 = -0.5735052602133023,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:36:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -140034906.39725283,
#  	amount_1 = 2.3,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:36:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -54132431.34666012,
#  	amount_1 = 0.88647445,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:35:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -221640074.2082016,
#  	amount_1 = 3.61441145,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:35:18+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -78117275.73409536,
#  	amount_1 = 1.2681289745,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:34:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -53795761.07258262,
#  	amount_1 = 0.871544454,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:34:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -616737.964468163,
#  	amount_1 = 0.01,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:34:33+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 242608123.70109773,
#  	amount_1 = -3.9220534732171943,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:33:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 88437191.339164,
#  	amount_1 = -1.436640318411584,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:33:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -5102448.997204722,
#  	amount_1 = 0.08319882,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:33:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -143808804.75361452,
#  	amount_1 = 2.345874154,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:32:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -99405827.86596166,
#  	amount_1 = 1.6155845,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:32:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -320358323.7638979,
#  	amount_1 = 5.17365215,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:31:27+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -84442661.66850422,
#  	amount_1 = 1.3554145,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:30:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -42414596.29748096,
#  	amount_1 = 0.679511454,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:30:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -375714315.27980804,
#  	amount_1 = 5.9815411,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:29:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -103470068.34016864,
#  	amount_1 = 1.63551541,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:28:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -182870712.12597078,
#  	amount_1 = 2.878247871,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:28:12+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -14119271.518672235,
#  	amount_1 = 0.2215758854681282,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:27:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -86591282.01142761,
#  	amount_1 = 1.3568541,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:27:21+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 32760472.83574198,
#  	amount_1 = -0.5103728542076644,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:27:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -216560393.04822248,
#  	amount_1 = 3.38145151,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:26:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -55391835.76950508,
#  	amount_1 = 0.861426551,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  )]

# %%
pd.DataFrame([s.__dict__ for s in swaps])
# Out:
#                         time token_symbol      amount_0      amount_1  \
# 0  2022-04-20 20:30:51+00:00     See/WBNB -2.663856e+10  1.000000e-15
# 1  2022-04-20 17:22:37+00:00     See/WBNB  1.000000e+18 -6.017646e-01
# 2  2022-04-20 17:22:10+00:00     See/WBNB  2.985247e+07 -2.888288e-04
# 3  2022-04-20 17:19:55+00:00     See/WBNB -2.062683e+08  2.000000e-03
# 4  2022-04-20 17:18:13+00:00     See/WBNB  6.081983e+10 -2.550125e+01
# ..                       ...          ...           ...           ...
# 95 2022-04-20 16:28:12+00:00     See/WBNB -1.411927e+07  2.215759e-01
# 96 2022-04-20 16:27:51+00:00     See/WBNB -8.659128e+07  1.356854e+00
# 97 2022-04-20 16:27:21+00:00     See/WBNB  3.276047e+07 -5.103729e-01
# 98 2022-04-20 16:27:15+00:00     See/WBNB -2.165604e+08  3.381452e+00
# 99 2022-04-20 16:26:51+00:00     See/WBNB -5.539184e+07  8.614266e-01
#
#                                 token_contract
# 0   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 1   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 2   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 3   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 4   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# ..                                         ...
# 95  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 96  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 97  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 98  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 99  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
#
# [100 rows x 5 columns]

# %%
swaps = client.get_lps_swaps(
    from_wallet = "0x8894E0a0c962CB723c1976a4421c95949bE2D4E3",
    from_ = "2022-04-01",
    limit = 100,
    contract="0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6",
)
swaps
# Out:
# [LPMoveResponse(
#  	time = 2022-04-20 16:59:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -72536352.74644268,
#  	amount_1 = 1.2852054285911114,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  )]

# %%
swaps = client.get_lps_swaps(
    from_ = "2022-04-01",
    limit = 100,
    contract="0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6",
    sort = "+time",
)
swaps
# Out:
# [LPMoveResponse(
#  	time = 2022-04-20 16:00:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -25628087.984773017,
#  	amount_1 = 0.3,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1706978.776529009,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:24+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -205322480.82227394,
#  	amount_1 = 2.422414554,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -2525106.486565128,
#  	amount_1 = 0.03,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1683165.980085744,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -414902082.77215844,
#  	amount_1 = 5.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:00:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1636324.756603909,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:01:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -409052.62174158,
#  	amount_1 = 0.005,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:01:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -536311143.2144883,
#  	amount_1 = 6.6776554521,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:01:27+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -128423118.3086918,
#  	amount_1 = 1.636141365,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:01:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -15619628.897642806,
#  	amount_1 = 0.2,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -32097808.05192617,
#  	amount_1 = 0.4116786945143941,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -267031933.7168687,
#  	amount_1 = 3.46101225,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1852614.359932333,
#  	amount_1 = 0.02424,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 32097808.05192617,
#  	amount_1 = -0.4174334666941189,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:21+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -76389775.72403026,
#  	amount_1 = 1.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 31328539.874177773,
#  	amount_1 = -0.4207137329285699,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -375036752.4236223,
#  	amount_1 = 5.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:02:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -31328539.874177773,
#  	amount_1 = 0.4116786945143941,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:33+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -741757.552964352,
#  	amount_1 = 0.01,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -3708560.208292162,
#  	amount_1 = 0.05,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1483317.753294763,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 1706978.776529009,
#  	amount_1 = -0.0229006832682889,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 14902082.772158472,
#  	amount_1 = -0.1998794335064397,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:03:57+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 3119642.509898672,
#  	amount_1 = -0.0418329181388768,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:04:18+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -234715173.87395516,
#  	amount_1 = 3.17334154,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:04:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -73649815.53861767,
#  	amount_1 = 1.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:05:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1471462.970587059,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:05:30+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -365995219.05814606,
#  	amount_1 = 5.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:05:33+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 1471462.970587059,
#  	amount_1 = -0.0201034898086166,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:05:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1456578.106006088,
#  	amount_1 = 0.02,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:06:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -36395281.00310931,
#  	amount_1 = 0.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:06:12+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 103311143.21448833,
#  	amount_1 = -1.4108992981322086,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:06:33+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 68423118.3086918,
#  	amount_1 = -0.9322151390148483,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:06:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -99053016.88530377,
#  	amount_1 = 1.3568757,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:06:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 20619628.897642806,
#  	amount_1 = -0.2813545466892766,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:07:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 77031933.71686868,
#  	amount_1 = -1.049677573571178,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:07:12+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 80389775.72403026,
#  	amount_1 = -1.0930450973361958,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:07:18+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -58561219.948692985,
#  	amount_1 = 0.8,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:07:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -144619527.87751198,
#  	amount_1 = 1.981221454,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:08:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -181660600.75604507,
#  	amount_1 = 2.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:08:30+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -241856876.0719925,
#  	amount_1 = 3.3481564,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:09:03+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -189707623.4612365,
#  	amount_1 = 2.6421445,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:09:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -48416833.33375041,
#  	amount_1 = 0.6765814355,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -71512.195770493,
#  	amount_1 = 0.001,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -276207092.6141951,
#  	amount_1 = 3.8774124,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:24+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 24715173.873955157,
#  	amount_1 = -0.3464470615808709,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 8369815.538617669,
#  	amount_1 = -0.1172699730299569,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -376263069.95669186,
#  	amount_1 = 5.32589927,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:10:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 37599529.05814608,
#  	amount_1 = -0.5320987045423586,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:12+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -96066035.2141473,
#  	amount_1 = 1.367456441,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:18+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 23395281.003109314,
#  	amount_1 = -0.3317006913438388,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:27+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -148602731.67755607,
#  	amount_1 = 2.1212423551,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:27+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -935322.891200816,
#  	amount_1 = 0.0133797580787444,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 2525106.486565128,
#  	amount_1 = -0.0359403627783933,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:11:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -8279767.939814002,
#  	amount_1 = 0.1184487804061546,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:12:09+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -302760472.835742,
#  	amount_1 = 4.35044255,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:12:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -2101890.488453332,
#  	amount_1 = 0.0303342109724526,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:12:39+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 29053016.885303758,
#  	amount_1 = -0.4170357593762561,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:12:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -34656049.66073259,
#  	amount_1 = 0.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:13:24+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -88437191.33916415,
#  	amount_1 = 1.27817111,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:13:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 68561209.94869299,
#  	amount_1 = -0.9862428672220324,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:14:11+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 104619527.87751196,
#  	amount_1 = -1.501230198317514,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:14:20+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -98576504.45827223,
#  	amount_1 = 1.4214929488917847,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:14:38+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -257290055.09230673,
#  	amount_1 = 3.72908714615468,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:14:44+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 3708560.208292162,
#  	amount_1 = -0.0536770000993292,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:14:50+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -641770.022024818,
#  	amount_1 = 0.0093350673340284,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:15:14+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -618723.534259197,
#  	amount_1 = 0.009,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:15:29+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -239786713.1324384,
#  	amount_1 = 3.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:15:50+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -27299192.588742767,
#  	amount_1 = 0.4,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:16:05+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -20460329.18546323,
#  	amount_1 = 0.3,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:16:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 88160600.75604507,
#  	amount_1 = -1.2849564615911113,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:16:23+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -108491354.98176569,
#  	amount_1 = 1.589681512,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:16:26+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 51856876.071992494,
#  	amount_1 = -0.7566636544204753,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:16:41+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -1618918.053637588,
#  	amount_1 = 0.0237236772225436,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:17:05+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -242608123.70109773,
#  	amount_1 = 3.56770558125,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:17:50+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 23977623.46123649,
#  	amount_1 = -0.3519541399995094,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:18:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 18416833.333750416,
#  	amount_1 = -0.2701654590320349,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:18:08+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -193583592.90412825,
#  	amount_1 = 2.861247254,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:18:35+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -67402176.39705369,
#  	amount_1 = 1.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:19:25+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -253501275.66445634,
#  	amount_1 = 3.77855412421,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:20:11+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -133426880.47916093,
#  	amount_1 = 2.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:20:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -111131439.38781522,
#  	amount_1 = 1.671745685,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:21:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -57699574.05448164,
#  	amount_1 = 0.87011242,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:21:42+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 28207092.61419509,
#  	amount_1 = -0.4234234297188562,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:21:57+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 86263069.95669188,
#  	amount_1 = -1.2927620949050465,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:22:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -221595518.68199942,
#  	amount_1 = 3.344154145,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:22:45+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -40399274.67250916,
#  	amount_1 = 0.61201456,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:23:18+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -89706286.46812491,
#  	amount_1 = 1.3615626,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:23:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -351963088.1367906,
#  	amount_1 = 5.3768145411,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:24:06+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -84905944.01583637,
#  	amount_1 = 1.3054385,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:24:24+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 9066035.214147298,
#  	amount_1 = -0.1388505768359611,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:24:48+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -186340398.6943972,
#  	amount_1 = 2.87572021,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:24:57+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 100602731.67755607,
#  	amount_1 = -1.546779270356015,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:25:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -32390255.6426141,
#  	amount_1 = 0.5,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:26:00+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -142150262.01142672,
#  	amount_1 = 2.2,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:26:33+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -64416568.5652508,
#  	amount_1 = 1.0,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:26:36+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = 50000.0,
#  	amount_1 = -0.0007730589370839,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:26:51+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -55391835.76950508,
#  	amount_1 = 0.861426551,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  ), LPMoveResponse(
#  	time = 2022-04-20 16:27:15+00:00,
#  	token_symbol = See/WBNB,
#  	amount_0 = -216560393.04822248,
#  	amount_1 = 3.38145151,
#  	token_contract = 0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6,
#  )]

# %%
pd.DataFrame([s.__dict__ for s in swaps])
# Out:
#                         time token_symbol      amount_0  amount_1  \
# 0  2022-04-20 16:00:09+00:00     See/WBNB -2.562809e+07  0.300000
# 1  2022-04-20 16:00:09+00:00     See/WBNB -1.706979e+06  0.020000
# 2  2022-04-20 16:00:24+00:00     See/WBNB -2.053225e+08  2.422415
# 3  2022-04-20 16:00:42+00:00     See/WBNB -2.525106e+06  0.030000
# 4  2022-04-20 16:00:45+00:00     See/WBNB -1.683166e+06  0.020000
# ..                       ...          ...           ...       ...
# 95 2022-04-20 16:26:00+00:00     See/WBNB -1.421503e+08  2.200000
# 96 2022-04-20 16:26:33+00:00     See/WBNB -6.441657e+07  1.000000
# 97 2022-04-20 16:26:36+00:00     See/WBNB  5.000000e+04 -0.000773
# 98 2022-04-20 16:26:51+00:00     See/WBNB -5.539184e+07  0.861427
# 99 2022-04-20 16:27:15+00:00     See/WBNB -2.165604e+08  3.381452
#
#                                 token_contract
# 0   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 1   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 2   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 3   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 4   0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# ..                                         ...
# 95  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 96  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 97  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 98  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
# 99  0x06f6286dd4a24A32E8F4696C8f2f6F01a8F8bAA6
#
# [100 rows x 5 columns]
